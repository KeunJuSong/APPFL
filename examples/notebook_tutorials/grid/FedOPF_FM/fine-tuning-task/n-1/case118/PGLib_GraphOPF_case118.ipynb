# %% [markdown]
# # N-1 Fine tuning task for FedOPF
#
# * Create N-1 contingencies: number & indicies of cut off lines and generators
#     * For the dataset, we only need to generate load because this is unsupervised way
# * Test on the zero-shot (i.e., just inference by using pretrained client/server/global model)
#     * For branch contingency, zero-shot is effective! (Done)
#     * **However, for generator contingency, fine-tuning must be needed**

# %%
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cu121.html

# !pip install pypower
# !pip install pyrlu
# # !pip install conflictfree

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
# os.environ["PYTORCH_LINALG_WARNINGS"] = "0"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0"
# os.environ["CUDA_VISIBLE_DEVICES"] = '0, 1, 2, 3'

import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Device:', device)  # 출력결과: cuda
print('Count of using GPUs:', torch.cuda.device_count())   #출력결과: 1 (GPU #2 한개 사용하므로)
print('Current cuda device:', torch.cuda.current_device())  # 출력결과: 2 (GPU #2 의미)
# Out:
# Device: cuda
# Count of using GPUs: 1
# Current cuda device: 0

# %%
from utils.utils118_graphlde import ACOPFProblem
grid_data_path = './data/pglib_opf_case118.mat'
grid = ACOPFProblem(grid_filename=grid_data_path)
# Out:
# /global/u1/k/kjsong/FedOPF-APPFL/fine-tuning-task/n-1/case118/utils/utils118_graphlde.py:88: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   self.slackva = torch.tensor([np.deg2rad(self.ppc['bus'][self.slack, idx_bus.VA])],

# %%
component="branch" # "gen" or "branch"
num_cases = 2
contingencies = grid.check_contingencies(component=component, num_cases=num_cases)

contingencies['contingencies'] = [x for x in contingencies['contingencies'] if x]
acopf_contingencies = []
for c in range(contingencies['num_cases']):
    acopf_contingencies += [ACOPFProblem(grid_filename=grid_data_path, contingencies=contingencies['contingencies'][c], component=component)] # update the grid components' values from modified ppc data based on the contingencies 

    # Put all variables in "data" to the cuda.
    acopf_contingencies[-1]._device = device
    for attr in dir(acopf_contingencies[-1]):
        var = getattr(acopf_contingencies[-1], attr)
        if not callable(var) and not attr.startswith("__") and torch.is_tensor(var):
            try:
                setattr(acopf_contingencies[-1], attr, var.to(device))
            except AttributeError:
                pass
# Out:
# 54
# 185
#
# Converged in 0.56 seconds
# Objective Function Value = 97213.97 $/hr
# ================================================================================
# |     System Summary                                                           |
# ================================================================================
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses            118     Total Gen Capacity    6515.0       -5777.0 to 7954.0
# Generators        54     On-line Capacity      6515.0       -5777.0 to 7954.0
# Committed Gens    54     Generation (actual)   4380.7             847.6
# Loads             99     Load                  4242.0            1438.0
#   Fixed           99       Fixed               4242.0            1438.0
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts            14     Shunt (inj)             -0.0              86.4
# Branches         185     Losses (I^2 * Z)       138.69            942.49
# Transformers      11     Branch Charging (inj)     -             1446.5
# Inter-ties         0     Total Inter-tie Flow     0.0               0.0
# Areas              1
#
#                           Minimum                      Maximum
#                  -------------------------  --------------------------------
# Voltage Magnitude   0.984 p.u. @ bus 75         1.060 p.u. @ bus 99
# Voltage Angle     -28.70 deg   @ bus 40        10.30 deg   @ bus 88
# P Losses (I^2*R)             -                  7.21 MW    @ line 46-68
# Q Losses (I^2*X)             -                 73.80 MVAr  @ line 8-9
# Lambda P           24.61 $/MWh @ bus 88        34.93 $/MWh @ bus 41
# Lambda Q           -0.20 $/MWh @ bus 24         0.44 $/MWh @ bus 75
#
# ================================================================================
# |     Bus Data                                                                 |
# ================================================================================
#  Bus      Voltage          Generation             Load          Lambda($/MVA-hr)
#   #   Mag(pu) Ang(deg)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)     P        Q
# ----- ------- --------  --------  --------  --------  --------  -------  -------
#     0  1
mu   Bus
# -----  -----  -------  --------  --------  --------  -------  -----
#  105     48      -       83.01     87.00     87.00    31.904    68
#  161     99     3.355   151.00    151.00    148.03      -      102

# %%
contingencies
# Out:
# {'contingencies': [{'branch': 45}, {'branch': 145}], 'num_cases': 2}

# %%
from pypower import idx_bus, idx_gen, idx_brch
import numpy as np
import torch_geometric
from torch_geometric.data import Data 
from models.Edge_GNN_solver import Edge_GNNSolver
import copy

# Load data generation (unsupervised)
pd_base = grid.ppc['bus'][:,idx_bus.PD] / grid.baseMVA.item()
qd_base = grid.ppc['bus'][:,idx_bus.QD] / grid.baseMVA.item()
num_data = 200
perturb = (1.0 + np.random.uniform(-0.1, 0.1, size=(num_data, grid.nbus)))

# data sample from uniform distribution
pd_samples = torch.from_numpy(pd_base * perturb).float()
qd_samples = torch.from_numpy(qd_base * perturb).float()
demand = pd_samples + 1j*qd_samples

# %%
# Graph data representation
graph_dataset_contingency = []
graph_dataset_contingency_statics = []

# Model config
train_config = {
    'probType': 'acopf',
    'useCompl': True, # boolean type: whether to use completion (DC3, DeepLDE 기술)

    # GNN model parameters
    'n_gnn_layers': 3,
    'nfeature_dim': 2, # input dim
    'efeature_dim': 4, # edge feature dim 
    'hidden_dim': 40,
    'dropout_rate': 0.1,
    'K': 10, # 6 # only for TAGConv or ChebConv and GATConv (as multi-head)

    # DeepLDE hyperparameters
    'epochs': 20, # 10 (GPU RTX 4090), 8 (GPU A100)
    'batchSize': 5, # 6, (8) (GPU RTX 4090; GPU 다운 에러 발생..), 16 (GPU A100)
    'lr': 1e-2, # 1e-3
    'lr_w': 1e-2, # 1e-3
    # 'weight_decay': 0.0, # 1e-5,
    'weight_decay': 1e-5, # 1e-5,

    # LDF parameters
    'rho_init': 0.1, # 0.01  
    's_init': 0.1,
    'p_iter_max': 5,
    'warmup_iter': 20, # 20, # 0 for non-warmup start cases
    'corrEps': 1e-4, # float type: correction procedure tolerance
}

# Models
contingency_models = []

for case in range(len(acopf_contingencies)):
    node_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus, 2))
    node_mask_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus))
    for s in range(node_feat_x.shape[0]):
        node_feat_x[s,:,0] = np.real(demand[s,:])
        node_feat_x[s,:,1] = np.imag(demand[s,:])
        node_mask_x[s,acopf_contingencies[case].spv] = 1
        # node_mask_x[s,self.pv] = 1
    
    edge_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nl, 6))
    for s in range(edge_feat_x.shape[0]):
        edge_feat_x[s,:,0] = acopf_contingencies[case].ppc['branch'][:, idx_brch.F_BUS]
        edge_feat_x[s,:,1] = acopf_contingencies[case].ppc['branch'][:, idx_brch.T_BUS]
        edge_feat_x[s,:,2] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_R]
        edge_feat_x[s,:,3] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_X]
        edge_feat_x[s,:,4] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_B]
        
        br_ratea_feat = (acopf_contingencies[case].ppc['branch'][:, idx_brch.RATE_A] / acopf_contingencies[case].baseMVA)
        # br_ratea_feat[br_ratea_feat == 0] = np.Inf
        edge_feat_x[s,:,5] = br_ratea_feat

    node_feat_x = torch.tensor(node_feat_x[:,:,:], dtype=torch.get_default_dtype())
    node_mask_x = torch.tensor(node_mask_x[:,:], dtype=torch.get_default_dtype())
    edge_feat_x = torch.tensor(edge_feat_x[:,:,:], dtype=torch.get_default_dtype())
    pyg_data_list = []
    for i in range(demand.shape[0]):
        pyg_data_list += [Data(
            x=node_feat_x[i,:,:],
            node_mask=node_mask_x[i,:].to(torch.bool),
            edge_index=edge_feat_x[i, :, 0:2].T.to(torch.long),
            edge_attr=edge_feat_x[i, :, 2:],) # R,X,B,RateA
            ]
    
    graph_dataset_contingency += [pyg_data_list]
    
    node_dataset = torch.zeros((acopf_contingencies[case].nbus*len(pyg_data_list),2))
    edge_dataset = torch.zeros((acopf_contingencies[case].nl*len(pyg_data_list),4))
    for (i,data) in enumerate(pyg_data_list):
        node_dataset[acopf_contingencies[case].nbus*i:acopf_contingencies[case].nbus*(i+1),:] = data.x
        edge_dataset[acopf_contingencies[case].nl*i:acopf_contingencies[case].nl*(i+1),:] = data.edge_attr
    
    node_means = node_dataset.mean(axis=0, keepdims = True)
    node_stds = node_dataset.std(axis=0, keepdims = True)
    edge_means = edge_dataset.mean(axis=0, keepdims = True)
    edge_stds = edge_dataset.std(axis=0, keepdims = True)

    graph_dataset_contingency_statics += [[node_means.to(dtype=torch.get_default_dtype()),
                                          node_stds.to(dtype=torch.get_default_dtype()),
                                          edge_means.to(dtype=torch.get_default_dtype()),
                                          edge_stds.to(dtype=torch.get_default_dtype())]]

    data_loader = torch_geometric.loader.DataLoader(pyg_data_list, batch_size=1, shuffle=False, drop_last=True)
    solver_net = Edge_GNNSolver(acopf_contingencies[case], train_config)
    contingency_models += [solver_net]

    print(solver_net)
# Out:
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=6480, out_features=107, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=6480, out_features=107, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# /tmp/ipykernel_65276/257001075.py:58: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,0] = np.real(demand[s,:])
# /tmp/ipykernel_65276/257001075.py:59: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,1] = np.imag(demand[s,:])

# %% [markdown]
# * Load pretrained GraphOPF model

# %%
pretrained_client = torch.load("./models/pretrained_models/client/checkpoint_Client6.pth", weights_only=False, map_location=device)
# pretrained_server = torch.load("./models/pretrained_models/server/checkpoint_Server_3.pth", weights_only=False, map_location=device)
# pretrained_global = torch.load("./models/pretrained_models/global/checkpoint_Global.pth", weights_only=False, map_location=device)

# %%
for contingency_model in contingency_models:
    if component == 'gen':
        print("Generator contingency")
        # Dimension reduction for N-1 contingency
        new_row = contingency_model.flatten.weight.shape[0] 
        new_col = contingency_model.flatten.weight.shape[1]
        old_row = pretrained_client['flatten.weight'].shape[0]
        old_col = pretrained_client['flatten.weight'].shape[1]
    
        pretrained_flatten_weight = copy.deepcopy(pretrained_client['flatten.weight'])
        pretrained_flatten_bias = copy.deepcopy(pretrained_client['flatten.bias'])
        
        # Way 1
        row_norm = torch.norm(pretrained_flatten_weight, dim=1)
        rows_removed = torch.argsort(row_norm)[:old_row - new_row]
        col_norm = torch.norm(pretrained_flatten_weight, dim=0)
        cols_removed = torch.argsort(col_norm)[:old_col - new_col]
        
        row_mask = torch.ones(pretrained_flatten_weight.size(0), dtype=torch.bool, device=device)
        row_mask[rows_removed] = False
        col_mask = torch.ones(pretrained_flatten_weight.size(1), dtype=torch.bool, device=device)
        col_mask[cols_removed] = False

        shrinked_weight = pretrained_flatten_weight[row_mask][:, col_mask]
        shrinked_bias = pretrained_flatten_bias[row_mask] # corresponding to the flatten.weight

        # # Way 2
        # shrinked_weight = pretrained_flatten_weight[(old_row - new_row):, (old_col - new_col):]
        # shrinked_bias = pretrained_flatten_bias[(old_row - new_row):] # corresponding to the flatten.weight

        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()
        
        layer_names = list(target_state_dict.keys())
        for name in layer_names[:-2]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()
            
        for name in layer_names[-2:]:
            if 'weight' in name:
                # print('weight load')
                target_state_dict[name] = shrinked_weight
            elif 'bias' in name:
                # print('bias load')
                target_state_dict[name] = shrinked_bias
    
    elif component == 'branch':
        print("Branch contingency")
        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()

        layer_names = list(target_state_dict.keys())
        for name in layer_names[:]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()

    contingency_model.load_state_dict(target_state_dict)

    # Freezing the half-GNN layers
    for i, (name, param) in enumerate(contingency_model.named_parameters()):
        if i <= 32: # 5, 10, 21
            # print(name)
            param.requires_grad = False
        else:
            print(name)
            param.requires_grad = True
# Out:
# Branch contingency
# flatten.weight
# flatten.bias
# Branch contingency
# flatten.weight
# flatten.bias

# %%
# for contingency_model in contingency_models:
#     if component == 'gen':
#         print("Generator contingency")
#         # Dimension reduction for N-1 contingency
#         new_row = contingency_model.flatten.weight.shape[0] 
#         new_col = contingency_model.flatten.weight.shape[1]
#         old_row = pretrained_client['flatten.weight'].shape[0]
#         old_col = pretrained_client['flatten.weight'].shape[1]
    
#         pretrained_flatten_weight = copy.deepcopy(pretrained_client['flatten.weight'])
#         pretrained_flatten_bias = copy.deepcopy(pretrained_client['flatten.bias'])
        
#         # Way 1
#         row_norm = torch.norm(pretrained_flatten_weight, dim=1)
#         rows_removed = torch.argsort(row_norm)[:old_row - new_row]
#         col_norm = torch.norm(pretrained_flatten_weight, dim=0)
#         cols_removed = torch.argsort(col_norm)[:old_col - new_col]
        
#         row_mask = torch.ones(pretrained_flatten_weight.size(0), dtype=torch.bool, device=device)
#         row_mask[rows_removed] = False
#         col_mask = torch.ones(pretrained_flatten_weight.size(1), dtype=torch.bool, device=device)
#         col_mask[cols_removed] = False

#         shrinked_weight = pretrained_flatten_weight[row_mask][:, col_mask]
#         shrinked_bias = pretrained_flatten_bias[row_mask] # corresponding to the flatten.weight

#         # # Way 2
#         # shrinked_weight = pretrained_flatten_weight[(old_row - new_row):, (old_col - new_col):]
#         # shrinked_bias = pretrained_flatten_bias[(old_row - new_row):] # corresponding to the flatten.weight

#         ### Transfer the weights from the pretrained GraphOPF
#         global_pretrained_state_dict = pretrained_client
#         target_state_dict = contingency_model.state_dict()
        
#         layer_names = list(target_state_dict.keys())
#         for name in layer_names[:-2]:
#             if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
#                 # print(name)
#                 target_state_dict[name] = global_pretrained_state_dict[name].clone()
            
#         for name in layer_names[-2:]:
#             if 'weight' in name:
#                 # print('weight load')
#                 target_state_dict[name] = shrinked_weight
#             elif 'bias' in name:
#                 # print('bias load')
#                 target_state_dict[name] = shrinked_bias
    
#     elif component == 'branch':
#         print("Branch contingency")
#         ### Transfer the weights from the pretrained GraphOPF
#         global_pretrained_state_dict = pretrained_client
#         target_state_dict = contingency_model.state_dict()

#         layer_names = list(target_state_dict.keys())
#         for name in layer_names[:]:
#             if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
#                 # print(name)
#                 target_state_dict[name] = global_pretrained_state_dict[name].clone()

#     contingency_model.load_state_dict(target_state_dict)

#     # # Freezing the half-GNN layers
#     # for i, (name, param) in enumerate(contingency_model.named_parameters()):
#     #     if i <= 32: # 5, 10, 21
#     #         # print(name)
#     #         param.requires_grad = False
#     #     else:
#     #         print(name)
#     #         param.requires_grad = True

# %% [markdown]
# * Fine-tuning (for generator contingency)

# %%
import torch.optim as optim
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

# Set the linear algebra solver(?)
torch._C._set_linalg_preferred_backend(torch._C._LinalgBackend.Cusolver) # torch._C._LinalgBackend.Magma, torch._C._LinalgBackend.Cusolver
# torch._C._get_linalg_preferred_backend() 

# stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    stats = {}
    
    # NOTE: LDF parameters.
    LagM_sp_gen = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_gen = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_bus = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    warmup_iter = train_config["warmup_iter"] # the warmup period: the NN is trained with an additional inner iteration before the first outer iteration.
    rho_init = train_config["rho_init"]
    
    rho = rho_init
    
    rho_iter = 0
    s_iter = 0
    
    p_iter_max = train_config["p_iter_max"]
    p_iter_max_sum = p_iter_max
    
    d = 0 # 0 for static case otherwise use 5"
    beta = 0 # 0.001 # 0 for static case otherwise use 1
    
    lr_w = train_config["lr_w"] # 이거 증가해도 되지 않을지?
    lr = train_config["lr"]
    print_interval = 1
    eps_converge = 1e-4
    
    contingency_models[case] = contingency_models[case].to(device)
    train_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][:20], batch_size=train_config['batchSize'], shuffle=True, drop_last=True)
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    train_loss_list = []
    train_start_time = time.time()
    for i in range(train_config["epochs"]):
        epoch_stats = {}
        ################### TRAINING PHASE ###################
        solver_net.train()
        if i<warmup_iter:
            ######### WARM-UP PERIOD #########
            if i == 0:
                solver_opt = optim.Adam(contingency_models[case].parameters(), lr=lr_w) # this will be reinitalized after warmup stage
                print("Warmup start!")
    
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                # start_time = time.time()
                solver_opt.zero_grad()
    
                # DNN + NR (equality constraint)
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, train_obj, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        else:
            if i == warmup_iter:
                print("Warmup ended!")
                # data.ref_freedom = False
    
                # ineq_lag_flag = True # for the first warmup end epoch, consider lag. multipliers update of ineq.
            # elif (i - warmup_iter)%ineq_lag_flag_trigger == 0:
            #     # print("Doing test... continue this case..")
            #     print("consider lagrangian multipliers update for ineq. constraints!")
            #     ineq_lag_flag = True
            # else:
            #     ineq_lag_flag = False
    
            # for every (updated) p_iter_max_sum time.
            if (i - warmup_iter)%p_iter_max_sum == 0:
                ######### Outer Interation: calculate step size of lagrangian multipliers update #########
                if i> warmup_iter:
                    print("current epoch %d || p_iter_max updated : %d -> %d" %(i, p_iter_max, p_iter_max + d))
                    # s = s_init * (1/(1+beta*(s_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    # s_iter += 1
                    # print("mu iter updated : %d -> %d" %(s_iter-1, s_iter))
    
                    rho = rho_init * (1/(1+beta*(rho_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    rho_iter += 1
                    print("rho iter updated : %d -> %d" %(rho_iter-1, rho_iter))
                    p_iter_max = p_iter_max + d
                    p_iter_max_sum += p_iter_max
    
                with torch.no_grad():
                    print("Lambda updated at %d epoch" %i)
                    contingency_models[case].eval()
                    for Xtrain in train_loader:
                        Xtrain = Xtrain.to(device)
                        #solver_opt.zero_grad()
                        Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                        # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                        # LagM += rho*ineq_violation(data, Xtrain.x, Yhat_train) # Update the lagrangian multiplier.
                        LagM_sp_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[:2] # Update the lagrangian multiplier.
                        LagM_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2:2+2*acopf_contingencies[case].ng] # Update the lagrangian multiplier.
                        LagM_bus += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus] # Update the lagrangian multiplier.
                        LagM_line += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:] # Update the lagrangian multiplier.
                
                ## Does this stablize the learning process much better?
                LagM_sp_gen = (LagM_sp_gen/len(train_loader))
                LagM_gen = (LagM_gen/len(train_loader))
                LagM_bus = (LagM_bus/len(train_loader))
                LagM_line = (LagM_line/len(train_loader))
    
                # solver_opt = optim.Adam(contingency_models[0].parameters(), lr = lr)
    
            contingency_models[case].train()
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                solver_opt.zero_grad()
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, obj_train, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        if (i == 0) or (i%print_interval == 0):
            print(
                'Epoch {}: train loss {:.4f}, train obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq p_g num viol {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, ineq line_theraml num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}'.format(
                    i, np.mean(epoch_stats['train_loss']), np.mean(epoch_stats['train_obj']), np.mean(epoch_stats['train_ineq_max']), np.mean(epoch_stats['train_ineq_mean']),
                    np.mean(epoch_stats['train_ineq_p_g_num_viol_0']), np.mean(epoch_stats['train_ineq_q_g_num_viol_0']), np.mean(epoch_stats['train_ineq_v_m_num_viol_0']), np.mean(epoch_stats['train_ineq_line_thermal_num_viol_0']),
                    np.mean(epoch_stats['train_eq_max']), np.mean(epoch_stats['train_eq_mean'])))
        
        train_loss_list.append(np.mean(epoch_stats['train_loss']))
        # valid_eval_list.append(np.mean(epoch_stats['valid_eval']))
    # stats_contingency += []
    print("\n")
train_end_time = time.time()
total_train_time = train_end_time - train_start_time
# Out:
# Contingency  0
# Warmup start!
# Epoch 0: train loss 36.5518, train obj 10.4240, ineq max 5.4180, ineq mean 0.0365, ineq p_g num viol 1.0000, ineq q_g num viol 12.7000, ineq v_m num viol 0.0000, ineq line_theraml num viol 10.6000, eq max 0.0000, eq mean 0.0000
# Epoch 1: train loss 17.6056, train obj 10.2758, ineq max 1.6151, ineq mean 0.0102, ineq p_g num viol 0.9500, ineq q_g num viol 8.9000, ineq v_m num viol 0.0000, ineq line_theraml num viol 8.3000, eq max 0.0000, eq mean 0.0000
# Epoch 2: train loss 11.8548, train obj 10.1928, ineq max 0.6029, ineq mean 0.0023, ineq p_g num viol 0.3500, ineq q_g num viol 6.7500, ineq v_m num viol 0.0000, ineq line_theraml num viol 3.9500, eq max 0.0000, eq mean 0.0000
# Epoch 3: train loss 11.0763, train obj 10.1521, ineq max 0.5770, ineq mean 0.0013, ineq p_g num viol 0.0000, ineq q_g num viol 3.9000, ineq v_m num viol 0.0000, ineq line_theraml num viol 2.0000, eq max 0.0000, eq mean 0.0000
# Epoch 4: train loss 10.8227, train obj 10.1323, ineq max 0.5379, ineq mean 0.0010, ineq p_g num viol 0.0000, ineq q_g num viol 4.7000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.8000, eq max 0.0000, eq mean 0.0000
# Epoch 5: train loss 10.6464, train obj 10.1175, ineq max 0.4638, ineq mean 0.0007, ineq p_g num viol 0.0000, ineq q_g num viol 3.3500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.3000, eq max 0.0000, eq mean 0.0000
# Epoch 6: train loss 10.5081, train obj 10.1141, ineq max 0.3426, ineq mean 0.0006, ineq p_g num viol 0.0000, ineq q_g num viol 2.7000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.1500, eq max 0.0000, eq mean 0.0000
# Epoch 7: train loss 10.4107, train obj 10.1086, ineq max 0.2057, ineq mean 0.0004, ineq p_g num viol 0.0000, ineq q_g num viol 3.5000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 8: train loss 10.1981, train obj 10.1042, ineq max 0.0647, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 2.4500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 9: train loss 10.1607, train obj 10.1024, ineq max 0.0383, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 2.4000, ineq v_m num viol 0.5500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 10: train loss 10.1381, train obj 10.1005, ineq max 0.0303, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 1.8500, ineq v_m num viol 0.9500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 11: train loss 10.1073, train obj 10.0978, ineq max 0.0081, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.6500, ineq v_m num viol 0.9500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 12: train loss 10.1040, train obj 10.0946, ineq max 0.0092, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.4000, ineq v_m num viol 1.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 13: train loss 10.0966, train obj 10.0931, ineq max 0.0035, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.3000, ineq v_m num viol 0.2000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 14: train loss 10.1005, train obj 10.0899, ineq max 0.0096, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.5500, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 15: train loss 10.0905, train obj 10.0877, ineq max 0.0028, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.2500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 16: train loss 10.0852, train obj 10.0850, ineq max 0.0002, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.1500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 17: train loss 10.0843, train obj 10.0824, ineq max 0.0019, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.1000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 18: train loss 10.0808, train obj 10.0795, ineq max 0.0012, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.1000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 19: train loss 10.0775, train obj 10.0769, ineq max 0.0006, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.0500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
#
#
# Contingency  1
# Warmup start!
# Epoch 0: train loss 26.8532, train obj 10.3170, ineq max 3.1567, ineq mean 0.0231, ineq p_g num viol 1.0000, ineq q_g num viol 16.4500, ineq v_m num viol 0.0000, ineq line_theraml num viol 8.0000, eq max 0.0000, eq mean 0.0000
# Epoch 1: train loss 14.0458, train obj 10.1945, ineq max 0.7797, ineq mean 0.0054, ineq p_g num viol 0.3500, ineq q_g num viol 11.4500, ineq v_m num viol 0.0000, ineq line_theraml num viol 4.4500, eq max 0.0000, eq mean 0.0000
# Epoch 2: train loss 11.3639, train obj 10.1331, ineq max 0.5874, ineq mean 0.0017, ineq p_g num viol 0.0000, ineq q_g num viol 7.5500, ineq v_m num viol 0.0000, ineq line_theraml num viol 1.7500, eq max 0.0000, eq mean 0.0000
# Epoch 3: train loss 11.0749, train obj 10.1062, ineq max 0.5624, ineq mean 0.0014, ineq p_g num viol 0.0000, ineq q_g num viol 5.9000, ineq v_m num viol 0.0000, ineq line_theraml num viol 1.6500, eq max 0.0000, eq mean 0.0000
# Epoch 4: train loss 10.8495, train obj 10.0871, ineq max 0.5378, ineq mean 0.0011, ineq p_g num viol 0.0000, ineq q_g num viol 5.1500, ineq v_m num viol 0.0000, ineq line_theraml num viol 1.4000, eq max 0.0000, eq mean 0.0000
# Epoch 5: train loss 10.6339, train obj 10.0738, ineq max 0.4782, ineq mean 0.0008, ineq p_g num viol 0.0000, ineq q_g num viol 3.4500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.5500, eq max 0.0000, eq mean 0.0000
# Epoch 6: train loss 10.4638, train obj 10.0619, ineq max 0.3682, ineq mean 0.0006, ineq p_g num viol 0.0000, ineq q_g num viol 3.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 7: train loss 10.3182, train obj 10.0532, ineq max 0.2051, ineq mean 0.0004, ineq p_g num viol 0.0000, ineq q_g num viol 3.1000, ineq v_m num viol 0.2000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 8: train loss 10.1486, train obj 10.0467, ineq max 0.0588, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 2.5000, ineq v_m num viol 0.6500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 9: train loss 10.1080, train obj 10.0407, ineq max 0.0647, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 1.6000, ineq v_m num viol 0.4000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 10: train loss 10.0977, train obj 10.0359, ineq max 0.0478, ineq mean 0.0001, ineq p_g num viol 0.0000, ineq q_g num viol 1.9500, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 11: train loss 10.0416, train obj 10.0297, ineq max 0.0104, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.8500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 12: train loss 10.0438, train obj 10.0262, ineq max 0.0173, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.6000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0500, eq max 0.0000, eq mean 0.0000
# Epoch 13: train loss 10.0369, train obj 10.0222, ineq max 0.0111, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.8500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.1000, eq max 0.0000, eq mean 0.0000
# Epoch 14: train loss 10.0514, train obj 10.0185, ineq max 0.0308, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.8500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.1000, eq max 0.0000, eq mean 0.0000
# Epoch 15: train loss 10.0346, train obj 10.0139, ineq max 0.0164, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.6000, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.1500, eq max 0.0000, eq mean 0.0000
# Epoch 16: train loss 10.0269, train obj 10.0113, ineq max 0.0149, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.5000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.2000, eq max 0.0000, eq mean 0.0000
# Epoch 17: train loss 10.0356, train obj 10.0095, ineq max 0.0208, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.8000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.2000, eq max 0.0000, eq mean 0.0000
# Epoch 18: train loss 10.0400, train obj 10.0055, ineq max 0.0327, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.6000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.2000, eq max 0.0000, eq mean 0.0000
# Epoch 19: train loss 10.0249, train obj 10.0021, ineq max 0.0203, ineq mean 0.0000, ineq p_g num viol 0.0000, ineq q_g num viol 0.6000, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.2000, eq max 0.0000, eq mean 0.0000

# %%
total_train_time
# Out:
# 2.1792099475860596

# %% [markdown]
# * Evaluation (zero-shot)

# %%
from pypower.api import makeYbus
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

test_stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    Ybus, Yf, Yt = makeYbus(acopf_contingencies[case].baseMVA, acopf_contingencies[case].ppc['bus'], acopf_contingencies[case].ppc['branch'])
    # branch thermal limit information
    flow_max = (acopf_contingencies[case].ppc['branch'][:, 5] / acopf_contingencies[case].baseMVA)**2
    flow_max[flow_max == 0] = np.inf
    flow_max = torch.tensor(flow_max, dtype=torch.float32).to(device)
    
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    test_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][100:], batch_size=1, shuffle=False, drop_last=True)
    contingency_models[case] = contingency_models[case].to(device)
    contingency_models[case].eval()
    test_stats = {}
    # test_stats["Contingency"] = case
    test_eps_converge = 1e-4
    
    LagM_sp_g = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_q_g = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_v_m = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line_l = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    solve_time = []
    for (i, Xtest) in enumerate(test_loader):
        Xtest = Xtest.to(device)
    
        start_time = time.time()
        Y = contingency_models[case](Xtest, n_means, n_stds, e_means, e_stds)
        end_time = time.time()
    
        solve_time += [end_time - start_time]
    
        ## line thermal limit
        pg, qg, vm, va = acopf_contingencies[case].get_yvars(Y)
        vr = vm*torch.cos(va)
        vi = vm*torch.sin(va)
        vz = torch.complex(vr, vi) # complex voltage
    
        # calculate the branch current of from bus and to bus based on the Yf*V and Yt*V
        If = torch.tensor(Yf.todense(), dtype=torch.complex64).to(device) @ vz.T
        It = torch.tensor(Yt.todense(), dtype=torch.complex64).to(device) @ vz.T
    
        # Calculate the apparent power S
        Sf = vz[:,acopf_contingencies[case].ppc['branch'][:,0].astype(int)] * torch.conj(If.T)
        St = vz[:,acopf_contingencies[case].ppc['branch'][:,1].astype(int)] * torch.conj(It.T)
        Sff = Sf * torch.conj(Sf)
        Stt = St * torch.conj(St)
    
        # calculate the line thermal limit constraints violation
        diff_Sf = Sff.real - flow_max
        diff_St = Stt.real - flow_max
        # diff_Sf[torch.clamp(diff_Sf, 0) != 0]
    
        line_limit_vio_Sf = torch.clamp(diff_Sf, 0)
        line_limit_vio_St = torch.clamp(diff_St, 0)
        ###########################################
    
        # test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(data, Xtest.x, Y, LagM)
        test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(acopf_contingencies[case], Xtest.x, Y, LagM_sp_g, LagM_q_g, LagM_v_m, LagM_line_l) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
    
        dict_agg(test_stats, 'time', end_time - start_time, op='sum')
    
        test_ineq_p_g = torch.cat([pg - acopf_contingencies[case].pmax, acopf_contingencies[case].pmin - pg], dim=1)
        test_ineq_p_g = torch.clamp(test_ineq_p_g, 0).to(device)
        test_ineq_q_g = test_ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
        test_ineq_v_m = test_ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
        test_ineq_line_l = test_ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
        dict_agg(test_stats, 'test_loss', test_loss.detach().cpu().numpy())
        # dict_agg(test_stats, 'test_loss', (test_loss[0]+test_loss[1]+test_loss[2]+test_loss[3]).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_obj_cost', test_obj_cost.detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_max', torch.max(test_ineq_dist, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_mean', torch.mean(test_ineq_dist, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_max', torch.max(test_ineq_p_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_mean', torch.mean(test_ineq_p_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_max', torch.max(test_ineq_q_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_mean', torch.mean(test_ineq_q_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_max', torch.max(test_ineq_v_m, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_mean', torch.mean(test_ineq_v_m, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_max', torch.max(test_ineq_line_l, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_mean', torch.mean(test_ineq_line_l, dim=1).detach().cpu().numpy())
    
        pg_rate_torch = (((pg <= acopf_contingencies[case].pmax) & (pg >= acopf_contingencies[case].pmin)).sum()/acopf_contingencies[case].ng)*100
        qg_rate_torch = (((qg <= acopf_contingencies[case].qmax) & (qg >= acopf_contingencies[case].qmin)).sum()/acopf_contingencies[case].ng)*100
        dict_agg(test_stats, 'test_p_g_satisfication rate (%)', pg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_q_g_satisfication rate (%)', qg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_p_g_satisfication rate (%)', ((torch.sum(test_ineq_p_g == 0, dim=1)/test_ineq_p_g.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_q_g_satisfication rate (%)', ((torch.sum(test_ineq_q_g == 0, dim=1)/test_ineq_q_g.shape[1])*100).detach().cpu().numpy())
    
        v_rate_torch = (((vm <= acopf_contingencies[case].vmax) & (vm >= acopf_contingencies[case].vmin)).sum()/acopf_contingencies[case].nbus)*100
        dict_agg(test_stats, 'test_v_m_satisfication rate (%)', v_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_v_m_satisfication rate (%)', ((torch.sum(test_ineq_v_m == 0, dim=1)/test_ineq_v_m.shape[1])*100).detach().cpu().numpy())
    
        sff_rate_torch = ((Sff.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        stt_rate_torch = ((Stt.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', sff_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', stt_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate (%)', ((torch.sum(test_ineq_line_l == 0, dim=1)/test_ineq_line_l.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', ((torch.sum(line_limit_vio_Sf == 0, dim=1)/line_limit_vio_Sf.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', ((torch.sum(line_limit_vio_St == 0, dim=1)/line_limit_vio_St.shape[1])*100).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_q_g_num_viol_0', torch.sum(test_ineq_q_g > test_eps_converge, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_num_viol_0', torch.sum(test_ineq_v_m > test_eps_converge, dim=1).detach().cpu().numpy())
    
        test_eq_real = test_eq_resid[:,:acopf_contingencies[case].nbus]
        test_eq_react = test_eq_resid[:,acopf_contingencies[case].nbus:]
        dict_agg(test_stats, 'test_eq_max', torch.max(torch.abs(test_eq_resid), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_mean', torch.mean(torch.abs(test_eq_resid), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_max', torch.max(torch.abs(test_eq_real), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_mean', torch.mean(torch.abs(test_eq_real), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_max', torch.max(torch.abs(test_eq_react), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_mean', torch.mean(torch.abs(test_eq_react), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_active_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,:acopf_contingencies[case].nbus] <= 1e-2) & (test_eq_resid[:,:acopf_contingencies[case].nbus] >= -1e-2)  , dim=1)/test_eq_resid[:,:acopf_contingencies[case].nbus].shape[1]*100).detach().cpu().numpy())
        dict_agg(test_stats, 'test_reactive_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,acopf_contingencies[case].nbus:] <= 1e-2) & (test_eq_resid[:,acopf_contingencies[case].nbus:] >= -1e-2)  , dim=1)/test_eq_resid[:,acopf_contingencies[case].nbus:].shape[1]*100).detach().cpu().numpy())

        print('Test batch {}: test loss {:.4f}, test obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}, p_g satisfication rate {:.4f}, q_g satisfication rate {:.4f}, v_m satisfication rate {:.4f}, test_line_limit_satisfication_rate {:.4f}, test_line_limit_satisfication_rate_Sf {:.4f}, test_line_limit_satisfication_rate_St {:.4f}, active eq satisfication rate {:.4f}, reactive eq satisfication rate {:.4f}'.format(
                    i, np.mean(test_stats['test_loss']), np.mean(test_stats['test_obj_cost']), np.mean(test_stats['test_ineq_max']), np.mean(test_stats['test_ineq_mean']),
                    np.mean(test_stats['test_ineq_q_g_num_viol_0']), np.mean(test_stats['test_ineq_v_m_num_viol_0']),
                    np.mean(test_stats['test_eq_max']), np.mean(test_stats['test_eq_mean']), np.mean(test_stats['test_p_g_satisfication rate (%)']), np.mean(test_stats['test_q_g_satisfication rate (%)']), np.mean(test_stats['test_v_m_satisfication rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']), np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']), np.mean(test_stats['test_active_eq_satisfication rate (%)']), np.mean(test_stats['test_reactive_eq_satisfication rate (%)'])))

    test_stats_contingency += [test_stats]
    print("\n")
# Out:
# Contingency  0
# Test batch 0: test loss 9.9185, test obj 9.9174, ineq max 0.0012, ineq mean 0.0000, ineq q_g num viol 1.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 98.1481, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 1: test loss 9.7783, test obj 9.7777, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.5000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.0741, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 2: test loss 9.7617, test obj 9.7613, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.3333, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.3827, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 3: test loss 9.7481, test obj 9.7478, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.2500, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.5370, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 4: test loss 9.7269, test obj 9.7267, ineq max 0.0002, ineq mean 0.0000, ineq q_g num viol 0.2000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.6296, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 5: test loss 9.7317, test obj 9.7315, ineq max 0.0002, ineq mean 0.0000, ineq q_g num viol 0.1667, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.6914, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 6: test loss 9.7291, test obj 9.7289, ineq max 0.0002, ineq mean 0.0000, ineq q_g num viol 0.1429, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7355, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 7: test loss 9.7377, test obj 9.7376, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.1250, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7685, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 8: test loss 9.7467, test obj 9.7465, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.1111, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7942, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 9: test loss 9.7574, test obj 9.7573, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.1000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8148, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 10: test loss 9.7498, test obj 9.7497, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0909, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8317, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 11: test loss 9.7552, test obj 9.7551, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0833, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8457, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 12: test loss 9.7512, test obj 9.7511, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0769, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8576, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 13: test loss 9.7521, test obj 9.7520, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0714, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8677, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 14: test loss 9.7639, test obj 9.7638, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0667, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8765, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 15: test loss 9.7706, test obj 9.7700, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.1250, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7685, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 16: test loss 9.7720, test obj 9.7711, ineq max 0.0008, ineq mean 0.0000, ineq q_g num viol 0.1765, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.6732, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 17: test loss 9.7695, test obj 9.7687, ineq max 0.0008, ineq mean 0.0000, ineq q_g num viol 0.1667, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.6914, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 18: test loss 9.7676, test obj 9.7668, ineq max 0.0008, ineq mean 0.0000, ineq q_g num viol 0.1579, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7076, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 19: test loss 9.7669, test obj 9.7662, ineq max 0.0007, ineq mean 0.0000, ineq q_g num viol 0.1500, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7222, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 20: test loss 9.7656, test obj 9.7649, ineq max 0.0007, ineq mean 0.0000, ineq q_g num viol 0.1429, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7354, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 21: test loss 9.7623, test obj 9.7616, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.1364, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7475, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 22: test loss 9.7579, test obj 9.7573, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.1304, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7584, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 23: test loss 9.7600, test obj 9.7594, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.1250, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7685, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 24: test loss 9.7632, test obj 9.7626, ineq max 0.0006, ineq mean 0.0000, ineq q_g num viol 0.1200, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7778, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 25: test loss 9.7632, test obj 9.7627, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.1154, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7863, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 26: test loss 9.7580, test obj 9.7574, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.1111, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.7942, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 27: test loss 9.7521, test obj 9.7516, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.1071, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8016, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 28: test loss 9.7543, test obj 9.7538, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.1034, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8084, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 29: test loss 9.7530, test obj 9.7525, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.1000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8148, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 30: test loss 9.7568, test obj 9.7564, ineq max 0.0005, ineq mean 0.0000, ineq q_g num viol 0.0968, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8208, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 31: test loss 9.7540, test obj 9.7535, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0938, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8264, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 32: test loss 9.7534, test obj 9.7530, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0909, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8316, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 33: test loss 9.7540, test obj 9.7536, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0882, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8366, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 34: test loss 9.7577, test obj 9.7573, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0857, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8413, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 35: test loss 9.7570, test obj 9.7566, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0833, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8457, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 36: test loss 9.7542, test obj 9.7538, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0811, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8498, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 37: test loss 9.7525, test obj 9.7521, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0789, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8538, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 38: test loss 9.7553, test obj 9.7550, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0769, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8575, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 39: test loss 9.7564, test obj 9.7560, ineq max 0.0004, ineq mean 0.0000, ineq q_g num viol 0.0750, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8611, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 40: test loss 9.7606, test obj 9.7602, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0732, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8645, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 41: test loss 9.7613, test obj 9.7609, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0714, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8677, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 42: test loss 9.7619, test obj 9.7616, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0698, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8708, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 43: test loss 9.7634, test obj 9.7630, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0682, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8737, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 44: test loss 9.7663, test obj 9.7660, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0667, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8765, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 45: test loss 9.7674, test obj 9.7670, ineq max 0.0003, ineq mean 0.0000, ineq q_g num viol 0.0652, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.8792, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch
ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9415, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 9.7547, test obj 9.7546, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0312, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9421, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 9.7547, test obj 9.7546, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0309, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9427, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 9.7555, test obj 9.7553, ineq max 0.0001, ineq mean 0.0000, ineq q_g num viol 0.0306, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9433, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# ...
# Test batch 67: test loss 9.8551, test obj 9.7712, ineq max 0.0730, ineq mean 0.0001, ineq q_g num viol 0.0441, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9183, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7416, test_line_limit_satisfication_rate_Sf 99.8808, test_line_limit_satisfication_rate_St 99.6026, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 68: test loss 9.8541, test obj 9.7686, ineq max 0.0743, ineq mean 0.0001, ineq q_g num viol 0.0435, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9195, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7376, test_line_limit_satisfication_rate_Sf 99.8747, test_line_limit_satisfication_rate_St 99.6005, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 9.8561, test obj 9.7669, ineq max 0.0767, ineq mean 0.0001, ineq q_g num viol 0.0429, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9206, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7336, test_line_limit_satisfication_rate_Sf 99.8687, test_line_limit_satisfication_rate_St 99.5985, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 9.8563, test obj 9.7668, ineq max 0.0772, ineq mean 0.0001, ineq q_g num viol 0.0423, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9218, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7335, test_line_limit_satisfication_rate_Sf 99.8706, test_line_limit_satisfication_rate_St 99.5965, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 9.8531, test obj 9.7648, ineq max 0.0761, ineq mean 0.0001, ineq q_g num viol 0.0417, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9228, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7372, test_line_limit_satisfication_rate_Sf 99.8724, test_line_limit_satisfication_rate_St 99.6021, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 9.8564, test obj 9.7646, ineq max 0.0784, ineq mean 0.0001, ineq q_g num viol 0.0411, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9239, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7334, test_line_limit_satisfication_rate_Sf 99.8667, test_line_limit_satisfication_rate_St 99.6002, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 9.8547, test obj 9.7641, ineq max 0.0773, ineq mean 0.0001, ineq q_g num viol 0.0405, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9249, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7370, test_line_limit_satisfication_rate_Sf 99.8685, test_line_limit_satisfication_rate_St 99.6056, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 9.8555, test obj 9.7654, ineq max 0.0771, ineq mean 0.0001, ineq q_g num viol 0.0400, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9259, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7369, test_line_limit_satisfication_rate_Sf 99.8703, test_line_limit_satisfication_rate_St 99.6036, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 9.8542, test obj 9.7653, ineq max 0.0761, ineq mean 0.0001, ineq q_g num viol 0.0395, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9269, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7404, test_line_limit_satisfication_rate_Sf 99.8720, test_line_limit_satisfication_rate_St 99.6088, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 9.8522, test obj 9.7639, ineq max 0.0756, ineq mean 0.0001, ineq q_g num viol 0.0390, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9278, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7403, test_line_limit_satisfication_rate_Sf 99.8736, test_line_limit_satisfication_rate_St 99.6069, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 9.8522, test obj 9.7651, ineq max 0.0746, ineq mean 0.0001, ineq q_g num viol 0.0385, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9288, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7436, test_line_limit_satisfication_rate_Sf 99.8753, test_line_limit_satisfication_rate_St 99.6119, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 9.8509, test obj 9.7649, ineq max 0.0736, ineq mean 0.0001, ineq q_g num viol 0.0380, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9297, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7468, test_line_limit_satisfication_rate_Sf 99.8768, test_line_limit_satisfication_rate_St 99.6168, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 9.8492, test obj 9.7640, ineq max 0.0730, ineq mean 0.0001, ineq q_g num viol 0.0375, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9306, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7466, test_line_limit_satisfication_rate_Sf 99.8784, test_line_limit_satisfication_rate_St 99.6149, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 9.8491, test obj 9.7631, ineq max 0.0738, ineq mean 0.0001, ineq q_g num viol 0.0370, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9314, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7431, test_line_limit_satisfication_rate_Sf 99.8732, test_line_limit_satisfication_rate_St 99.6130, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 9.8502, test obj 9.7622, ineq max 0.0753, ineq mean 0.0001, ineq q_g num viol 0.0366, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9323, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7396, test_line_limit_satisfication_rate_Sf 99.8682, test_line_limit_satisfication_rate_St 99.6111, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 9.8533, test obj 9.7639, ineq max 0.0763, ineq mean 0.0001, ineq q_g num viol 0.0361, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9331, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7362, test_line_limit_satisfication_rate_Sf 99.8632, test_line_limit_satisfication_rate_St 99.6093, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 9.8507, test obj 9.7624, ineq max 0.0754, ineq mean 0.0001, ineq q_g num viol 0.0357, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9339, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7394, test_line_limit_satisfication_rate_Sf 99.8649, test_line_limit_satisfication_rate_St 99.6139, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 9.8508, test obj 9.7628, ineq max 0.0753, ineq mean 0.0001, ineq q_g num viol 0.0353, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9346, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7393, test_line_limit_satisfication_rate_Sf 99.8665, test_line_limit_satisfication_rate_St 99.6121, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 9.8506, test obj 9.7614, ineq max 0.0763, ineq mean 0.0001, ineq q_g num viol 0.0349, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9354, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7360, test_line_limit_satisfication_rate_Sf 99.8617, test_line_limit_satisfication_rate_St 99.6103, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 9.8495, test obj 9.7601, ineq max 0.0767, ineq mean 0.0001, ineq q_g num viol 0.0345, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9361, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7359, test_line_limit_satisfication_rate_Sf 99.8633, test_line_limit_satisfication_rate_St 99.6086, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 9.8517, test obj 9.7605, ineq max 0.0779, ineq mean 0.0001, ineq q_g num viol 0.0341, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9369, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7328, test_line_limit_satisfication_rate_Sf 99.8587, test_line_limit_satisfication_rate_St 99.6069, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 9.8511, test obj 9.7610, ineq max 0.0770, ineq mean 0.0001, ineq q_g num viol 0.0337, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9376, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7358, test_line_limit_satisfication_rate_Sf 99.8603, test_line_limit_satisfication_rate_St 99.6113, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 9.8520, test obj 9.7599, ineq max 0.0784, ineq mean 0.0001, ineq q_g num viol 0.0333, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9383, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7327, test_line_limit_satisfication_rate_Sf 99.8559, test_line_limit_satisfication_rate_St 99.6096, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 9.8503, test obj 9.7585, ineq max 0.0782, ineq mean 0.0001, ineq q_g num viol 0.0330, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9390, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7327, test_line_limit_satisfication_rate_Sf 99.8574, test_line_limit_satisfication_rate_St 99.6080, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 9.8484, test obj 9.7572, ineq max 0.0778, ineq mean 0.0001, ineq q_g num viol 0.0326, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9396, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7327, test_line_limit_satisfication_rate_Sf 99.8590, test_line_limit_satisfication_rate_St 99.6063, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 9.8471, test obj 9.7569, ineq max 0.0769, ineq mean 0.0001, ineq q_g num viol 0.0323, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9403, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7355, test_line_limit_satisfication_rate_Sf 99.8605, test_line_limit_satisfication_rate_St 99.6106, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 9.8456, test obj 9.7563, ineq max 0.0761, ineq mean 0.0001, ineq q_g num viol 0.0319, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9409, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7355, test_line_limit_satisfication_rate_Sf 99.8620, test_line_limit_satisfication_rate_St 99.6090, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 9.8447, test obj 9.7564, ineq max 0.0753, ineq mean 0.0001, ineq q_g num viol 0.0316, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9415, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7383, test_line_limit_satisfication_rate_Sf 99.8634, test_line_limit_satisfication_rate_St 99.6131, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 9.8455, test obj 9.7567, ineq max 0.0759, ineq mean 0.0001, ineq q_g num viol 0.0312, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9421, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7354, test_line_limit_satisfication_rate_Sf 99.8592, test_line_limit_satisfication_rate_St 99.6115, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 9.8446, test obj 9.7567, ineq max 0.0751, ineq mean 0.0001, ineq q_g num viol 0.0309, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9427, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7381, test_line_limit_satisfication_rate_Sf 99.8607, test_line_limit_satisfication_rate_St 99.6155, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 9.8467, test obj 9.7574, ineq max 0.0762, ineq mean 0.0001, ineq q_g num viol 0.0306, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9433, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7353, test_line_limit_satisfication_rate_Sf 99.8566, test_line_limit_satisfication_rate_St 99.6139, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 98: test loss 9.8448, test obj 9.7564, ineq max 0.0754, ineq mean 0.0001, ineq q_g num viol 0.0303, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9439, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7379, test_line_limit_satisfication_rate_Sf 99.8580, test_line_limit_satisfication_rate_St 99.6178, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 99: test loss 9.8454, test obj 9.7573, ineq max 0.0752, ineq mean 0.0001, ineq q_g num viol 0.0300, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 99.9445, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.7378, test_line_limit_satisfication_rate_Sf 99.8595, test_line_limit_satisfication_rate_St 99.6162, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000

# %% [markdown]
# * Arithmetic mean

# %%
## Calculate the results of GraphLDE
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats_contingency[case]['test_obj_cost'])*10000, 4))
    print("GraphLDE eq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_mean']))
    print("GraphLDE eq. max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_max']))
    print("GraphLDE eq. active mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_mean']))
    print("GraphLDE eq. active max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_max']))
    print("GraphLDE eq. reactive mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_mean']))
    print("GraphLDE eq. reactive max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_max']))
    
    print("\n")
    print("GraphLDE ineq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_mean']))
    print("GraphLDE ineq. max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_max']))
    print("GraphLDE ineq. p_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_mean']))
    print("GraphLDE ineq. p_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_max']))
    print("GraphLDE ineq. q_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_mean']))
    print("GraphLDE ineq. q_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_max']))
    print("GraphLDE ineq. v_m mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_mean']))
    print("GraphLDE ineq. v_m max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_max']))
    print("GraphLDE ineq. line_l mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_mean']))
    print("GraphLDE ineq. line_l max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_max']))
    
    print("\n")
    print("GraphLDE p_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_p_g_satisfication rate (%)']))
    print("GraphLDE q_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_q_g_satisfication rate (%)']))
    print("GraphLDE v_m satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_v_m_satisfication rate (%)']))
    print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_Sf(%)']))
    print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_St(%)']))
    print("GraphLDE active eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_active_eq_satisfication rate (%)']))
    print("GraphLDE reactive eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_reactive_eq_satisfication rate (%)']))
    
    print("\n")
    # print("DeepLDE time (ms) <== average value for test dataset:", (test_stats['time']/1000)*1e3)
    print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
    print("\n")
# Out:
# Contingency  0
# GraphLDE obj. value for test samples:  97552.445
# GraphLDE eq. mean for test samples:  1.956532e-06
# GraphLDE eq. max for test samples:  3.8502538e-05
# GraphLDE eq. active mean for test samples:  1.6854203e-06
# GraphLDE eq. active max for test samples:  1.3961494e-05
# GraphLDE eq. reactive mean for test samples:  2.2276438e-06
# GraphLDE eq. reactive max for test samples:  3.842808e-05
#
#
# GraphLDE ineq. mean for test samples:  1.9958044e-07
# GraphLDE ineq. max for test samples:  0.0001428996
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  1.3231445e-06
# GraphLDE ineq. q_g max for test samples:  0.0001428996
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  100.0
# GraphLDE q_g satisfication rate for test samples:  99.94445
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  100.0
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 14.197514057159424
#
#
# Contingency  1
# GraphLDE obj. value for test samples:  97573.08
# GraphLDE eq. mean for test samples:  1.9852391e-06
# GraphLDE eq. max for test samples:  3.8304937e-05
# GraphLDE eq. active mean for test samples:  1.731433e-06
# GraphLDE eq. active max for test samples:  1.4054078e-05
# GraphLDE eq. reactive mean for test samples:  2.239046e-06
# GraphLDE eq. reactive max for test samples:  3.8279693e-05
#
#
# GraphLDE ineq. mean for test samples:  0.00012307851
# GraphLDE ineq. max for test samples:  0.0752383
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  1.514881e-06
# GraphLDE ineq. q_g max for test samples:  0.00016360715
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.00023773138
# GraphLDE ineq. line_l max for test samples:  0.07515375
#
#
# GraphLDE p_g satisfication rate for test samples:  100.0
# GraphLDE q_g satisfication rate for test samples:  99.94445
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.85945
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.61621
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 14.197514057159424

# %% [markdown]
# * Harmonic mean

# %%
import statistics as st

## Calculate optimality gap
print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats['test_obj_cost'])*10000, 4))
print("GraphLDE eq. mean for test samples: ", st.harmonic_mean(test_stats['test_eq_mean'])) # print("LDF eq. mean for test samples: ", np.mean(test_stats['test_eq_mean']))
print("GraphLDE eq. max for test samples: ", st.harmonic_mean(test_stats['test_eq_max'])) # print("LDF eq. max for test samples: ", np.mean(test_stats['test_eq_max']))
print("GraphLDE eq. active mean for test samples: ", st.harmonic_mean(test_stats['test_eq_real_mean'])) # print("LDF eq. active mean for test samples: ", np.mean(test_stats['test_eq_real_mean']))
print("GraphLDE eq. active max for test samples: ", st.harmonic_mean(test_stats['test_eq_real_max'])) # print("LDF eq. active max for test samples: ", np.mean(test_stats['test_eq_real_max']))
print("GraphLDE eq. reactive mean for test samples: ", st.harmonic_mean(test_stats['test_eq_react_mean'])) # print("LDF eq. reactive mean for test samples: ", np.mean(test_stats['test_eq_react_mean']))
print("GraphLDE eq. reactive max for test samples: ", st.harmonic_mean(test_stats['test_eq_react_max'])) # print("LDF eq. reactive max for test samples: ", np.mean(test_stats['test_eq_react_max']))
print("\n")
print("GraphLDE ineq. mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_mean'])) # print("LDF ineq. mean for test samples: ", np.mean(test_stats['test_ineq_mean']))
print("GraphLDE ineq. max for test samples: ", st.harmonic_mean(test_stats['test_ineq_max'])) # print("LDF ineq. max for test samples: ", np.mean(test_stats['test_ineq_max']))
print("GraphLDE ineq. p_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_mean'])) # print("LDF ineq. p_g mean for test samples: ", np.mean(test_stats['test_ineq_p_g_mean']))
print("GraphLDE ineq. p_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_max'])) # print("LDF ineq. p_g max for test samples: ", np.mean(test_stats['test_ineq_p_g_max']))
print("GraphLDE ineq. q_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_mean'])) # print("LDF ineq. q_g mean for test samples: ", np.mean(test_stats['test_ineq_q_g_mean']))
print("GraphLDE ineq. q_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_max'])) # print("LDF ineq. q_g max for test samples: ", np.mean(test_stats['test_ineq_q_g_max']))
print("GraphLDE ineq. v_m mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_mean'])) # print("LDF ineq. v_m mean for test samples: ", np.mean(test_stats['test_ineq_v_m_mean']))
print("GraphLDE ineq. v_m max for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_max'])) # print("LDF ineq. v_m max for test samples: ", np.mean(test_stats['test_ineq_v_m_max']))
print("GraphLDE ineq. line_l mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_mean'])) # print("LDF ineq. line_l mean for test samples: ", np.mean(test_stats['test_ineq_line_l_mean']))
print("GraphLDE ineq. line_l max for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_max'])) # print("LDF ineq. line_l max for test samples: ", np.mean(test_stats['test_ineq_line_l_max']))
print("\n")

print("GraphLDE p_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_p_g_satisfication rate (%)'].reshape(-1))) # print("LDF p_g satisfication rate for test samples: ", np.mean(test_stats['test_p_g_satisfication rate (%)']))
print("GraphLDE q_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_q_g_satisfication rate (%)'].reshape(-1))) # print("LDF q_g satisfication rate for test samples: ", np.mean(test_stats['test_q_g_satisfication rate (%)']))
print("GraphLDE v_m satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_v_m_satisfication rate (%)'].reshape(-1))) # print("LDF v_m satisfication rate for test samples: ", np.mean(test_stats['test_v_m_satisfication rate (%)']))
print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_Sf(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']))
print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_St(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']))
print("GraphLDE active eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_active_eq_satisfication rate (%)'].reshape(-1))) # print("LDF active eq satisfication rate for test samples: ", np.mean(test_stats['test_active_eq_satisfication rate (%)']))
print("GraphLDE reactive eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_reactive_eq_satisfication rate (%)'].reshape(-1))) # print("LDF reactive eq satisfication rate for test samples: ", np.mean(test_stats['test_reactive_eq_satisfication rate (%)']))

print("\n")
print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
# Out:
# GraphLDE obj. value for test samples:  1310930.4
# GraphLDE eq. mean for test samples:  3.5897927e-05
# GraphLDE eq. max for test samples:  0.0016717056
# GraphLDE eq. active mean for test samples:  2.8573166e-05
# GraphLDE eq. active max for test samples:  0.0009564006
# GraphLDE eq. reactive mean for test samples:  4.3002572e-05
# GraphLDE eq. reactive max for test samples:  0.0015979278
#
#
# GraphLDE ineq. mean for test samples:  0.00036288172
# GraphLDE ineq. max for test samples:  0.64950836
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  0.0039722873
# GraphLDE ineq. q_g max for test samples:  0.48839676
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  99.89972
# GraphLDE q_g satisfication rate for test samples:  92.89624
# GraphLDE v_m satisfication rate for test samples:  99.99926
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.987434
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.992966
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 53.45505237579346
# /pscratch/sd/k/kjsong/conda/pytorch/2.8.0/lib/python3.12/statistics.py:593: RuntimeWarning: divide by zero encountered in scalar divide
#   T, total, count = _sum(w / x if w else 0 for w, x in zip(weights, data))
