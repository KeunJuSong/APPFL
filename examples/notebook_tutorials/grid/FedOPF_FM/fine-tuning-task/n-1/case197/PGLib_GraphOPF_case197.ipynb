# %% [markdown]
# # N-1 Fine tuning task for FedOPF
#
# * Create N-1 contingencies: number & indicies of cut off lines and generators
#     * For the dataset, we only need to generate load because this is unsupervised way
# * Test on the zero-shot (i.e., just inference by using pretrained client/server/global model)
#     * For branch contingency, zero-shot is effective! (Done)
#     * **However, for generator contingency, fine-tuning must be needed**

# %%
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cu121.html

# !pip install pypower
# !pip install pyrlu
# # !pip install conflictfree

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
# os.environ["PYTORCH_LINALG_WARNINGS"] = "0"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0"
# os.environ["CUDA_VISIBLE_DEVICES"] = '0, 1, 2, 3'

import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Device:', device)  # 출력결과: cuda
print('Count of using GPUs:', torch.cuda.device_count())   #출력결과: 1 (GPU #2 한개 사용하므로)
print('Current cuda device:', torch.cuda.current_device())  # 출력결과: 2 (GPU #2 의미)
# Out:
# Device: cuda
# Count of using GPUs: 1
# Current cuda device: 0

# %%
from utils.utils197_graphlde import ACOPFProblem
grid_data_path = './data/pglib_opf_case197.mat'
grid = ACOPFProblem(grid_filename=grid_data_path)

# %%
component="gen" # "gen" or "branch"
num_cases = 10
contingencies = grid.check_contingencies(component=component, num_cases=num_cases)

contingencies['contingencies'] = [x for x in contingencies['contingencies'] if x]
acopf_contingencies = []
for c in range(contingencies['num_cases']):
    acopf_contingencies += [ACOPFProblem(grid_filename=grid_data_path, contingencies=contingencies['contingencies'][c], component=component)] # update the grid components' values from modified ppc data based on the contingencies 

    # Put all variables in "data" to the cuda.
    acopf_contingencies[-1]._device = device
    for attr in dir(acopf_contingencies[-1]):
        var = getattr(acopf_contingencies[-1], attr)
        if not callable(var) and not attr.startswith("__") and torch.is_tensor(var):
            try:
                setattr(acopf_contingencies[-1], attr, var.to(device))
            except AttributeError:
                pass
# Out:
# 11
# 210
#
# Converged in 0.82 seconds
# Objective Function Value = 109824.20 $/hr
# ================================================================================
# |     System Summary                                                           |
# ================================================================================
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses             89     Total Gen Capacity    9321.2       -1489.3 to 4245.9
# Generators        11     On-line Capacity      9321.2       -1489.3 to 4245.9
# Committed Gens    11     Generation (actual)   5830.2            2705.2
# Loads             35     Load                  5727.9            1374.9
#   Fixed           35       Fixed               5727.9            1374.9
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts            44     Shunt (inj)             -5.7             567.9
# Branches         210     Losses (I^2 * Z)        96.63           1898.20
# Transformers      50     Branch Charging (inj)     -                0.0
# Inter-ties         0     Total Inter-tie Flow     0.0               0.0
# Areas              1
#
#                           Minimum                      Maximum
#                  -------------------------  --------------------------------
# Voltage Magnitude   0.977 p.u. @ bus 61         1.100 p.u. @ bus 27
# Voltage Angle     -12.47 deg   @ bus 83        24.99 deg   @ bus 79
# P Losses (I^2*R)             -                 14.29 MW    @ line 47-67
# Q Losses (I^2*X)             -                238.47 MVAr  @ line 67-79
# Lambda P         -104.63 $/MWh @ bus 79        71.65 $/MWh @ bus 34
# Lambda Q           -9.84 $/MWh @ bus 49        25.25 $/MWh @ bus 79
#
# ================================================================================
# |     Bus Data                                                                 |
# ================================================================================
#  Bus      Voltage          Generation             Load          Lambda($/MVA-hr)
#   #   Mag(pu) Ang(deg)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)     P        Q
# ----- ------- --------  --------  --------  --------  --------  -------  -------
#     0  1
#  196     75     12    186.38     92.79   -186.10    -72.47     0.285     20.32
#  197     75     12    190.47     94.67   -190.16    -73.90     0.305     20.76
#  198     12     27      6.83     -3.96     -6.73      4.68     0.104      0.72
#  199     12     42      2.50     -0.18     -2.36      0.59     0.137      0.40
#  200     24     30    180.46     85.17   -180.27    -66.81     0.191     18.36
#  201     81     51    285.55    116.27   -285.03    -78.30     0.522     37.97
#  202     81     71     39.36     -9.93    -39.34     10.70     0.016      0.77
#  203      3     27    479.95    164.92   -478.75    -70.55     1.192     94.37
#  204     67     79  -1297.79     89.76   1299.13    140.85     1.339    230.61
#  205     52     65   -179.70    -59.65    179.73     63.08     0.032      3.43
#  206      0     40    212.97     94.05   -212.65    -72.29     0.317     21.76
#  207     28     42    228.07     70.86   -227.74    -47.95     0.332     22.92
#  208     53     77    419.33    242.11   -418.09   -162.21     1.237     79.90
#  209     21     53    357.14    -39.07   -357.03     50.96     0.108     11.90
#                                                              --------  --------
#                                                     Total:   126.766   2232.44
#
# ================================================================================
# |     Generation Constraints                                                   |
# ================================================================================
#  Gen   Bus                Active Power Limits
#   #     #    Pmin mu    Pmin       Pg       Pmax    Pmax mu
# ----  -----  -------  --------  --------  --------  -------
#    1    23   10.453    166.67    166.67    500.00      -
#    2    36      -      666.67   2000.00   2000.00    1.963
#    4    44      -        7.08     21.23     21.23    8.938
#    5    55      -      400.00   1200.00   1200.00   23.660
#    6    59    5.972    333.33    333.33   1000.00      -
#    7    64      -     -908.93    100.00    100.00   15.732
#    8    70      -      200.00    600.00    600.00    9.496
#    9    80    0.030    200.00    200.00    600.00      -
#   10    88      -      200.00    600.00    600.00   14.358
#
# Gen  Bus              Reactive Power Limits
#  #    #   Qmin mu    Qmin       Qg       Qmax    Qmax mu
# ---  ---  -------  --------  --------  --------  -------
#   0   20     -     -257.62    661.90    661.90    1.251
#   1   23     -      -78.83    228.16    228.16    0.322
#   2   36     -     -282.01    943.64    943.64    1.205
#   3   41   4.499    -29.81    -29.81     92.96      -
#   4   44     -       -4.11      8.91      8.91    2.025
#   7   64     -       -6.64     14.78     14.78    1.724
#   8   70     -      -93.22    274.20    274.20    0.005
#  10   88     -      -93.22    274.20    274.20    0.005
#
# ================================================================================
# |     Branch Flow Constraints                                                  |
# ================================================================================
# Brnch   From     "From" End        Limit       "To" End        To
#   #     Bus   |Sf| mu    |Sf|     |Smax|     |St|    |St| mu   Bus
# -----  -----  -------  --------  --------  --------  -------  -----
#   33     34      -      318.97    319.00    319.00   102.894    49
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!
# change to load bus!

# %%
contingencies
# Out:
# {'contingencies': [{'gen': 9},
#   {'gen': 3},
#   {'gen': 6},
#   {'gen': 7},
#   {'gen': 3},
#   {'gen': 6},
#   {'gen': 4},
#   {'gen': 8},
#   {'gen': 5},
#   {'gen': 0}],
#  'num_cases': 10}

# %%
from pypower import idx_bus, idx_gen, idx_brch
import numpy as np
import torch_geometric
from torch_geometric.data import Data 
from models.Edge_GNN_solver import Edge_GNNSolver
import copy

# Load data generation (unsupervised)
pd_base = grid.ppc['bus'][:,idx_bus.PD] / grid.baseMVA.item()
qd_base = grid.ppc['bus'][:,idx_bus.QD] / grid.baseMVA.item()
num_data = 200
perturb = (1.0 + np.random.uniform(-0.2, 0.2, size=(num_data, grid.nbus)))
# data sample from uniform distribution
pd_samples = torch.from_numpy(pd_base * perturb).float()
qd_samples = torch.from_numpy(qd_base * perturb).float()
demand = pd_samples + 1j*qd_samples

# Graph data representation
graph_dataset_contingency = []
graph_dataset_contingency_statics = []

# Model config
train_config = {
    'probType': 'acopf',
    'useCompl': True, # boolean type: whether to use completion (DC3, DeepLDE 기술)

    # GNN model parameters
    'n_gnn_layers': 3,
    'nfeature_dim': 2, # input dim
    'efeature_dim': 4, # edge feature dim 
    'hidden_dim': 40,
    'dropout_rate': 0.1,
    'K': 10, # 6 # only for TAGConv or ChebConv and GATConv (as multi-head)

    # DeepLDE hyperparameters
    'epochs': 20, # 10 (GPU RTX 4090), 8 (GPU A100)
    'batchSize': 5, # 6, (8) (GPU RTX 4090; GPU 다운 에러 발생..), 16 (GPU A100)
    'lr': 1e-2, # 1e-3
    'lr_w': 1e-2, # 1e-3
    'weight_decay': 0.0, # 1e-5,

    # LDF parameters
    'rho_init': 0.1, # 0.01  
    's_init': 0.1,
    'p_iter_max': 5,
    'warmup_iter': 20, # 20, # 0 for non-warmup start cases
    'corrEps': 1e-4, # float type: correction procedure tolerance
}

# Models
contingency_models = []

for case in range(len(acopf_contingencies)):
    node_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus, 2))
    node_mask_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus))
    for s in range(node_feat_x.shape[0]):
        node_feat_x[s,:,0] = np.real(demand[s,:])
        node_feat_x[s,:,1] = np.imag(demand[s,:])
        node_mask_x[s,acopf_contingencies[case].spv] = 1
        # node_mask_x[s,self.pv] = 1
    
    edge_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nl, 6))
    for s in range(edge_feat_x.shape[0]):
        edge_feat_x[s,:,0] = acopf_contingencies[case].ppc['branch'][:, idx_brch.F_BUS]
        edge_feat_x[s,:,1] = acopf_contingencies[case].ppc['branch'][:, idx_brch.T_BUS]
        edge_feat_x[s,:,2] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_R]
        edge_feat_x[s,:,3] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_X]
        edge_feat_x[s,:,4] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_B]
        
        br_ratea_feat = (acopf_contingencies[case].ppc['branch'][:, idx_brch.RATE_A] / acopf_contingencies[case].baseMVA)
        # br_ratea_feat[br_ratea_feat == 0] = np.Inf
        edge_feat_x[s,:,5] = br_ratea_feat

    node_feat_x = torch.tensor(node_feat_x[:,:,:], dtype=torch.get_default_dtype())
    node_mask_x = torch.tensor(node_mask_x[:,:], dtype=torch.get_default_dtype())
    edge_feat_x = torch.tensor(edge_feat_x[:,:,:], dtype=torch.get_default_dtype())
    pyg_data_list = []
    for i in range(demand.shape[0]):
        pyg_data_list += [Data(
            x=node_feat_x[i,:,:],
            node_mask=node_mask_x[i,:].to(torch.bool),
            edge_index=edge_feat_x[i, :, 0:2].T.to(torch.long),
            edge_attr=edge_feat_x[i, :, 2:],) # R,X,B,RateA
            ]
    
    graph_dataset_contingency += [pyg_data_list]
    
    node_dataset = torch.zeros((acopf_contingencies[case].nbus*len(pyg_data_list),2))
    edge_dataset = torch.zeros((acopf_contingencies[case].nl*len(pyg_data_list),4))
    for (i,data) in enumerate(pyg_data_list):
        node_dataset[acopf_contingencies[case].nbus*i:acopf_contingencies[case].nbus*(i+1),:] = data.x
        edge_dataset[acopf_contingencies[case].nl*i:acopf_contingencies[case].nl*(i+1),:] = data.edge_attr
    
    node_means = node_dataset.mean(axis=0, keepdims = True)
    node_stds = node_dataset.std(axis=0, keepdims = True)
    edge_means = edge_dataset.mean(axis=0, keepdims = True)
    edge_stds = edge_dataset.std(axis=0, keepdims = True)

    graph_dataset_contingency_statics += [[node_means.to(dtype=torch.get_default_dtype()),
                                          node_stds.to(dtype=torch.get_default_dtype()),
                                          edge_means.to(dtype=torch.get_default_dtype()),
                                          edge_stds.to(dtype=torch.get_default_dtype())]]

    data_loader = torch_geometric.loader.DataLoader(pyg_data_list, batch_size=1, shuffle=False, drop_last=True)
    solver_net = Edge_GNNSolver(acopf_contingencies[case], train_config)
    contingency_models += [solver_net]

    print(solver_net)
# Out:
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=4200, out_features=69, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=4200, out_features=69, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=4200, out_features=69, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=4200, out_features=69, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# /tmp/ipykernel_1539557/3520271133.py:57: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,0] = np.real(demand[s,:])
# /tmp/ipykernel_1539557/3520271133.py:58: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,1] = np.imag(demand[s,:])

# %% [markdown]
# * Load pretrained GraphOPF model

# %%
pretrained_client = torch.load("./models/pretrained_models/client/checkpoint_Client8.pth", weights_only=False, map_location=device)
# pretrained_server = torch.load("./models/pretrained_models/server/checkpoint_Server_0.pth", weights_only=False, map_location=device)
# pretrained_global = torch.load("./models/pretrained_models/global/checkpoint_Global.pth", weights_only=False, map_location=device)

# %%
for contingency_model in contingency_models:
    if component == 'gen':
        print("Generator contingency")
        # Dimension reduction for N-1 contingency
        new_row = contingency_model.flatten.weight.shape[0] 
        new_col = contingency_model.flatten.weight.shape[1]
        old_row = pretrained_client['flatten.weight'].shape[0]
        old_col = pretrained_client['flatten.weight'].shape[1]
    
        pretrained_flatten_weight = copy.deepcopy(pretrained_client['flatten.weight'])
        pretrained_flatten_bias = copy.deepcopy(pretrained_client['flatten.bias'])
        
        # Way 1
        row_norm = torch.norm(pretrained_flatten_weight, dim=1)
        rows_removed = torch.argsort(row_norm)[:old_row - new_row]
        col_norm = torch.norm(pretrained_flatten_weight, dim=0)
        cols_removed = torch.argsort(col_norm)[:old_col - new_col]
        
        row_mask = torch.ones(pretrained_flatten_weight.size(0), dtype=torch.bool, device=device)
        row_mask[rows_removed] = False
        col_mask = torch.ones(pretrained_flatten_weight.size(1), dtype=torch.bool, device=device)
        col_mask[cols_removed] = False

        shrinked_weight = pretrained_flatten_weight[row_mask][:, col_mask]
        shrinked_bias = pretrained_flatten_bias[row_mask] # corresponding to the flatten.weight

        # # Way 2
        # shrinked_weight = pretrained_flatten_weight[(old_row - new_row):, (old_col - new_col):]
        # shrinked_bias = pretrained_flatten_bias[(old_row - new_row):] # corresponding to the flatten.weight

        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()
        
        layer_names = list(target_state_dict.keys())
        for name in layer_names[:-2]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()
            
        for name in layer_names[-2:]:
            if 'weight' in name:
                # print('weight load')
                target_state_dict[name] = shrinked_weight
            elif 'bias' in name:
                # print('bias load')
                target_state_dict[name] = shrinked_bias
    
    elif component == 'branch':
        print("Branch contingency")
        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()

        layer_names = list(target_state_dict.keys())
        for name in layer_names[:]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()

    contingency_model.load_state_dict(target_state_dict)

    # # Freezing the half-GNN layers
    # for i, (name, param) in enumerate(contingency_model.named_parameters()):
    #     if i <= 32: # 5, 10, 21
    #         # print(name)
    #         param.requires_grad = False
    #     else:
    #         print(name)
    #         param.requires_grad = True
# Out:
# Branch contingency
# Branch contingency
# Branch contingency
# Branch contingency

# %% [markdown]
# * Fine-tuning (for generator contingency)

# %%
import torch.optim as optim
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

# Set the linear algebra solver(?)
torch._C._set_linalg_preferred_backend(torch._C._LinalgBackend.Cusolver) # torch._C._LinalgBackend.Magma, torch._C._LinalgBackend.Cusolver
# torch._C._get_linalg_preferred_backend() 

# stats_contingency = []
for case in range(len(acopf_contingencies)):
# for case in range(1):
    print("Contingency ", case)
    stats = {}
    
    # NOTE: LDF parameters.
    LagM_sp_gen = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_gen = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_bus = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    warmup_iter = train_config["warmup_iter"] # the warmup period: the NN is trained with an additional inner iteration before the first outer iteration.
    rho_init = train_config["rho_init"]
    
    rho = rho_init
    
    rho_iter = 0
    s_iter = 0
    
    p_iter_max = train_config["p_iter_max"]
    p_iter_max_sum = p_iter_max
    
    d = 0 # 0 for static case otherwise use 5"
    beta = 0 # 0.001 # 0 for static case otherwise use 1
    
    lr_w = train_config["lr_w"] # 이거 증가해도 되지 않을지?
    lr = train_config["lr"]
    print_interval = 1
    eps_converge = 1e-4
    
    contingency_models[case] = contingency_models[case].to(device)
    train_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][:20], batch_size=train_config['batchSize'], shuffle=True, drop_last=True)
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    train_loss_list = []
    train_start_time = time.time()
    for i in range(train_config["epochs"]):
        epoch_stats = {}
        ################### TRAINING PHASE ###################
        solver_net.train()
        if i<warmup_iter:
            ######### WARM-UP PERIOD #########
            if i == 0:
                solver_opt = optim.Adam(contingency_models[case].parameters(), lr=lr_w) # this will be reinitalized after warmup stage
                print("Warmup start!")
    
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                # start_time = time.time()
                solver_opt.zero_grad()
    
                # DNN + NR (equality constraint)
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, train_obj, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        else:
            if i == warmup_iter:
                print("Warmup ended!")
                # data.ref_freedom = False
    
                # ineq_lag_flag = True # for the first warmup end epoch, consider lag. multipliers update of ineq.
            # elif (i - warmup_iter)%ineq_lag_flag_trigger == 0:
            #     # print("Doing test... continue this case..")
            #     print("consider lagrangian multipliers update for ineq. constraints!")
            #     ineq_lag_flag = True
            # else:
            #     ineq_lag_flag = False
    
            # for every (updated) p_iter_max_sum time.
            if (i - warmup_iter)%p_iter_max_sum == 0:
                ######### Outer Interation: calculate step size of lagrangian multipliers update #########
                if i> warmup_iter:
                    print("current epoch %d || p_iter_max updated : %d -> %d" %(i, p_iter_max, p_iter_max + d))
                    # s = s_init * (1/(1+beta*(s_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    # s_iter += 1
                    # print("mu iter updated : %d -> %d" %(s_iter-1, s_iter))
    
                    rho = rho_init * (1/(1+beta*(rho_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    rho_iter += 1
                    print("rho iter updated : %d -> %d" %(rho_iter-1, rho_iter))
                    p_iter_max = p_iter_max + d
                    p_iter_max_sum += p_iter_max
    
                with torch.no_grad():
                    print("Lambda updated at %d epoch" %i)
                    contingency_models[case].eval()
                    for Xtrain in train_loader:
                        Xtrain = Xtrain.to(device)
                        #solver_opt.zero_grad()
                        Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                        # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                        # LagM += rho*ineq_violation(data, Xtrain.x, Yhat_train) # Update the lagrangian multiplier.
                        LagM_sp_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[:2] # Update the lagrangian multiplier.
                        LagM_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2:2+2*acopf_contingencies[case].ng] # Update the lagrangian multiplier.
                        LagM_bus += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus] # Update the lagrangian multiplier.
                        LagM_line += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:] # Update the lagrangian multiplier.
                
                ## Does this stablize the learning process much better?
                LagM_sp_gen = (LagM_sp_gen/len(train_loader))
                LagM_gen = (LagM_gen/len(train_loader))
                LagM_bus = (LagM_bus/len(train_loader))
                LagM_line = (LagM_line/len(train_loader))
    
                # solver_opt = optim.Adam(contingency_models[0].parameters(), lr = lr)
    
            contingency_models[case].train()
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                solver_opt.zero_grad()
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, obj_train, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        if (i == 0) or (i%print_interval == 0):
            print(
                'Epoch {}: train loss {:.4f}, train obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq p_g num viol {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, ineq line_theraml num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}'.format(
                    i, np.mean(epoch_stats['train_loss']), np.mean(epoch_stats['train_obj']), np.mean(epoch_stats['train_ineq_max']), np.mean(epoch_stats['train_ineq_mean']),
                    np.mean(epoch_stats['train_ineq_p_g_num_viol_0']), np.mean(epoch_stats['train_ineq_q_g_num_viol_0']), np.mean(epoch_stats['train_ineq_v_m_num_viol_0']), np.mean(epoch_stats['train_ineq_line_thermal_num_viol_0']),
                    np.mean(epoch_stats['train_eq_max']), np.mean(epoch_stats['train_eq_mean'])))
        
        train_loss_list.append(np.mean(epoch_stats['train_loss']))
        # valid_eval_list.append(np.mean(epoch_stats['valid_eval']))
    # stats_contingency += []
    print("\n")
train_end_time = time.time()
total_train_time = train_end_time - train_start_time
# Out:
# Contingency  0
# Warmup start!
# Epoch 0: train loss 1.3112, train obj 0.3866, ineq max 0.6023, ineq mean 0.0009, ineq p_g num viol 0.6500, ineq q_g num viol 2.1500, ineq v_m num viol 0.7500, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 1: train loss 0.6135, train obj 0.3640, ineq max 0.2488, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0000, ineq v_m num viol 0.4500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 2: train loss 0.6049, train obj 0.3581, ineq max 0.2466, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.2000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 3: train loss 0.6024, train obj 0.3464, ineq max 0.2560, ineq mean 0.0002, ineq p_g num viol 0.6500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 4: train loss 0.5496, train obj 0.3482, ineq max 0.2015, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 5: train loss 0.5845, train obj 0.3459, ineq max 0.2386, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 6: train loss 0.5805, train obj 0.3398, ineq max 0.2407, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 7: train loss 0.5526, train obj 0.3320, ineq max 0.2206, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 8: train loss 0.5644, train obj 0.3192, ineq max 0.2451, ineq mean 0.0002, ineq p_g num viol 0.6500, ineq q_g num viol 0.0000, ineq v_m num viol 0.1000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 9: train loss 0.6444, train obj 0.3216, ineq max 0.3227, ineq mean 0.0003, ineq p_g num viol 0.5500, ineq q_g num viol 0.0500, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 10: train loss 0.5697, train obj 0.3031, ineq max 0.2666, ineq mean 0.0003, ineq p_g num viol 0.6500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 11: train loss 0.5281, train obj 0.2977, ineq max 0.2303, ineq mean 0.0002, ineq p_g num viol 0.5000, ineq q_g num viol 0.0000, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 12: train loss 0.5389, train obj 0.2902, ineq max 0.2484, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.3000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 13: train loss 0.5129, train obj 0.2805, ineq max 0.2324, ineq mean 0.0002, ineq p_g num viol 0.5000, ineq q_g num viol 0.0000, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 14: train loss 0.5116, train obj 0.2617, ineq max 0.2500, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 15: train loss 0.4709, train obj 0.2386, ineq max 0.2323, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0000, ineq v_m num viol 0.2500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 16: train loss 0.4406, train obj 0.2112, ineq max 0.2295, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 17: train loss 0.4415, train obj 0.1680, ineq max 0.2723, ineq mean 0.0003, ineq p_g num viol 0.4500, ineq q_g num viol 0.4500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 18: train loss 0.4089, train obj 0.1279, ineq max 0.2780, ineq mean 0.0003, ineq p_g num viol 0.6000, ineq q_g num viol 0.6500, ineq v_m num viol 0.2500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 19: train loss 0.3087, train obj 0.0944, ineq max 0.2128, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.1500, ineq v_m num viol 0.0500, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
#
#
# Contingency  1
# Warmup start!
# Epoch 0: train loss 0.8836, train obj 0.0002, ineq max 0.6331, ineq mean 0.0009, ineq p_g num viol 0.5500, ineq q_g num viol 3.9000, ineq v_m num viol 0.8000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 1: train loss 0.4781, train obj 0.0016, ineq max 0.4595, ineq mean 0.0005, ineq p_g num viol 0.6000, ineq q_g num viol 1.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 2: train loss 0.2838, train obj 0.0011, ineq max 0.2750, ineq mean 0.0003, ineq p_g num viol 0.5500, ineq q_g num viol 0.7500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 3: train loss 0.2840, train obj 0.0018, ineq max 0.2816, ineq mean 0.0003, ineq p_g num viol 0.6000, ineq q_g num viol 0.2000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 4: train loss 0.2712, train obj 0.0019, ineq max 0.2690, ineq mean 0.0003, ineq p_g num viol 0.6500, ineq q_g num viol 0.2500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 5: train loss 0.2108, train obj 0.0015, ineq max 0.2089, ineq mean 0.0002, ineq p_g num viol 0.5000, ineq q_g num viol 0.3000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 6: train loss 0.2564, train obj 0.0008, ineq max 0.2553, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.3000, ineq v_m num viol 0.2000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 7: train loss 0.2721, train obj 0.0005, ineq max 0.2710, ineq mean 0.0003, ineq p_g num viol 0.5500, ineq q_g num viol 0.1500, ineq v_m num viol 0.1000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 8: train loss 0.2848, train obj 0.0005, ineq max 0.2843, ineq mean 0.0003, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 9: train loss 0.2350, train obj 0.0005, ineq max 0.2336, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.2500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 10: train loss 0.1905, train obj 0.0004, ineq max 0.1896, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.2500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 11: train loss 0.2107, train obj 0.0004, ineq max 0.2100, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.4000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 12: train loss 0.2149, train obj 0.0004, ineq max 0.2144, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.1000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 13: train loss 0.1978, train obj 0.0003, ineq max 0.1973, ineq mean 0.0002, ineq p_g num viol 0.5000, ineq q_g num viol 0.0500, ineq v_m num viol 0.1500, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 14: train loss 0.2446, train obj 0.0003, ineq max 0.2443, ineq mean 0.0002, ineq p_g num viol 0.6000, ineq q_g num viol 0.0000, ineq v_m num viol 0.2000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 15: train loss 0.2059, train obj 0.0002, ineq max 0.2057, ineq mean 0.0002, ineq p_g num viol 0.6500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 16: train loss 0.2018, train obj 0.0002, ineq max 0.2015, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 17: train loss 0.2311, train obj 0.0002, ineq max 0.2309, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0000, eq mean 0.0000
# Epoch 18: train loss 0.2210, train obj 0.0002, ineq max 0.2208, ineq mean 0.0002, ineq p_g num viol 0.5500, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000
# Epoch 19: train loss 0.2250, train obj 0.0002, ineq max 0.2247, ineq mean 0.0002, ineq p_g num viol 0.6500, ineq q_g num viol 0.0500, ineq v_m num viol 0.0000, ineq line_theraml num viol 0.0000, eq max 0.0001, eq mean 0.0000

# %%
total_train_time
# Out:
# 3.79400372505188

# %% [markdown]
# * Evaluation (zero-shot)

# %%
from pypower.api import makeYbus
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

test_stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    Ybus, Yf, Yt = makeYbus(acopf_contingencies[case].baseMVA, acopf_contingencies[case].ppc['bus'], acopf_contingencies[case].ppc['branch'])
    # branch thermal limit information
    flow_max = (acopf_contingencies[case].ppc['branch'][:, 5] / acopf_contingencies[case].baseMVA)**2
    flow_max[flow_max == 0] = np.inf
    flow_max = torch.tensor(flow_max, dtype=torch.float32).to(device)
    
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    test_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][100:], batch_size=1, shuffle=False, drop_last=True)
    contingency_models[case] = contingency_models[case].to(device)
    contingency_models[case].eval()
    test_stats = {}
    # test_stats["Contingency"] = case
    test_eps_converge = 1e-4
    
    LagM_sp_g = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_q_g = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_v_m = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line_l = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    solve_time = []
    for (i, Xtest) in enumerate(test_loader):
        Xtest = Xtest.to(device)
    
        start_time = time.time()
        Y = contingency_models[case](Xtest, n_means, n_stds, e_means, e_stds)
        end_time = time.time()
    
        solve_time += [end_time - start_time]
    
        ## line thermal limit
        pg, qg, vm, va = acopf_contingencies[case].get_yvars(Y)
        vr = vm*torch.cos(va)
        vi = vm*torch.sin(va)
        vz = torch.complex(vr, vi) # complex voltage
    
        # calculate the branch current of from bus and to bus based on the Yf*V and Yt*V
        If = torch.tensor(Yf.todense(), dtype=torch.complex64).to(device) @ vz.T
        It = torch.tensor(Yt.todense(), dtype=torch.complex64).to(device) @ vz.T
    
        # Calculate the apparent power S
        Sf = vz[:,acopf_contingencies[case].ppc['branch'][:,0].astype(int)] * torch.conj(If.T)
        St = vz[:,acopf_contingencies[case].ppc['branch'][:,1].astype(int)] * torch.conj(It.T)
        Sff = Sf * torch.conj(Sf)
        Stt = St * torch.conj(St)
    
        # calculate the line thermal limit constraints violation
        diff_Sf = Sff.real - flow_max
        diff_St = Stt.real - flow_max
        # diff_Sf[torch.clamp(diff_Sf, 0) != 0]
    
        line_limit_vio_Sf = torch.clamp(diff_Sf, 0)
        line_limit_vio_St = torch.clamp(diff_St, 0)
        ###########################################
    
        # test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(data, Xtest.x, Y, LagM)
        test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(acopf_contingencies[case], Xtest.x, Y, LagM_sp_g, LagM_q_g, LagM_v_m, LagM_line_l) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
    
        dict_agg(test_stats, 'time', end_time - start_time, op='sum')
    
        test_ineq_p_g = torch.cat([pg - acopf_contingencies[case].pmax, acopf_contingencies[case].pmin - pg], dim=1)
        test_ineq_p_g = torch.clamp(test_ineq_p_g, 0).to(device)
        test_ineq_q_g = test_ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
        test_ineq_v_m = test_ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
        test_ineq_line_l = test_ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
        dict_agg(test_stats, 'test_loss', test_loss.detach().cpu().numpy())
        # dict_agg(test_stats, 'test_loss', (test_loss[0]+test_loss[1]+test_loss[2]+test_loss[3]).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_obj_cost', test_obj_cost.detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_max', torch.max(test_ineq_dist, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_mean', torch.mean(test_ineq_dist, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_max', torch.max(test_ineq_p_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_mean', torch.mean(test_ineq_p_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_max', torch.max(test_ineq_q_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_mean', torch.mean(test_ineq_q_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_max', torch.max(test_ineq_v_m, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_mean', torch.mean(test_ineq_v_m, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_max', torch.max(test_ineq_line_l, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_mean', torch.mean(test_ineq_line_l, dim=1).detach().cpu().numpy())
    
        pg_rate_torch = (((pg <= acopf_contingencies[case].pmax) & (pg >= acopf_contingencies[case].pmin)).sum()/acopf_contingencies[case].ng)*100
        qg_rate_torch = (((qg <= acopf_contingencies[case].qmax) & (qg >= acopf_contingencies[case].qmin)).sum()/acopf_contingencies[case].ng)*100
        dict_agg(test_stats, 'test_p_g_satisfication rate (%)', pg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_q_g_satisfication rate (%)', qg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_p_g_satisfication rate (%)', ((torch.sum(test_ineq_p_g == 0, dim=1)/test_ineq_p_g.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_q_g_satisfication rate (%)', ((torch.sum(test_ineq_q_g == 0, dim=1)/test_ineq_q_g.shape[1])*100).detach().cpu().numpy())
    
        v_rate_torch = (((vm <= acopf_contingencies[case].vmax) & (vm >= acopf_contingencies[case].vmin)).sum()/acopf_contingencies[case].nbus)*100
        dict_agg(test_stats, 'test_v_m_satisfication rate (%)', v_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_v_m_satisfication rate (%)', ((torch.sum(test_ineq_v_m == 0, dim=1)/test_ineq_v_m.shape[1])*100).detach().cpu().numpy())
    
        sff_rate_torch = ((Sff.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        stt_rate_torch = ((Stt.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', sff_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', stt_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate (%)', ((torch.sum(test_ineq_line_l == 0, dim=1)/test_ineq_line_l.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', ((torch.sum(line_limit_vio_Sf == 0, dim=1)/line_limit_vio_Sf.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', ((torch.sum(line_limit_vio_St == 0, dim=1)/line_limit_vio_St.shape[1])*100).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_q_g_num_viol_0', torch.sum(test_ineq_q_g > test_eps_converge, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_num_viol_0', torch.sum(test_ineq_v_m > test_eps_converge, dim=1).detach().cpu().numpy())
    
        test_eq_real = test_eq_resid[:,:acopf_contingencies[case].nbus]
        test_eq_react = test_eq_resid[:,acopf_contingencies[case].nbus:]
        dict_agg(test_stats, 'test_eq_max', torch.max(torch.abs(test_eq_resid), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_mean', torch.mean(torch.abs(test_eq_resid), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_max', torch.max(torch.abs(test_eq_real), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_mean', torch.mean(torch.abs(test_eq_real), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_max', torch.max(torch.abs(test_eq_react), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_mean', torch.mean(torch.abs(test_eq_react), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_active_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,:acopf_contingencies[case].nbus] <= 1e-2) & (test_eq_resid[:,:acopf_contingencies[case].nbus] >= -1e-2)  , dim=1)/test_eq_resid[:,:acopf_contingencies[case].nbus].shape[1]*100).detach().cpu().numpy())
        dict_agg(test_stats, 'test_reactive_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,acopf_contingencies[case].nbus:] <= 1e-2) & (test_eq_resid[:,acopf_contingencies[case].nbus:] >= -1e-2)  , dim=1)/test_eq_resid[:,acopf_contingencies[case].nbus:].shape[1]*100).detach().cpu().numpy())

        print('Test batch {}: test loss {:.4f}, test obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}, p_g satisfication rate {:.4f}, q_g satisfication rate {:.4f}, v_m satisfication rate {:.4f}, test_line_limit_satisfication_rate {:.4f}, test_line_limit_satisfication_rate_Sf {:.4f}, test_line_limit_satisfication_rate_St {:.4f}, active eq satisfication rate {:.4f}, reactive eq satisfication rate {:.4f}'.format(
                    i, np.mean(test_stats['test_loss']), np.mean(test_stats['test_obj_cost']), np.mean(test_stats['test_ineq_max']), np.mean(test_stats['test_ineq_mean']),
                    np.mean(test_stats['test_ineq_q_g_num_viol_0']), np.mean(test_stats['test_ineq_v_m_num_viol_0']),
                    np.mean(test_stats['test_eq_max']), np.mean(test_stats['test_eq_mean']), np.mean(test_stats['test_p_g_satisfication rate (%)']), np.mean(test_stats['test_q_g_satisfication rate (%)']), np.mean(test_stats['test_v_m_satisfication rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']), np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']), np.mean(test_stats['test_active_eq_satisfication rate (%)']), np.mean(test_stats['test_reactive_eq_satisfication rate (%)'])))

    test_stats_contingency += [test_stats]
    print("\n")
# Out:
# Contingency  0
# Test batch 0: test loss 1.0831, test obj 0.0002, ineq max 1.0829, ineq mean 0.0010, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 97.1429, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 1: test loss 0.5416, test obj 0.0002, ineq max 0.5415, ineq mean 0.0005, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.5714, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 2: test loss 0.3611, test obj 0.0002, ineq max 0.3610, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 3: test loss 0.2709, test obj 0.0002, ineq max 0.2707, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.2857, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 4: test loss 0.3467, test obj 0.0002, ineq max 0.3465, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8571, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 5: test loss 0.2889, test obj 0.0002, ineq max 0.2888, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 6: test loss 0.2477, test obj 0.0002, ineq max 0.2475, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.1837, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 7: test loss 0.2888, test obj 0.0002, ineq max 0.2886, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9286, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 8: test loss 0.2771, test obj 0.0002, ineq max 0.2770, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7302, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 9: test loss 0.2494, test obj 0.0002, ineq max 0.2493, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.8571, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 10: test loss 0.2268, test obj 0.0002, ineq max 0.2266, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9611, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 11: test loss 0.2079, test obj 0.0002, ineq max 0.2077, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 12: test loss 0.2335, test obj 0.0002, ineq max 0.2333, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9011, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 13: test loss 0.2459, test obj 0.0002, ineq max 0.2458, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.7755, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 14: test loss 0.2296, test obj 0.0002, ineq max 0.2294, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.8571, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 15: test loss 0.2152, test obj 0.0002, ineq max 0.2151, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9286, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 16: test loss 0.2026, test obj 0.0002, ineq max 0.2024, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9916, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 17: test loss 0.1913, test obj 0.0002, ineq max 0.1912, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 18: test loss 0.1926, test obj 0.0002, ineq max 0.1924, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9474, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 19: test loss 0.1829, test obj 0.0002, ineq max 0.1828, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0000, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 20: test loss 0.2180, test obj 0.0002, ineq max 0.2178, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9116, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 21: test loss 0.2670, test obj 0.0002, ineq max 0.2668, ineq mean 0.0003, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.8312, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 22: test loss 0.2554, test obj 0.0002, ineq max 0.2552, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.8820, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 23: test loss 0.2448, test obj 0.0002, ineq max 0.2446, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.9286, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 24: test loss 0.2350, test obj 0.0002, ineq max 0.2348, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9714, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 25: test loss 0.2259, test obj 0.0002, ineq max 0.2258, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0110, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 26: test loss 0.2176, test obj 0.0002, ineq max 0.2174, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 27: test loss 0.2098, test obj 0.0002, ineq max 0.2097, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0816, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 28: test loss 0.2026, test obj 0.0002, ineq max 0.2024, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.1133, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 29: test loss 0.1958, test obj 0.0002, ineq max 0.1957, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.1429, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 30: test loss 0.1897, test obj 0.0002, ineq max 0.1895, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.0783, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 31: test loss 0.1837, test obj 0.0002, ineq max 0.1836, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.1071, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 32: test loss 0.1782, test obj 0.0002, ineq max 0.1780, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 99.1342, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 33: test loss 0.1845, test obj 0.0002, ineq max 0.1844, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0756, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 34: test loss 0.1793, test obj 0.0002, ineq max 0.1791, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.1020, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 35: test loss 0.1934, test obj 0.0002, ineq max 0.1933, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 36: test loss 0.2018, test obj 0.0002, ineq max 0.2017, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9961, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 37: test loss 0.1965, test obj 0.0002, ineq max 0.1964, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0226, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 38: test loss 0.2162, test obj 0.0002, ineq max 0.2160, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9743, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 39: test loss 0.2108, test obj 0.0002, ineq max 0.2106, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0000, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 40: test loss 0.2056, test obj 0.0002, ineq max 0.2055, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0244, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 41: test loss 0.2008, test obj 0.0002, ineq max 0.2006, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0476, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 42: test loss 0.1961, test obj 0.0002, ineq max 0.1959, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0698, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 43: test loss 0.2000, test obj 0.0002, ineq max 0.1999, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 99.0260, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 44: test loss 0.2183, test obj 0.0002, ineq max 0.2181, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9841, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 45: test loss 0.2199, test obj 0.0002, ineq max 0.2198, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9441, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 46: test loss 0.2261, test obj 0.0002, ineq max 0.2260, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.9058, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 47: test loss 0.2243, test obj 0.0002, ineq max 0.2241, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8690, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 48: test loss 0.2197, test obj 0.0002, ineq max 0.2195, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8921, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 49: test loss 0.2187, test obj 0.0002, ineq max 0.2186, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8571, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 50: test loss 0.2168, test obj 0.0002, ineq max 0.2166, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8235, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 51: test loss 0.2126, test obj 0.0002, ineq max 0.2124, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.8462, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 52: test loss 0.2124, test obj 0.0002, ineq max 0.2123, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8140, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 53: test loss 0.2280, test obj 0.0002, ineq max 0.2279, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7831, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 54: test loss 0.2239, test obj 0.0002, ineq max 0.2237, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.8052, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 55: test loss 0.2209, test obj 0.0002, ineq max 0.2208, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7755, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 56: test loss 0.2283, test obj 0.0002, ineq max 0.2282, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7469, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 57: test loss 0.2397, test obj 0.0002, ineq max 0.2396, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7192, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 58: test loss 0.2414, test obj 0.0002, ineq max 0.2412, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6925, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 59: test loss 0.2428, test obj 0.0002, ineq max 0.2427, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6667, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 60: test loss 0.2388, test obj 0.0002, ineq max 0.2387, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6885, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 61: test loss 0.2407, test obj 0.0002, ineq max 0.2406, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6636, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 62: test loss 0.2369, test obj 0.0002, ineq max 0.2368, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6848, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 63: test loss 0.2332, test obj 0.0002, ineq max 0.2331, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7054, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 64: test loss 0.2333, test obj 0.0002, ineq max 0.2332, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6813, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 65: test loss 0.2330, test obj 0.0002, ineq max 0.2328, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6580, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 66: test loss 0.2295, test obj 0.0002, ineq max 0.2294, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6780, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 67: test loss 0.2261, test obj 0.0002, ineq max 0.2260, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6975, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 68: test loss 0.2229, test obj 0.0002, ineq max 0.2227, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7164, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 0.2235, test obj 0.0002, ineq max 0.2233, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6939, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 0.2385, test obj 0.0002, ineq max 0.2383, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6721, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 0.2363, test obj 0.0002, ineq max 0.2361, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6508, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 0.2432, test obj 0.0002, ineq max 0.2431, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6301, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 0.2447, test obj 0.0002, ineq max 0.2445, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6100, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 0.2414, test obj 0.0002, ineq max 0.2413, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6286, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 0.2466, test obj 0.0002, ineq max 0.2465, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6090, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 0.2434, test obj 0.0002, ineq max 0.2433, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6271, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 0.2403, test obj 0.0002, ineq max 0.2402, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6447, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 0.2388, test obj 0.0002, ineq max 0.2386, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6257, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 0.2358, test obj 0.0002, ineq max 0.2356, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6429, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 0.2412, test obj 0.0002, ineq max 0.2410, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6243, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 0.2430, test obj 0.0002, ineq max 0.2428, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6063, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 0.2401, test obj 0.0002, ineq max 0.2399, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6231, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 0.2372, test obj 0.0002, ineq max 0.2371, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6395, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 0.2372, test obj 0.0002, ineq max 0.2370, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.6218, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 0.2431, test obj 0.0002, ineq max 0.2429, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6047, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 0.2403, test obj 0.0002, ineq max 0.2401, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.6207, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 0.2375, test obj 0.0002, ineq max 0.2374, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.6364, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 0.2359, test obj 0.0002, ineq max 0.2357, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6196, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 0.2333, test obj 0.0002, ineq max 0.2331, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6349, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 0.2307, test obj 0.0002, ineq max 0.2306, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6499, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 0.2287, test obj 0.0002, ineq max 0.2285, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6335, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 0.2262, test obj 0.0002, ineq max 0.2261, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6482, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 0.2238, test obj 0.0002, ineq max 0.2237, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6626, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 0.2215, test obj 0.0002, ineq max 0.2213, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6767, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 0.2199, test obj 0.0002, ineq max 0.2197, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0000, eq mean 0.0000, p_g satisfication rate 98.6607, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 0.2176, test obj 0.0002, ineq max 0.2175, ineq mean 0.0002, ineq q_g num viol 0.0412, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6745, q_g satisfication rate 99.8822, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 0.2258, test obj 0.0002, ineq max 0.2256, ineq mean 0.0002, ineq q_g num viol 0.0408, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6589, q_g satisfication rate 99.8834, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# ...
# Test batch 68: test loss 0.2201, test obj 0.0002, ineq max 0.2200, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7578, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 0.2209, test obj 0.0002, ineq max 0.2207, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7347, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 0.2358, test obj 0.0002, ineq max 0.2356, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7123, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 0.2335, test obj 0.0002, ineq max 0.2334, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6905, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 0.2404, test obj 0.0002, ineq max 0.2403, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6693, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 0.2418, test obj 0.0002, ineq max 0.2416, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6487, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 0.2386, test obj 0.0002, ineq max 0.2384, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6667, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 0.2437, test obj 0.0002, ineq max 0.2435, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6466, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 0.2405, test obj 0.0002, ineq max 0.2404, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6642, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 0.2374, test obj 0.0002, ineq max 0.2373, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6813, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 0.2360, test obj 0.0002, ineq max 0.2359, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6619, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 0.2331, test obj 0.0002, ineq max 0.2329, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6786, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 0.2384, test obj 0.0002, ineq max 0.2382, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6596, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 0.2402, test obj 0.0002, ineq max 0.2400, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6411, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 0.2373, test obj 0.0002, ineq max 0.2371, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6575, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 0.2344, test obj 0.0002, ineq max 0.2343, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6735, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 0.2344, test obj 0.0002, ineq max 0.2342, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6555, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 0.2401, test obj 0.0002, ineq max 0.2400, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6379, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 0.2374, test obj 0.0002, ineq max 0.2372, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6535, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 0.2347, test obj 0.0002, ineq max 0.2345, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6688, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 0.2330, test obj 0.0002, ineq max 0.2328, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6517, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 0.2304, test obj 0.0002, ineq max 0.2302, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6667, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 0.2279, test obj 0.0002, ineq max 0.2277, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6813, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 0.2258, test obj 0.0002, ineq max 0.2257, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6646, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 0.2234, test obj 0.0002, ineq max 0.2232, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6790, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 0.2210, test obj 0.0002, ineq max 0.2209, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6930, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 0.2187, test obj 0.0002, ineq max 0.2185, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7068, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 0.2170, test obj 0.0002, ineq max 0.2169, ineq mean 0.0002, ineq q_g num viol 0.0000, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6905, q_g satisfication rate 100.0000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 0.2148, test obj 0.0002, ineq max 0.2146, ineq mean 0.0002, ineq q_g num viol 0.0412, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7040, q_g satisfication rate 99.8822, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 0.2229, test obj 0.0002, ineq max 0.2227, ineq mean 0.0002, ineq q_g num viol 0.0408, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.6880, q_g satisfication rate 99.8834, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 98: test loss 0.2206, test obj 0.0002, ineq max 0.2205, ineq mean 0.0002, ineq q_g num viol 0.0404, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7013, q_g satisfication rate 99.8846, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 99: test loss 0.2184, test obj 0.0002, ineq max 0.2183, ineq mean 0.0002, ineq q_g num viol 0.0400, ineq v_m num viol 0.0000, eq max 0.0001, eq mean 0.0000, p_g satisfication rate 98.7143, q_g satisfication rate 99.8857, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000

# %% [markdown]
# * Arithmetic mean

# %%
## Calculate the results of GraphLDE
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats_contingency[case]['test_obj_cost'])*10000, 4))
    print("GraphLDE eq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_mean']))
    print("GraphLDE eq. max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_max']))
    print("GraphLDE eq. active mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_mean']))
    print("GraphLDE eq. active max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_max']))
    print("GraphLDE eq. reactive mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_mean']))
    print("GraphLDE eq. reactive max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_max']))
    
    print("\n")
    print("GraphLDE ineq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_mean']))
    print("GraphLDE ineq. max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_max']))
    print("GraphLDE ineq. p_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_mean']))
    print("GraphLDE ineq. p_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_max']))
    print("GraphLDE ineq. q_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_mean']))
    print("GraphLDE ineq. q_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_max']))
    print("GraphLDE ineq. v_m mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_mean']))
    print("GraphLDE ineq. v_m max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_max']))
    print("GraphLDE ineq. line_l mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_mean']))
    print("GraphLDE ineq. line_l max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_max']))
    
    print("\n")
    print("GraphLDE p_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_p_g_satisfication rate (%)']))
    print("GraphLDE q_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_q_g_satisfication rate (%)']))
    print("GraphLDE v_m satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_v_m_satisfication rate (%)']))
    print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_Sf(%)']))
    print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_St(%)']))
    print("GraphLDE active eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_active_eq_satisfication rate (%)']))
    print("GraphLDE reactive eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_reactive_eq_satisfication rate (%)']))
    
    print("\n")
    # print("DeepLDE time (ms) <== average value for test dataset:", (test_stats['time']/1000)*1e3)
    print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
    print("\n")
# Out:
# Contingency  0
# GraphLDE obj. value for test samples:  1.5334
# GraphLDE eq. mean for test samples:  2.3401292e-06
# GraphLDE eq. max for test samples:  5.0368384e-05
# GraphLDE eq. active mean for test samples:  1.6569849e-06
# GraphLDE eq. active max for test samples:  2.3418677e-05
# GraphLDE eq. reactive mean for test samples:  3.0232734e-06
# GraphLDE eq. reactive max for test samples:  5.0368384e-05
#
#
# GraphLDE ineq. mean for test samples:  0.00021342082
# GraphLDE ineq. max for test samples:  0.22109032
# GraphLDE ineq. p_g mean for test samples:  0.0031583316
# GraphLDE ineq. p_g max for test samples:  0.22108318
# GraphLDE ineq. q_g mean for test samples:  2.9702804e-07
# GraphLDE ineq. q_g max for test samples:  7.133707e-06
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  98.685715
# GraphLDE q_g satisfication rate for test samples:  99.88571
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  100.0
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 17.397634983062744
#
#
# Contingency  1
# GraphLDE obj. value for test samples:  1.5335
# GraphLDE eq. mean for test samples:  2.3471798e-06
# GraphLDE eq. max for test samples:  5.214765e-05
# GraphLDE eq. active mean for test samples:  1.6664846e-06
# GraphLDE eq. active max for test samples:  2.259757e-05
# GraphLDE eq. reactive mean for test samples:  3.0278754e-06
# GraphLDE eq. reactive max for test samples:  5.214765e-05
#
#
# GraphLDE ineq. mean for test samples:  0.00021512115
# GraphLDE ineq. max for test samples:  0.22285733
# GraphLDE ineq. p_g mean for test samples:  0.003183584
# GraphLDE ineq. p_g max for test samples:  0.22285087
# GraphLDE ineq. q_g mean for test samples:  2.0951566e-07
# GraphLDE ineq. q_g max for test samples:  6.4384194e-06
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  98.685715
# GraphLDE q_g satisfication rate for test samples:  99.88571
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  100.0
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 17.397634983062744
#
#
# Contingency  2
# GraphLDE obj. value for test samples:  1.5333
# GraphLDE eq. mean for test samples:  2.3367345e-06
# GraphLDE eq. max for test samples:  5.182388e-05
# GraphLDE eq. active mean for test samples:  1.6527009e-06
# GraphLDE eq. active max for test samples:  2.3502043e-05
# GraphLDE eq. reactive mean for test samples:  3.020768e-06
# GraphLDE eq. reactive max for test samples:  5.180754e-05
#
#
# GraphLDE ineq. mean for test samples:  0.00021123722
# GraphLDE ineq. max for test samples:  0.21882536
# GraphLDE ineq. p_g mean for test samples:  0.003125953
# GraphLDE ineq. p_g max for test samples:  0.21881671
# GraphLDE ineq. q_g mean for test samples:  3.5767894e-07
# GraphLDE ineq. q_g max for test samples:  8.634627e-06
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  98.71429
# GraphLDE q_g satisfication rate for test samples:  99.88571
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  100.0
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 17.397634983062744
#
#
# Contingency  3
# GraphLDE obj. value for test samples:  1.5333
# GraphLDE eq. mean for test samples:  2.3382318e-06
# GraphLDE eq. max for test samples:  5.2138268e-05
# GraphLDE eq. active mean for test samples:  1.6667985e-06
# GraphLDE eq. active max for test samples:  2.3511688e-05
# GraphLDE eq. reactive mean for test samples:  3.0096655e-06
# GraphLDE eq. reactive max for test samples:  5.2138268e-05
#
#
# GraphLDE ineq. mean for test samples:  0.00021070009
# GraphLDE ineq. max for test samples:  0.21826883
# GraphLDE ineq. p_g mean for test samples:  0.0031179795
# GraphLDE ineq. p_g max for test samples:  0.21825853
# GraphLDE ineq. q_g mean for test samples:  3.824628e-07
# GraphLDE ineq. q_g max for test samples:  1.03028115e-05
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  98.71429
# GraphLDE q_g satisfication rate for test samples:  99.88571
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  100.0
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 17.397634983062744

# %% [markdown]
# * Harmonic mean

# %%
import statistics as st

## Calculate optimality gap
print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats['test_obj_cost'])*10000, 4))
print("GraphLDE eq. mean for test samples: ", st.harmonic_mean(test_stats['test_eq_mean'])) # print("LDF eq. mean for test samples: ", np.mean(test_stats['test_eq_mean']))
print("GraphLDE eq. max for test samples: ", st.harmonic_mean(test_stats['test_eq_max'])) # print("LDF eq. max for test samples: ", np.mean(test_stats['test_eq_max']))
print("GraphLDE eq. active mean for test samples: ", st.harmonic_mean(test_stats['test_eq_real_mean'])) # print("LDF eq. active mean for test samples: ", np.mean(test_stats['test_eq_real_mean']))
print("GraphLDE eq. active max for test samples: ", st.harmonic_mean(test_stats['test_eq_real_max'])) # print("LDF eq. active max for test samples: ", np.mean(test_stats['test_eq_real_max']))
print("GraphLDE eq. reactive mean for test samples: ", st.harmonic_mean(test_stats['test_eq_react_mean'])) # print("LDF eq. reactive mean for test samples: ", np.mean(test_stats['test_eq_react_mean']))
print("GraphLDE eq. reactive max for test samples: ", st.harmonic_mean(test_stats['test_eq_react_max'])) # print("LDF eq. reactive max for test samples: ", np.mean(test_stats['test_eq_react_max']))
print("\n")
print("GraphLDE ineq. mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_mean'])) # print("LDF ineq. mean for test samples: ", np.mean(test_stats['test_ineq_mean']))
print("GraphLDE ineq. max for test samples: ", st.harmonic_mean(test_stats['test_ineq_max'])) # print("LDF ineq. max for test samples: ", np.mean(test_stats['test_ineq_max']))
print("GraphLDE ineq. p_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_mean'])) # print("LDF ineq. p_g mean for test samples: ", np.mean(test_stats['test_ineq_p_g_mean']))
print("GraphLDE ineq. p_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_max'])) # print("LDF ineq. p_g max for test samples: ", np.mean(test_stats['test_ineq_p_g_max']))
print("GraphLDE ineq. q_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_mean'])) # print("LDF ineq. q_g mean for test samples: ", np.mean(test_stats['test_ineq_q_g_mean']))
print("GraphLDE ineq. q_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_max'])) # print("LDF ineq. q_g max for test samples: ", np.mean(test_stats['test_ineq_q_g_max']))
print("GraphLDE ineq. v_m mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_mean'])) # print("LDF ineq. v_m mean for test samples: ", np.mean(test_stats['test_ineq_v_m_mean']))
print("GraphLDE ineq. v_m max for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_max'])) # print("LDF ineq. v_m max for test samples: ", np.mean(test_stats['test_ineq_v_m_max']))
print("GraphLDE ineq. line_l mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_mean'])) # print("LDF ineq. line_l mean for test samples: ", np.mean(test_stats['test_ineq_line_l_mean']))
print("GraphLDE ineq. line_l max for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_max'])) # print("LDF ineq. line_l max for test samples: ", np.mean(test_stats['test_ineq_line_l_max']))
print("\n")

print("GraphLDE p_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_p_g_satisfication rate (%)'].reshape(-1))) # print("LDF p_g satisfication rate for test samples: ", np.mean(test_stats['test_p_g_satisfication rate (%)']))
print("GraphLDE q_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_q_g_satisfication rate (%)'].reshape(-1))) # print("LDF q_g satisfication rate for test samples: ", np.mean(test_stats['test_q_g_satisfication rate (%)']))
print("GraphLDE v_m satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_v_m_satisfication rate (%)'].reshape(-1))) # print("LDF v_m satisfication rate for test samples: ", np.mean(test_stats['test_v_m_satisfication rate (%)']))
print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_Sf(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']))
print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_St(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']))
print("GraphLDE active eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_active_eq_satisfication rate (%)'].reshape(-1))) # print("LDF active eq satisfication rate for test samples: ", np.mean(test_stats['test_active_eq_satisfication rate (%)']))
print("GraphLDE reactive eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_reactive_eq_satisfication rate (%)'].reshape(-1))) # print("LDF reactive eq satisfication rate for test samples: ", np.mean(test_stats['test_reactive_eq_satisfication rate (%)']))

print("\n")
print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
# Out:
# GraphLDE obj. value for test samples:  1310930.4
# GraphLDE eq. mean for test samples:  3.5897927e-05
# GraphLDE eq. max for test samples:  0.0016717056
# GraphLDE eq. active mean for test samples:  2.8573166e-05
# GraphLDE eq. active max for test samples:  0.0009564006
# GraphLDE eq. reactive mean for test samples:  4.3002572e-05
# GraphLDE eq. reactive max for test samples:  0.0015979278
#
#
# GraphLDE ineq. mean for test samples:  0.00036288172
# GraphLDE ineq. max for test samples:  0.64950836
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  0.0039722873
# GraphLDE ineq. q_g max for test samples:  0.48839676
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  99.89972
# GraphLDE q_g satisfication rate for test samples:  92.89624
# GraphLDE v_m satisfication rate for test samples:  99.99926
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.987434
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.992966
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 53.45505237579346
# /pscratch/sd/k/kjsong/conda/pytorch/2.8.0/lib/python3.12/statistics.py:593: RuntimeWarning: divide by zero encountered in scalar divide
#   T, total, count = _sum(w / x if w else 0 for w, x in zip(weights, data))
