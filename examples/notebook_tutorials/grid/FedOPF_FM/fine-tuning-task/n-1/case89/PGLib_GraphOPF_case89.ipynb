# %% [markdown]
# # N-1 Fine tuning task for FedOPF
#
# * Create N-1 contingencies: number & indicies of cut off lines and generators
#     * For the dataset, we only need to generate load because this is unsupervised way
# * Test on the zero-shot (i.e., just inference by using pretrained client/server/global model)
#     * **In 89 case, fine-tuning must be needed for both branch and generator contingency**

# %%
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cu121.html

# !pip install pypower
# !pip install pyrlu
# # !pip install conflictfree

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
# os.environ["PYTORCH_LINALG_WARNINGS"] = "0"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0"
# os.environ["CUDA_VISIBLE_DEVICES"] = '0, 1, 2, 3'

import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Device:', device)  # 출력결과: cuda
print('Count of using GPUs:', torch.cuda.device_count())   #출력결과: 1 (GPU #2 한개 사용하므로)
print('Current cuda device:', torch.cuda.current_device())  # 출력결과: 2 (GPU #2 의미)
# Out:
# Device: cuda
# Count of using GPUs: 1
# Current cuda device: 0

# %%
from utils.utils89_graphlde import ACOPFProblem
grid_data_path = './data/pglib_opf_case89.mat'
grid = ACOPFProblem(grid_filename=grid_data_path)
# Out:
# /global/u1/k/kjsong/FedOPF-APPFL/fine-tuning-task/n-1/case89/utils/utils89_graphlde.py:88: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   self.slackva = torch.tensor([np.deg2rad(self.ppc['bus'][self.slack, idx_bus.VA])],

# %%
component="gen" # "gen" or "branch"
num_cases = 2
contingencies = grid.check_contingencies(component=component, num_cases=num_cases)

contingencies['contingencies'] = [x for x in contingencies['contingencies'] if x]
acopf_contingencies = []
for c in range(contingencies['num_cases']):
    acopf_contingencies += [ACOPFProblem(grid_filename=grid_data_path, contingencies=contingencies['contingencies'][c], component=component)] # update the grid components' values from modified ppc data based on the contingencies 

    # Put all variables in "data" to the cuda.
    acopf_contingencies[-1]._device = device
    for attr in dir(acopf_contingencies[-1]):
        var = getattr(acopf_contingencies[-1], attr)
        if not callable(var) and not attr.startswith("__") and torch.is_tensor(var):
            try:
                setattr(acopf_contingencies[-1], attr, var.to(device))
            except AttributeError:
                pass
# Out:
# 11
# 210
#
# Converged in 0.69 seconds
# Objective Function Value = 131834.31 $/hr
# ================================================================================
# |     System Summary                                                           |
# ================================================================================
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses             89     Total Gen Capacity    8721.2       -1392.5 to 3974.4
# Generators        11     On-line Capacity      8721.2       -1392.5 to 3974.4
# Committed Gens    11     Generation (actual)   5825.0            2653.8
# Loads             35     Load                  5727.9            1374.9
#   Fixed           35       Fixed               5727.9            1374.9
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts            44     Shunt (inj)             -5.7             567.9
# Branches         210     Losses (I^2 * Z)        91.42           1846.80
# Transformers      50     Branch Charging (inj)     -                0.0
# Inter-ties         0     Total Inter-tie Flow     0.0               0.0
# Areas              1
#
#                           Minimum                      Maximum
#                  -------------------------  --------------------------------
# Voltage Magnitude   0.975 p.u. @ bus 61         1.100 p.u. @ bus 27
# Voltage Angle     -12.35 deg   @ bus 83        21.81 deg   @ bus 79
# P Losses (I^2*R)             -                 14.29 MW    @ line 47-67
# Q Losses (I^2*X)             -                238.47 MVAr  @ line 67-79
# Lambda P          -77.75 $/MWh @ bus 79        52.97 $/MWh @ bus 34
# Lambda Q           -5.27 $/MWh @ bus 49        20.46 $/MWh @ bus 79
#
# ================================================================================
# |     Bus Data                                                                 |
# ================================================================================
#  Bus      Voltage          Generation             Load          Lambda($/MVA-hr)
#   #   Mag(pu) Ang(deg)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)     P        Q
# ----- ------- --------  --------  --------  --------  --------  -------  -------
#     0  1
#
# ================================================================================
# |     Branch Flow Constraints                                                  |
# ================================================================================
# Brnch   From     "From" End        Limit       "To" End        To
#   #     Bus   |Sf| mu    |Sf|     |Smax|     |St|    |St| mu   Bus
# -----  -----  -------  --------  --------  --------  -------  -----
#   33     34      -      318.97    319.00    319.00    87.081    49
#   94     47   124.686  1303.00   1303.00   1300.60      -       67
# change to load bus!
# change to load bus!

# %%
contingencies
# Out:
# {'contingencies': [{'gen': 6}, {'gen': 9}], 'num_cases': 2}

# %%
from pypower import idx_bus, idx_gen, idx_brch
import numpy as np
import torch_geometric
from torch_geometric.data import Data 
from models.Edge_GNN_solver import Edge_GNNSolver
import copy

# Load data generation (unsupervised)
pd_base = grid.ppc['bus'][:,idx_bus.PD] / grid.baseMVA.item()
qd_base = grid.ppc['bus'][:,idx_bus.QD] / grid.baseMVA.item()
num_data = 200
perturb = (1.0 + np.random.uniform(-0.2, 0.05, size=(num_data, grid.nbus)))

# data sample from uniform distribution
pd_samples = torch.from_numpy(pd_base * perturb).float()
qd_samples = torch.from_numpy(qd_base * perturb).float()
demand = pd_samples + 1j*qd_samples

# %%
# Graph data representation
graph_dataset_contingency = []
graph_dataset_contingency_statics = []

# Model config
train_config = {
    'probType': 'acopf',
    'useCompl': True, # boolean type: whether to use completion (DC3, DeepLDE 기술)

    # GNN model parameters
    'n_gnn_layers': 3,
    'nfeature_dim': 2, # input dim
    'efeature_dim': 4, # edge feature dim 
    'hidden_dim': 40,
    'dropout_rate': 0.1,
    'K': 10, # 6 # only for TAGConv or ChebConv and GATConv (as multi-head)

    # DeepLDE hyperparameters
    'epochs': 40, # 10 (GPU RTX 4090), 8 (GPU A100)
    'batchSize': 5, # 6, (8) (GPU RTX 4090; GPU 다운 에러 발생..), 16 (GPU A100)
    'lr': 1e-2, # 1e-3
    'lr_w': 1e-2, # 1e-3
    'weight_decay': 1e-3, # 1e-5,

    # LDF parameters
    'rho_init': 0.1, # 0.01  
    's_init': 0.1,
    'p_iter_max': 10,
    'warmup_iter': 40, # 20, # 0 for non-warmup start cases
    'corrEps': 1e-4, # float type: correction procedure tolerance
}

# Models
contingency_models = []

for case in range(len(acopf_contingencies)):
    node_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus, 2))
    node_mask_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus))
    for s in range(node_feat_x.shape[0]):
        node_feat_x[s,:,0] = np.real(demand[s,:])
        node_feat_x[s,:,1] = np.imag(demand[s,:])
        node_mask_x[s,acopf_contingencies[case].spv] = 1
        # node_mask_x[s,self.pv] = 1
    
    edge_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nl, 6))
    for s in range(edge_feat_x.shape[0]):
        edge_feat_x[s,:,0] = acopf_contingencies[case].ppc['branch'][:, idx_brch.F_BUS]
        edge_feat_x[s,:,1] = acopf_contingencies[case].ppc['branch'][:, idx_brch.T_BUS]
        edge_feat_x[s,:,2] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_R]
        edge_feat_x[s,:,3] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_X]
        edge_feat_x[s,:,4] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_B]
        
        br_ratea_feat = (acopf_contingencies[case].ppc['branch'][:, idx_brch.RATE_A] / acopf_contingencies[case].baseMVA)
        # br_ratea_feat[br_ratea_feat == 0] = np.Inf
        edge_feat_x[s,:,5] = br_ratea_feat

    node_feat_x = torch.tensor(node_feat_x[:,:,:], dtype=torch.get_default_dtype())
    node_mask_x = torch.tensor(node_mask_x[:,:], dtype=torch.get_default_dtype())
    edge_feat_x = torch.tensor(edge_feat_x[:,:,:], dtype=torch.get_default_dtype())
    pyg_data_list = []
    for i in range(demand.shape[0]):
        pyg_data_list += [Data(
            x=node_feat_x[i,:,:],
            node_mask=node_mask_x[i,:].to(torch.bool),
            edge_index=edge_feat_x[i, :, 0:2].T.to(torch.long),
            edge_attr=edge_feat_x[i, :, 2:],) # R,X,B,RateA
            ]
    
    graph_dataset_contingency += [pyg_data_list]
    
    node_dataset = torch.zeros((acopf_contingencies[case].nbus*len(pyg_data_list),2))
    edge_dataset = torch.zeros((acopf_contingencies[case].nl*len(pyg_data_list),4))
    for (i,data) in enumerate(pyg_data_list):
        node_dataset[acopf_contingencies[case].nbus*i:acopf_contingencies[case].nbus*(i+1),:] = data.x
        edge_dataset[acopf_contingencies[case].nl*i:acopf_contingencies[case].nl*(i+1),:] = data.edge_attr
    
    node_means = node_dataset.mean(axis=0, keepdims = True)
    node_stds = node_dataset.std(axis=0, keepdims = True)
    edge_means = edge_dataset.mean(axis=0, keepdims = True)
    edge_stds = edge_dataset.std(axis=0, keepdims = True)

    graph_dataset_contingency_statics += [[node_means.to(dtype=torch.get_default_dtype()),
                                          node_stds.to(dtype=torch.get_default_dtype()),
                                          edge_means.to(dtype=torch.get_default_dtype()),
                                          edge_stds.to(dtype=torch.get_default_dtype())]]

    data_loader = torch_geometric.loader.DataLoader(pyg_data_list, batch_size=1, shuffle=False, drop_last=True)
    solver_net = Edge_GNNSolver(acopf_contingencies[case], train_config)
    contingency_models += [solver_net]

    print(solver_net)
# Out:
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=1320, out_features=21, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=1320, out_features=21, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# /tmp/ipykernel_376984/2693771600.py:40: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,0] = np.real(demand[s,:])
# /tmp/ipykernel_376984/2693771600.py:41: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,1] = np.imag(demand[s,:])

# %% [markdown]
# * Load pretrained GraphOPF model

# %%
pretrained_client = torch.load("./models/pretrained_models/client/checkpoint_Client5.pth", weights_only=False, map_location=device)
# pretrained_server = torch.load("./models/pretrained_models/server/checkpoint_Server_0.pth", weights_only=False, map_location=device)
# pretrained_global = torch.load("./models/pretrained_models/global/checkpoint_Global.pth", weights_only=False, map_location=device)

# %%
for contingency_model in contingency_models:
    if component == 'gen':
        print("Generator contingency")
        # Dimension reduction for N-1 contingency
        new_row = contingency_model.flatten.weight.shape[0] 
        new_col = contingency_model.flatten.weight.shape[1]
        old_row = pretrained_client['flatten.weight'].shape[0]
        old_col = pretrained_client['flatten.weight'].shape[1]
    
        pretrained_flatten_weight = copy.deepcopy(pretrained_client['flatten.weight'])
        pretrained_flatten_bias = copy.deepcopy(pretrained_client['flatten.bias'])
        
        # Way 1
        row_norm = torch.norm(pretrained_flatten_weight, dim=1)
        rows_removed = torch.argsort(row_norm)[:old_row - new_row]
        col_norm = torch.norm(pretrained_flatten_weight, dim=0)
        cols_removed = torch.argsort(col_norm)[:old_col - new_col]
        
        row_mask = torch.ones(pretrained_flatten_weight.size(0), dtype=torch.bool, device=device)
        row_mask[rows_removed] = False
        col_mask = torch.ones(pretrained_flatten_weight.size(1), dtype=torch.bool, device=device)
        col_mask[cols_removed] = False

        shrinked_weight = pretrained_flatten_weight[row_mask][:, col_mask]
        shrinked_bias = pretrained_flatten_bias[row_mask] # corresponding to the flatten.weight

        # # Way 2
        # shrinked_weight = pretrained_flatten_weight[(old_row - new_row):, (old_col - new_col):]
        # shrinked_bias = pretrained_flatten_bias[(old_row - new_row):] # corresponding to the flatten.weight

        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()
        
        layer_names = list(target_state_dict.keys())
        for name in layer_names[:-2]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()
            
        for name in layer_names[-2:]:
            if 'weight' in name:
                # print('weight load')
                target_state_dict[name] = shrinked_weight
            elif 'bias' in name:
                # print('bias load')
                target_state_dict[name] = shrinked_bias
    
    elif component == 'branch':
        print("Branch contingency")
        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()

        layer_names = list(target_state_dict.keys())
        for name in layer_names[:]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()

    contingency_model.load_state_dict(target_state_dict)

    # Freezing the half-GNN layers
    for i, (name, param) in enumerate(contingency_model.named_parameters()):
        if i <= 32: # 5, 10, 21
            # print(name)
            param.requires_grad = False
        else:
            print(name)
            param.requires_grad = True
# Out:
# Generator contingency
# flatten.weight
# flatten.bias
# Generator contingency
# flatten.weight
# flatten.bias

# %% [markdown]
# * Fine-tuning (for generator contingency)

# %%
import torch.optim as optim
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

# Set the linear algebra solver(?)
torch._C._set_linalg_preferred_backend(torch._C._LinalgBackend.Cusolver) # torch._C._LinalgBackend.Magma, torch._C._LinalgBackend.Cusolver
# torch._C._get_linalg_preferred_backend() 

# stats_contingency = []
for case in range(len(acopf_contingencies)):
# for case in range(1):
    print("Contingency ", case)
    stats = {}
    
    # NOTE: LDF parameters.
    LagM_sp_gen = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_gen = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_bus = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    warmup_iter = train_config["warmup_iter"] # the warmup period: the NN is trained with an additional inner iteration before the first outer iteration.
    rho_init = train_config["rho_init"]
    
    rho = rho_init
    
    rho_iter = 0
    s_iter = 0
    
    p_iter_max = train_config["p_iter_max"]
    p_iter_max_sum = p_iter_max
    
    d = 0 # 0 for static case otherwise use 5"
    beta = 0 # 0.001 # 0 for static case otherwise use 1
    
    lr_w = train_config["lr_w"] # 이거 증가해도 되지 않을지?
    lr = train_config["lr"]
    print_interval = 1
    eps_converge = 1e-4
    
    contingency_models[case] = contingency_models[case].to(device)
    train_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][:20], batch_size=train_config['batchSize'], shuffle=True, drop_last=True)
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    train_loss_list = []
    train_start_time = time.time()
    for i in range(train_config["epochs"]):
        epoch_stats = {}
        ################### TRAINING PHASE ###################
        solver_net.train()
        if i<warmup_iter:
            ######### WARM-UP PERIOD #########
            if i == 0:
                solver_opt = optim.Adam(contingency_models[case].parameters(), lr=lr_w) # this will be reinitalized after warmup stage
                print("Warmup start!")
    
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                # start_time = time.time()
                solver_opt.zero_grad()
    
                # DNN + NR (equality constraint)
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, train_obj, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        else:
            if i == warmup_iter:
                print("Warmup ended!")
                # data.ref_freedom = False
    
                # ineq_lag_flag = True # for the first warmup end epoch, consider lag. multipliers update of ineq.
            # elif (i - warmup_iter)%ineq_lag_flag_trigger == 0:
            #     # print("Doing test... continue this case..")
            #     print("consider lagrangian multipliers update for ineq. constraints!")
            #     ineq_lag_flag = True
            # else:
            #     ineq_lag_flag = False
    
            # for every (updated) p_iter_max_sum time.
            if (i - warmup_iter)%p_iter_max_sum == 0:
                ######### Outer Interation: calculate step size of lagrangian multipliers update #########
                if i> warmup_iter:
                    print("current epoch %d || p_iter_max updated : %d -> %d" %(i, p_iter_max, p_iter_max + d))
                    # s = s_init * (1/(1+beta*(s_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    # s_iter += 1
                    # print("mu iter updated : %d -> %d" %(s_iter-1, s_iter))
    
                    rho = rho_init * (1/(1+beta*(rho_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    rho_iter += 1
                    print("rho iter updated : %d -> %d" %(rho_iter-1, rho_iter))
                    p_iter_max = p_iter_max + d
                    p_iter_max_sum += p_iter_max
    
                with torch.no_grad():
                    print("Lambda updated at %d epoch" %i)
                    contingency_models[case].eval()
                    for Xtrain in train_loader:
                        Xtrain = Xtrain.to(device)
                        #solver_opt.zero_grad()
                        Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                        # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                        # LagM += rho*ineq_violation(data, Xtrain.x, Yhat_train) # Update the lagrangian multiplier.
                        LagM_sp_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[:2] # Update the lagrangian multiplier.
                        LagM_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2:2+2*acopf_contingencies[case].ng] # Update the lagrangian multiplier.
                        LagM_bus += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus] # Update the lagrangian multiplier.
                        LagM_line += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:] # Update the lagrangian multiplier.
                
                ## Does this stablize the learning process much better?
                LagM_sp_gen = (LagM_sp_gen/len(train_loader))
                LagM_gen = (LagM_gen/len(train_loader))
                LagM_bus = (LagM_bus/len(train_loader))
                LagM_line = (LagM_line/len(train_loader))
    
                # solver_opt = optim.Adam(contingency_models[0].parameters(), lr = lr)
    
            contingency_models[case].train()
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                solver_opt.zero_grad()
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, obj_train, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        if (i == 0) or (i%print_interval == 0):
            print(
                'Epoch {}: train loss {:.4f}, train obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq p_g num viol {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, ineq line_theraml num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}'.format(
                    i, np.mean(epoch_stats['train_loss']), np.mean(epoch_stats['train_obj']), np.mean(epoch_stats['train_ineq_max']), np.mean(epoch_stats['train_ineq_mean']),
                    np.mean(epoch_stats['train_ineq_p_g_num_viol_0']), np.mean(epoch_stats['train_ineq_q_g_num_viol_0']), np.mean(epoch_stats['train_ineq_v_m_num_viol_0']), np.mean(epoch_stats['train_ineq_line_thermal_num_viol_0']),
                    np.mean(epoch_stats['train_eq_max']), np.mean(epoch_stats['train_eq_mean'])))
        
        train_loss_list.append(np.mean(epoch_stats['train_loss']))
        # valid_eval_list.append(np.mean(epoch_stats['valid_eval']))
    # stats_contingency += []
    print("\n")
train_end_time = time.time()
total_train_time = train_end_time - train_start_time
# Out:
# Contingency  0
# Warmup start!
# Epoch 0: train loss 316.1033, train obj 10.6757, ineq max 95.5341, ineq mean 0.4910, ineq p_g num viol 1.0000, ineq q_g num viol 7.4000, ineq v_m num viol 0.8000, ineq line_theraml num viol 4.3500, eq max 0.0027, eq mean 0.0001
# Epoch 1: train loss 150.7980, train obj 10.7430, ineq max 49.1238, ineq mean 0.2252, ineq p_g num viol 1.0000, ineq q_g num viol 6.7000, ineq v_m num viol 2.1500, ineq line_theraml num viol 3.2500, eq max 0.0029, eq mean 0.0001
# Epoch 2: train loss 75.6852, train obj 10.7885, ineq max 24.0128, ineq mean 0.1043, ineq p_g num viol 1.0000, ineq q_g num viol 7.5500, ineq v_m num viol 4.4500, ineq line_theraml num viol 2.0000, eq max 0.0030, eq mean 0.0001
# Epoch 3: train loss 48.0251, train obj 10.8174, ineq max 15.0773, ineq mean 0.0598, ineq p_g num viol 1.0000, ineq q_g num viol 5.1000, ineq v_m num viol 5.0000, ineq line_theraml num viol 1.2500, eq max 0.0030, eq mean 0.0001
# Epoch 4: train loss 40.1486, train obj 10.8360, ineq max 13.3417, ineq mean 0.0471, ineq p_g num viol 1.0000, ineq q_g num viol 4.6500, ineq v_m num viol 5.0000, ineq line_theraml num viol 0.9000, eq max 0.0030, eq mean 0.0001
# Epoch 5: train loss 38.2438, train obj 10.8486, ineq max 12.7588, ineq mean 0.0440, ineq p_g num viol 1.0000, ineq q_g num viol 4.8500, ineq v_m num viol 5.0000, ineq line_theraml num viol 0.8000, eq max 0.0030, eq mean 0.0001
# Epoch 6: train loss 36.9089, train obj 10.8572, ineq max 12.2862, ineq mean 0.0419, ineq p_g num viol 1.0000, ineq q_g num viol 4.9500, ineq v_m num viol 5.0000, ineq line_theraml num viol 0.7500, eq max 0.0031, eq mean 0.0001
# Epoch 7: train loss 35.7801, train obj 10.8660, ineq max 12.2065, ineq mean 0.0401, ineq p_g num viol 1.0000, ineq q_g num viol 4.9000, ineq v_m num viol 5.0000, ineq line_theraml num viol 0.7000, eq max 0.0032, eq mean 0.0002
# Epoch 8: train loss 34.9311, train obj 10.8723, ineq max 12.1603, ineq mean 0.0387, ineq p_g num viol 1.0000, ineq q_g num viol 4.9500, ineq v_m num viol 5.1000, ineq line_theraml num viol 0.7000, eq max 0.0033, eq mean 0.0002
# Epoch 9: train loss 34.3395, train obj 10.8790, ineq max 12.1291, ineq mean 0.0377, ineq p_g num viol 1.0000, ineq q_g num viol 5.3000, ineq v_m num viol 5.1500, ineq line_theraml num viol 0.7000, eq max 0.0033, eq mean 0.0002
# Epoch 10: train loss 33.5782, train obj 10.8881, ineq max 12.0737, ineq mean 0.0365, ineq p_g num viol 1.0000, ineq q_g num viol 5.1000, ineq v_m num viol 5.2500, ineq line_theraml num viol 1.0000, eq max 0.0033, eq mean 0.0002
# Epoch 11: train loss 32.9032, train obj 10.8987, ineq max 12.0263, ineq mean 0.0354, ineq p_g num viol 1.0000, ineq q_g num viol 5.0000, ineq v_m num viol 5.2500, ineq line_theraml num viol 0.8000, eq max 0.0033, eq mean 0.0002
# Epoch 12: train loss 32.2407, train obj 10.9122, ineq max 11.9643, ineq mean 0.0343, ineq p_g num viol 1.0000, ineq q_g num viol 4.7500, ineq v_m num viol 5.3500, ineq line_theraml num viol 0.9000, eq max 0.0033, eq mean 0.0002
# Epoch 13: train loss 31.5211, train obj 10.9274, ineq max 11.8974, ineq mean 0.0331, ineq p_g num viol 1.0000, ineq q_g num viol 4.2500, ineq v_m num viol 5.4000, ineq line_theraml num viol 0.9000, eq max 0.0033, eq mean 0.0002
# Epoch 14: train loss 30.6581, train obj 10.9492, ineq max 11.8076, ineq mean 0.0317, ineq p_g num viol 1.0000, ineq q_g num viol 4.0500, ineq v_m num viol 5.5500, ineq line_theraml num viol 0.9000, eq max 0.0033, eq mean 0.0002
# Epoch 15: train loss 29.5125, train obj 10.9795, ineq max 11.6698, ineq mean 0.0298, ineq p_g num viol 1.0000, ineq q_g num viol 5.0500, ineq v_m num viol 5.6000, ineq line_theraml num viol 1.1000, eq max 0.0034, eq mean 0.0002
# Epoch 16: train loss 28.3623, train obj 11.0336, ineq max 11.4422, ineq mean 0.0279, ineq p_g num viol 1.0000, ineq q_g num viol 4.7500, ineq v_m num viol 5.6000, ineq line_theraml num viol 1.2000, eq max 0.0034, eq mean 0.0002
# Epoch 17: train loss 27.4997, train obj 11.1229, ineq max 11.0581, ineq mean 0.0263, ineq p_g num viol 1.0000, ineq q_g num viol 3.5000, ineq v_m num viol 5.7000, ineq line_theraml num viol 1.2000, eq max 0.0034, eq mean 0.0002
# Epoch 18: train loss 26.6163, train obj 11.3054, ineq max 10.2707, ineq mean 0.0246, ineq p_g num viol 1.0000, ineq q_g num viol 3.0000, ineq v_m num viol 5.7000, ineq line_theraml num viol 1.2000, eq max 0.0034, eq mean 0.0002
# Epoch 19: train loss 25.3116, train obj 11.6080, ineq max 8.9323, ineq mean 0.0220, ineq p_g num viol 1.0000, ineq q_g num viol 2.5000, ineq v_m num viol 5.7000, ineq line_theraml num viol 1.2000, eq max 0.0034, eq mean 0.0002
# Epoch 20: train loss 23.0669, train obj 12.1715, ineq max 6.5172, ineq mean 0.0175, ineq p_g num viol 1.0000, ineq q_g num viol 2.8000, ineq v_m num viol 5.6500, ineq line_theraml num viol 1.2000, eq max 0.0034, eq mean 0.0002
# Epoch 21: train loss 20.2285, train obj 13.0684, ineq max 3.5636, ineq mean 0.0115, ineq p_g num viol 0.6000, ineq q_g num viol 2.9500, ineq v_m num viol 5.7000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0002
# Epoch 22: train loss 19.4941, train obj 14.0312, ineq max 2.5543, ineq mean 0.0088, ineq p_g num viol 0.0500, ineq q_g num viol 2.9500, ineq v_m num viol 5.6500, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0002
# Epoch 23: train loss 19.4974, train obj 14.2468, ineq max 2.4014, ineq mean 0.0084, ineq p_g num viol 0.0000, ineq q_g num viol 3.5500, ineq v_m num viol 5.7000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0002
# Epoch 24: train loss 18.9780, train obj 13.9721, ineq max 2.3509, ineq mean 0.0080, ineq p_g num viol 0.0000, ineq q_g num viol 3.4000, ineq v_m num viol 5.6000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 25: train loss 18.3400, train obj 13.4797, ineq max 2.3341, ineq mean 0.0078, ineq p_g num viol 0.2000, ineq q_g num viol 2.5500, ineq v_m num viol 5.6000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0002
# Epoch 26: train loss 18.3117, train obj 13.1704, ineq max 2.5448, ineq mean 0.0083, ineq p_g num viol 0.5500, ineq q_g num viol 2.1000, ineq v_m num viol 5.6500, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 27: train loss 18.0382, train obj 13.2462, ineq max 2.3438, ineq mean 0.0077, ineq p_g num viol 0.2500, ineq q_g num viol 2.0000, ineq v_m num viol 5.5000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 28: train loss 17.8152, train obj 13.3463, ineq max 2.1978, ineq mean 0.0072, ineq p_g num viol 0.2000, ineq q_g num viol 1.6500, ineq v_m num viol 5.5500, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 29: train loss 17.6439, train obj 13.2861, ineq max 2.1459, ineq mean 0.0070, ineq p_g num viol 0.1000, ineq q_g num viol 1.7000, ineq v_m num viol 5.6000, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 30: train loss 17.5702, train obj 13.2288, ineq max 2.1547, ineq mean 0.0070, ineq p_g num viol 0.1500, ineq q_g num viol 1.5500, ineq v_m num viol 5.5500, ineq line_theraml num viol 1.2000, eq max 0.0035, eq mean 0.0001
# Epoch 31: train loss 17.4017, train obj 13.0978, ineq max 2.1711, ineq mean 0.0069, ineq p_g num viol 0.2500, ineq q_g num viol 1.6500, ineq v_m num viol 5.5000, ineq line_theraml num viol 0.9000, eq max 0.0035, eq mean 0.0001
# Epoch 32: train loss 17.3528, train obj 13.0056, ineq max 2.2649, ineq mean 0.0070, ineq p_g num viol 0.3500, ineq q_g num viol 1.3000, ineq v_m num viol 5.5500, ineq line_theraml num viol 0.9000, eq max 0.0035, eq mean 0.0001
# Epoch 33: train loss 17.2450, train obj 13.0064, ineq max 2.1598, ineq mean 0.0068, ineq p_g num viol 0.3500, ineq q_g num viol 1.0500, ineq v_m num viol 5.4500, ineq line_theraml num viol 0.9000, eq max 0.0035, eq mean 0.0001
# Epoch 34: train loss 17.2454, train obj 13.0220, ineq max 2.1835, ineq mean 0.0068, ineq p_g num viol 0.2000, ineq q_g num viol 1.3000, ineq v_m num viol 5.4500, ineq line_theraml num viol 0.8000, eq max 0.0035, eq mean 0.0002
# Epoch 35: train loss 17.2373, train obj 13.0173, ineq max 2.1703, ineq mean 0.0068, ineq p_g num viol 0.2000, ineq q_g num viol 1.2500, ineq v_m num viol 5.6500, ineq line_theraml num viol 0.6000, eq max 0.0035, eq mean 0.0001
# Epoch 36: train loss 17.1716, train obj 13.0014, ineq max 2.1336, ineq mean 0.0067, ineq p_g num viol 0.1500, ineq q_g num viol 1.5000, ineq v_m num viol 5.6000, ineq line_theraml num viol 0.6000, eq max 0.0035, eq mean 0.0001
# Epoch 37: train loss 17.1709, train obj 12.9328, ineq max 2.2190, ineq mean 0.0068, ineq p_g num viol 0.1500, ineq q_g num viol 1.2500, ineq v_m num viol 5.5000, ineq line_theraml num viol 0.6000, eq max 0.0035, eq mean 0.0001
# Epoch 38: train loss 17.1615, train obj 12.8520, ineq max 2.2931, ineq mean 0.0069, ineq p_g num viol 0.3000, ineq q_g num viol 1.2000, ineq v_m num viol 5.5000, ineq line_theraml num viol 0.6000, eq max 0.0035, eq mean 0.0001
# Epoch 39: train loss 17.1868, train obj 12.8137, ineq max 2.3132, ineq mean 0.0070, ineq p_g num viol 0.3500, ineq q_g num viol 1.2500, ineq v_m num viol 5.5000, ineq line_theraml num viol 0.6000, eq max 0.0035, eq mean 0.0001
#
#
# Contingency  1
# Warmup start!
# Epoch 0: train loss 432.0521, train obj 9.1661, ineq max 136.0457, ineq mean 0.6799, ineq p_g num viol 1.0000, ineq q_g num viol 8.6500, ineq v_m num viol 1.0000, ineq line_theraml num viol 2.7000, eq max 0.0031, eq mean 0.0001
# Epoch 1: train loss 48.2017, train obj 9.2452, ineq max 12.7308, ineq mean 0.0626, ineq p_g num viol 1.0000, ineq q_g num viol 7.3000, ineq v_m num viol 1.0000, ineq line_theraml num viol 0.4000, eq max 0.0031, eq mean 0.0001
# Epoch 2: train loss 42.5578, train obj 9.2986, ineq max 11.4836, ineq mean 0.0535, ineq p_g num viol 1.0000, ineq q_g num viol 7.6500, ineq v_m num viol 2.3000, ineq line_theraml num viol 0.4000, eq max 0.0030, eq mean 0.0001
# Epoch 3: train loss 48.4872, train obj 9.3344, ineq max 11.0395, ineq mean 0.0629, ineq p_g num viol 0.9500, ineq q_g num viol 6.4500, ineq v_m num viol 3.3000, ineq line_theraml num viol 0.4000, eq max 0.0030, eq mean 0.0001
# Epoch 4: train loss 54.9668, train obj 9.3670, ineq max 11.9362, ineq mean 0.0733, ineq p_g num viol 0.9500, ineq q_g num viol 7.5500, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.4000, eq max 0.0030, eq mean 0.0001
# Epoch 5: train loss 58.8728, train obj 9.3883, ineq max 12.7997, ineq mean 0.0796, ineq p_g num viol 0.9500, ineq q_g num viol 7.6000, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.5500, eq max 0.0030, eq mean 0.0001
# Epoch 6: train loss 57.1874, train obj 9.4086, ineq max 12.4215, ineq mean 0.0768, ineq p_g num viol 0.9000, ineq q_g num viol 7.6000, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.4000, eq max 0.0031, eq mean 0.0001
# Epoch 7: train loss 54.0434, train obj 9.4262, ineq max 11.3969, ineq mean 0.0717, ineq p_g num viol 0.9000, ineq q_g num viol 7.6000, ineq v_m num viol 4.1000, ineq line_theraml num viol 0.4000, eq max 0.0031, eq mean 0.0001
# Epoch 8: train loss 48.7942, train obj 9.4456, ineq max 9.7220, ineq mean 0.0633, ineq p_g num viol 0.9000, ineq q_g num viol 7.4000, ineq v_m num viol 4.1000, ineq line_theraml num viol 0.4000, eq max 0.0031, eq mean 0.0001
# Epoch 9: train loss 41.8756, train obj 9.4714, ineq max 8.4173, ineq mean 0.0521, ineq p_g num viol 0.9000, ineq q_g num viol 7.2000, ineq v_m num viol 4.1500, ineq line_theraml num viol 0.4000, eq max 0.0031, eq mean 0.0001
# Epoch 10: train loss 33.6963, train obj 9.5109, ineq max 7.2403, ineq mean 0.0389, ineq p_g num viol 0.9000, ineq q_g num viol 6.8500, ineq v_m num viol 4.1000, ineq line_theraml num viol 0.5000, eq max 0.0032, eq mean 0.0001
# Epoch 11: train loss 24.8677, train obj 9.5785, ineq max 4.9819, ineq mean 0.0246, ineq p_g num viol 0.8500, ineq q_g num viol 7.2500, ineq v_m num viol 4.1000, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 12: train loss 18.6685, train obj 9.6858, ineq max 4.1300, ineq mean 0.0144, ineq p_g num viol 0.7500, ineq q_g num viol 4.8000, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 13: train loss 18.0688, train obj 9.8600, ineq max 3.9113, ineq mean 0.0132, ineq p_g num viol 0.6500, ineq q_g num viol 4.3000, ineq v_m num viol 3.9000, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 14: train loss 17.7825, train obj 10.0848, ineq max 3.7853, ineq mean 0.0124, ineq p_g num viol 0.3500, ineq q_g num viol 3.6000, ineq v_m num viol 3.9000, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 15: train loss 17.0497, train obj 10.2394, ineq max 3.6805, ineq mean 0.0109, ineq p_g num viol 0.1500, ineq q_g num viol 3.3000, ineq v_m num viol 3.9000, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 16: train loss 16.7542, train obj 10.2760, ineq max 3.6338, ineq mean 0.0104, ineq p_g num viol 0.1500, ineq q_g num viol 2.9000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 17: train loss 16.5317, train obj 10.2289, ineq max 3.5802, ineq mean 0.0101, ineq p_g num viol 0.2000, ineq q_g num viol 2.7500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 18: train loss 16.4363, train obj 10.1462, ineq max 3.5153, ineq mean 0.0101, ineq p_g num viol 0.3000, ineq q_g num viol 2.5500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 19: train loss 16.2981, train obj 10.0979, ineq max 3.4760, ineq mean 0.0100, ineq p_g num viol 0.2500, ineq q_g num viol 1.7500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 20: train loss 16.2434, train obj 10.0586, ineq max 3.4107, ineq mean 0.0099, ineq p_g num viol 0.3500, ineq q_g num viol 2.0000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0033, eq mean 0.0001
# Epoch 21: train loss 16.1407, train obj 10.0374, ineq max 3.3618, ineq mean 0.0098, ineq p_g num viol 0.3500, ineq q_g num viol 2.0000, ineq v_m num viol 3.9500, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 22: train loss 16.0089, train obj 10.0475, ineq max 3.2883, ineq mean 0.0096, ineq p_g num viol 0.3500, ineq q_g num viol 1.9000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 23: train loss 15.8716, train obj 10.0850, ineq max 3.1736, ineq mean 0.0093, ineq p_g num viol 0.2500, ineq q_g num viol 1.7500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 24: train loss 15.7212, train obj 10.1030, ineq max 3.0675, ineq mean 0.0090, ineq p_g num viol 0.1500, ineq q_g num viol 1.9500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 25: train loss 15.6057, train obj 10.0495, ineq max 2.9977, ineq mean 0.0089, ineq p_g num viol 0.3000, ineq q_g num viol 1.9000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 26: train loss 15.4572, train obj 10.0309, ineq max 2.9170, ineq mean 0.0087, ineq p_g num viol 0.2500, ineq q_g num viol 1.8000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0032, eq mean 0.0001
# Epoch 27: train loss 15.3015, train obj 10.0205, ineq max 2.8156, ineq mean 0.0085, ineq p_g num viol 0.2000, ineq q_g num viol 1.8500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0031, eq mean 0.0001
# Epoch 28: train loss 15.1316, train obj 10.0008, ineq max 2.7341, ineq mean 0.0082, ineq p_g num viol 0.2000, ineq q_g num viol 1.8500, ineq v_m num viol 3.9500, ineq line_theraml num viol 0.6000, eq max 0.0031, eq mean 0.0001
# Epoch 29: train loss 14.9957, train obj 9.9513, ineq max 2.6500, ineq mean 0.0081, ineq p_g num viol 0.3000, ineq q_g num viol 1.9500, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0031, eq mean 0.0001
# Epoch 30: train loss 14.7957, train obj 9.9394, ineq max 2.5234, ineq mean 0.0078, ineq p_g num viol 0.2500, ineq q_g num viol 1.9000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0031, eq mean 0.0001
# Epoch 31: train loss 14.6237, train obj 9.9470, ineq max 2.4499, ineq mean 0.0075, ineq p_g num viol 0.3000, ineq q_g num viol 1.8500, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0030, eq mean 0.0001
# Epoch 32: train loss 14.4484, train obj 9.9551, ineq max 2.3472, ineq mean 0.0072, ineq p_g num viol 0.2000, ineq q_g num viol 1.6500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0030, eq mean 0.0001
# Epoch 33: train loss 14.3099, train obj 9.9561, ineq max 2.2613, ineq mean 0.0070, ineq p_g num viol 0.2000, ineq q_g num viol 1.5500, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0030, eq mean 0.0001
# Epoch 34: train loss 14.2439, train obj 9.9431, ineq max 2.2620, ineq mean 0.0069, ineq p_g num viol 0.1500, ineq q_g num viol 1.5000, ineq v_m num viol 4.0500, ineq line_theraml num viol 0.6000, eq max 0.0030, eq mean 0.0001
# Epoch 35: train loss 14.1898, train obj 9.9194, ineq max 2.2646, ineq mean 0.0069, ineq p_g num viol 0.2000, ineq q_g num viol 1.2500, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0030, eq mean 0.0001
# Epoch 36: train loss 14.1785, train obj 9.8973, ineq max 2.2941, ineq mean 0.0069, ineq p_g num viol 0.2500, ineq q_g num viol 1.0000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0029, eq mean 0.0001
# Epoch 37: train loss 14.1442, train obj 9.8795, ineq max 2.2998, ineq mean 0.0069, ineq p_g num viol 0.2000, ineq q_g num viol 0.9500, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0029, eq mean 0.0001
# Epoch 38: train loss 14.1421, train obj 9.8830, ineq max 2.2875, ineq mean 0.0068, ineq p_g num viol 0.2000, ineq q_g num viol 1.2000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0029, eq mean 0.0001
# Epoch 39: train loss 14.1134, train obj 9.8759, ineq max 2.2870, ineq mean 0.0068, ineq p_g num viol 0.2500, ineq q_g num viol 1.0000, ineq v_m num viol 4.0000, ineq line_theraml num viol 0.6000, eq max 0.0029, eq mean 0.0001

# %%
total_train_time
# Out:
# 4.342317581176758

# %% [markdown]
# * Evaluation (zero-shot)

# %%
from pypower.api import makeYbus
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

test_stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    Ybus, Yf, Yt = makeYbus(acopf_contingencies[case].baseMVA, acopf_contingencies[case].ppc['bus'], acopf_contingencies[case].ppc['branch'])
    # branch thermal limit information
    flow_max = (acopf_contingencies[case].ppc['branch'][:, 5] / acopf_contingencies[case].baseMVA)**2
    flow_max[flow_max == 0] = np.inf
    flow_max = torch.tensor(flow_max, dtype=torch.float32).to(device)
    
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    test_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][100:], batch_size=1, shuffle=False, drop_last=True)
    contingency_models[case] = contingency_models[case].to(device)
    contingency_models[case].eval()
    test_stats = {}
    # test_stats["Contingency"] = case
    test_eps_converge = 1e-4
    
    LagM_sp_g = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_q_g = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_v_m = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line_l = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    solve_time = []
    for (i, Xtest) in enumerate(test_loader):
        Xtest = Xtest.to(device)
    
        start_time = time.time()
        Y = contingency_models[case](Xtest, n_means, n_stds, e_means, e_stds)
        end_time = time.time()
    
        solve_time += [end_time - start_time]
    
        ## line thermal limit
        pg, qg, vm, va = acopf_contingencies[case].get_yvars(Y)
        vr = vm*torch.cos(va)
        vi = vm*torch.sin(va)
        vz = torch.complex(vr, vi) # complex voltage
    
        # calculate the branch current of from bus and to bus based on the Yf*V and Yt*V
        If = torch.tensor(Yf.todense(), dtype=torch.complex64).to(device) @ vz.T
        It = torch.tensor(Yt.todense(), dtype=torch.complex64).to(device) @ vz.T
    
        # Calculate the apparent power S
        Sf = vz[:,acopf_contingencies[case].ppc['branch'][:,0].astype(int)] * torch.conj(If.T)
        St = vz[:,acopf_contingencies[case].ppc['branch'][:,1].astype(int)] * torch.conj(It.T)
        Sff = Sf * torch.conj(Sf)
        Stt = St * torch.conj(St)
    
        # calculate the line thermal limit constraints violation
        diff_Sf = Sff.real - flow_max
        diff_St = Stt.real - flow_max
        # diff_Sf[torch.clamp(diff_Sf, 0) != 0]
    
        line_limit_vio_Sf = torch.clamp(diff_Sf, 0)
        line_limit_vio_St = torch.clamp(diff_St, 0)
        ###########################################
    
        # test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(data, Xtest.x, Y, LagM)
        test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(acopf_contingencies[case], Xtest.x, Y, LagM_sp_g, LagM_q_g, LagM_v_m, LagM_line_l) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
    
        dict_agg(test_stats, 'time', end_time - start_time, op='sum')
    
        test_ineq_p_g = torch.cat([pg - acopf_contingencies[case].pmax, acopf_contingencies[case].pmin - pg], dim=1)
        test_ineq_p_g = torch.clamp(test_ineq_p_g, 0).to(device)
        test_ineq_q_g = test_ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
        test_ineq_v_m = test_ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
        test_ineq_line_l = test_ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
        dict_agg(test_stats, 'test_loss', test_loss.detach().cpu().numpy())
        # dict_agg(test_stats, 'test_loss', (test_loss[0]+test_loss[1]+test_loss[2]+test_loss[3]).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_obj_cost', test_obj_cost.detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_max', torch.max(test_ineq_dist, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_mean', torch.mean(test_ineq_dist, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_max', torch.max(test_ineq_p_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_mean', torch.mean(test_ineq_p_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_max', torch.max(test_ineq_q_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_mean', torch.mean(test_ineq_q_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_max', torch.max(test_ineq_v_m, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_mean', torch.mean(test_ineq_v_m, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_max', torch.max(test_ineq_line_l, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_mean', torch.mean(test_ineq_line_l, dim=1).detach().cpu().numpy())
    
        pg_rate_torch = (((pg <= acopf_contingencies[case].pmax) & (pg >= acopf_contingencies[case].pmin)).sum()/acopf_contingencies[case].ng)*100
        qg_rate_torch = (((qg <= acopf_contingencies[case].qmax) & (qg >= acopf_contingencies[case].qmin)).sum()/acopf_contingencies[case].ng)*100
        dict_agg(test_stats, 'test_p_g_satisfication rate (%)', pg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_q_g_satisfication rate (%)', qg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_p_g_satisfication rate (%)', ((torch.sum(test_ineq_p_g == 0, dim=1)/test_ineq_p_g.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_q_g_satisfication rate (%)', ((torch.sum(test_ineq_q_g == 0, dim=1)/test_ineq_q_g.shape[1])*100).detach().cpu().numpy())
    
        v_rate_torch = (((vm <= acopf_contingencies[case].vmax) & (vm >= acopf_contingencies[case].vmin)).sum()/acopf_contingencies[case].nbus)*100
        dict_agg(test_stats, 'test_v_m_satisfication rate (%)', v_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_v_m_satisfication rate (%)', ((torch.sum(test_ineq_v_m == 0, dim=1)/test_ineq_v_m.shape[1])*100).detach().cpu().numpy())
    
        sff_rate_torch = ((Sff.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        stt_rate_torch = ((Stt.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', sff_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', stt_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate (%)', ((torch.sum(test_ineq_line_l == 0, dim=1)/test_ineq_line_l.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', ((torch.sum(line_limit_vio_Sf == 0, dim=1)/line_limit_vio_Sf.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', ((torch.sum(line_limit_vio_St == 0, dim=1)/line_limit_vio_St.shape[1])*100).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_q_g_num_viol_0', torch.sum(test_ineq_q_g > test_eps_converge, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_num_viol_0', torch.sum(test_ineq_v_m > test_eps_converge, dim=1).detach().cpu().numpy())
    
        test_eq_real = test_eq_resid[:,:acopf_contingencies[case].nbus]
        test_eq_react = test_eq_resid[:,acopf_contingencies[case].nbus:]
        dict_agg(test_stats, 'test_eq_max', torch.max(torch.abs(test_eq_resid), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_mean', torch.mean(torch.abs(test_eq_resid), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_max', torch.max(torch.abs(test_eq_real), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_mean', torch.mean(torch.abs(test_eq_real), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_max', torch.max(torch.abs(test_eq_react), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_mean', torch.mean(torch.abs(test_eq_react), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_active_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,:acopf_contingencies[case].nbus] <= 1e-2) & (test_eq_resid[:,:acopf_contingencies[case].nbus] >= -1e-2)  , dim=1)/test_eq_resid[:,:acopf_contingencies[case].nbus].shape[1]*100).detach().cpu().numpy())
        dict_agg(test_stats, 'test_reactive_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,acopf_contingencies[case].nbus:] <= 1e-2) & (test_eq_resid[:,acopf_contingencies[case].nbus:] >= -1e-2)  , dim=1)/test_eq_resid[:,acopf_contingencies[case].nbus:].shape[1]*100).detach().cpu().numpy())

        print('Test batch {}: test loss {:.4f}, test obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}, p_g satisfication rate {:.4f}, q_g satisfication rate {:.4f}, v_m satisfication rate {:.4f}, test_line_limit_satisfication_rate {:.4f}, test_line_limit_satisfication_rate_Sf {:.4f}, test_line_limit_satisfication_rate_St {:.4f}, active eq satisfication rate {:.4f}, reactive eq satisfication rate {:.4f}'.format(
                    i, np.mean(test_stats['test_loss']), np.mean(test_stats['test_obj_cost']), np.mean(test_stats['test_ineq_max']), np.mean(test_stats['test_ineq_mean']),
                    np.mean(test_stats['test_ineq_q_g_num_viol_0']), np.mean(test_stats['test_ineq_v_m_num_viol_0']),
                    np.mean(test_stats['test_eq_max']), np.mean(test_stats['test_eq_mean']), np.mean(test_stats['test_p_g_satisfication rate (%)']), np.mean(test_stats['test_q_g_satisfication rate (%)']), np.mean(test_stats['test_v_m_satisfication rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']), np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']), np.mean(test_stats['test_active_eq_satisfication rate (%)']), np.mean(test_stats['test_reactive_eq_satisfication rate (%)'])))

    test_stats_contingency += [test_stats]
    print("\n")
# Out:
# Contingency  0
# Test batch 0: test loss 14.7067, test obj 12.9597, ineq max 1.3723, ineq mean 0.0028, ineq q_g num viol 2.0000, ineq v_m num viol 6.0000, eq max 0.0029, eq mean 0.0001, p_g satisfication rate 90.9091, q_g satisfication rate 81.8182, v_m satisfication rate 93.2584, test_line_limit_satisfication_rate 99.5238, test_line_limit_satisfication_rate_Sf 99.5238, test_line_limit_satisfication_rate_St 99.5238, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 1: test loss 13.7835, test obj 12.8582, ineq max 0.6968, ineq mean 0.0015, ineq q_g num viol 1.5000, ineq v_m num viol 5.5000, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 86.3636, v_m satisfication rate 93.2584, test_line_limit_satisfication_rate 99.7619, test_line_limit_satisfication_rate_Sf 99.7619, test_line_limit_satisfication_rate_St 99.7619, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 2: test loss 13.4931, test obj 12.8285, ineq max 0.4865, ineq mean 0.0011, ineq q_g num viol 1.3333, ineq v_m num viol 5.6667, eq max 0.0034, eq mean 0.0002, p_g satisfication rate 96.9697, q_g satisfication rate 87.8788, v_m satisfication rate 93.2584, test_line_limit_satisfication_rate 99.8413, test_line_limit_satisfication_rate_Sf 99.8413, test_line_limit_satisfication_rate_St 99.8413, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 3: test loss 13.8779, test obj 12.8698, ineq max 0.8383, ineq mean 0.0016, ineq q_g num viol 1.2500, ineq v_m num viol 5.7500, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 88.6364, v_m satisfication rate 93.2584, test_line_limit_satisfication_rate 99.8810, test_line_limit_satisfication_rate_Sf 99.8810, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 4: test loss 13.7325, test obj 12.8436, ineq max 0.7117, ineq mean 0.0014, ineq q_g num viol 1.4000, ineq v_m num viol 5.6000, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 96.3636, q_g satisfication rate 87.2727, v_m satisfication rate 93.4831, test_line_limit_satisfication_rate 99.9048, test_line_limit_satisfication_rate_Sf 99.9048, test_line_limit_satisfication_rate_St 99.9048, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 5: test loss 13.6225, test obj 12.8395, ineq max 0.6174, ineq mean 0.0013, ineq q_g num viol 1.5000, ineq v_m num viol 5.6667, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 96.9697, q_g satisfication rate 86.3636, v_m satisfication rate 93.4457, test_line_limit_satisfication_rate 99.9206, test_line_limit_satisfication_rate_Sf 99.9206, test_line_limit_satisfication_rate_St 99.9206, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 6: test loss 13.6858, test obj 12.8534, ineq max 0.6754, ineq mean 0.0013, ineq q_g num viol 1.5714, ineq v_m num viol 5.7143, eq max 0.0031, eq mean 0.0001, p_g satisfication rate 96.1039, q_g satisfication rate 85.7143, v_m satisfication rate 93.4189, test_line_limit_satisfication_rate 99.9320, test_line_limit_satisfication_rate_Sf 99.9320, test_line_limit_satisfication_rate_St 99.9320, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 7: test loss 13.7140, test obj 12.8610, ineq max 0.6761, ineq mean 0.0014, ineq q_g num viol 1.5000, ineq v_m num viol 5.7500, eq max 0.0031, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 86.3636, v_m satisfication rate 93.3989, test_line_limit_satisfication_rate 99.9405, test_line_limit_satisfication_rate_Sf 99.9405, test_line_limit_satisfication_rate_St 99.9405, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 8: test loss 14.2578, test obj 12.8472, ineq max 0.9361, ineq mean 0.0023, ineq q_g num viol 1.5556, ineq v_m num viol 5.5556, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 95.9596, q_g satisfication rate 85.8586, v_m satisfication rate 93.6330, test_line_limit_satisfication_rate 99.8942, test_line_limit_satisfication_rate_Sf 99.8942, test_line_limit_satisfication_rate_St 99.8942, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 9: test loss 14.4302, test obj 12.8683, ineq max 1.1287, ineq mean 0.0025, ineq q_g num viol 1.4000, ineq v_m num viol 5.5000, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 87.2727, v_m satisfication rate 93.7079, test_line_limit_satisfication_rate 99.9048, test_line_limit_satisfication_rate_Sf 99.9048, test_line_limit_satisfication_rate_St 99.9048, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 10: test loss 15.7556, test obj 12.8564, ineq max 1.7712, ineq mean 0.0047, ineq q_g num viol 1.4545, ineq v_m num viol 5.4545, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 95.8678, q_g satisfication rate 86.7769, v_m satisfication rate 93.7692, test_line_limit_satisfication_rate 99.8701, test_line_limit_satisfication_rate_Sf 99.8701, test_line_limit_satisfication_rate_St 99.8701, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 11: test loss 15.5378, test obj 12.8536, ineq max 1.6401, ineq mean 0.0043, ineq q_g num viol 1.5000, ineq v_m num viol 5.4167, eq max 0.0032, eq mean 0.0001, p_g satisfication rate 96.2121, q_g satisfication rate 86.3636, v_m satisfication rate 93.8202, test_line_limit_satisfication_rate 99.8810, test_line_limit_satisfication_rate_Sf 99.8810, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 12: test loss 16.7579, test obj 12.8425, ineq max 2.2440, ineq mean 0.0063, ineq q_g num viol 1.5385, ineq v_m num viol 5.3846, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 96.5035, q_g satisfication rate 86.0140, v_m satisfication rate 93.7770, test_line_limit_satisfication_rate 99.8535, test_line_limit_satisfication_rate_Sf 99.8535, test_line_limit_satisfication_rate_St 99.8535, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 13: test loss 16.4981, test obj 12.8452, ineq max 2.0956, ineq mean 0.0059, ineq q_g num viol 1.4286, ineq v_m num viol 5.4286, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 96.1039, q_g satisfication rate 87.0130, v_m satisfication rate 93.7400, test_line_limit_satisfication_rate 99.8639, test_line_limit_satisfication_rate_Sf 99.8639, test_line_limit_satisfication_rate_St 99.8639, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 14: test loss 17.8901, test obj 12.8259, ineq max 2.7919, ineq mean 0.0081, ineq q_g num viol 1.4667, ineq v_m num viol 5.4667, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 96.3636, q_g satisfication rate 86.6667, v_m satisfication rate 93.7079, test_line_limit_satisfication_rate 99.8413, test_line_limit_satisfication_rate_Sf 99.8413, test_line_limit_satisfication_rate_St 99.8413, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 15: test loss 17.5953, test obj 12.8293, ineq max 2.6282, ineq mean 0.0077, ineq q_g num viol 1.4375, ineq v_m num viol 5.4375, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 96.0227, q_g satisfication rate 86.9318, v_m satisfication rate 93.7500, test_line_limit_satisfication_rate 99.8512, test_line_limit_satisfication_rate_Sf 99.8512, test_line_limit_satisfication_rate_St 99.8512, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 16: test loss 17.6603, test obj 12.8183, ineq max 2.6563, ineq mean 0.0078, ineq q_g num viol 1.4706, ineq v_m num viol 5.4118, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 96.2567, q_g satisfication rate 86.6310, v_m satisfication rate 93.7872, test_line_limit_satisfication_rate 99.8319, test_line_limit_satisfication_rate_Sf 99.8319, test_line_limit_satisfication_rate_St 99.8319, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 17: test loss 17.4780, test obj 12.8254, ineq max 2.5724, ineq mean 0.0075, ineq q_g num viol 1.4444, ineq v_m num viol 5.4444, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.9596, q_g satisfication rate 86.8687, v_m satisfication rate 93.7578, test_line_limit_satisfication_rate 99.8413, test_line_limit_satisfication_rate_Sf 99.8413, test_line_limit_satisfication_rate_St 99.8413, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 18: test loss 17.2429, test obj 12.8223, ineq max 2.4455, ineq mean 0.0071, ineq q_g num viol 1.4211, ineq v_m num viol 5.4737, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 96.1722, q_g satisfication rate 87.0813, v_m satisfication rate 93.7315, test_line_limit_satisfication_rate 99.8496, test_line_limit_satisfication_rate_Sf 99.8496, test_line_limit_satisfication_rate_St 99.8496, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 19: test loss 17.1684, test obj 12.8332, ineq max 2.4533, ineq mean 0.0070, ineq q_g num viol 1.4000, ineq v_m num viol 5.5000, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.9091, q_g satisfication rate 87.2727, v_m satisfication rate 93.7079, test_line_limit_satisfication_rate 99.8571, test_line_limit_satisfication_rate_Sf 99.8571, test_line_limit_satisfication_rate_St 99.8571, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 20: test loss 17.0732, test obj 12.8415, ineq max 2.4362, ineq mean 0.0068, ineq q_g num viol 1.3333, ineq v_m num viol 5.5238, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.6710, q_g satisfication rate 87.8788, v_m satisfication rate 93.6865, test_line_limit_satisfication_rate 99.8639, test_line_limit_satisfication_rate_Sf 99.8639, test_line_limit_satisfication_rate_St 99.8639, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 21: test loss 16.9966, test obj 12.8497, ineq max 2.4305, ineq mean 0.0067, ineq q_g num viol 1.2727, ineq v_m num viol 5.5000, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 88.4297, v_m satisfication rate 93.7181, test_line_limit_satisfication_rate 99.8701, test_line_limit_satisfication_rate_Sf 99.8701, test_line_limit_satisfication_rate_St 99.8701, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 22: test loss 16.8228, test obj 12.8463, ineq max 2.3321, ineq mean 0.0064, ineq q_g num viol 1.2609, ineq v_m num viol 5.4783, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.6522, q_g satisfication rate 88.5375, v_m satisfication rate 93.7470, test_line_limit_satisfication_rate 99.8758, test_line_limit_satisfication_rate_Sf 99.8758, test_line_limit_satisfication_rate_St 99.8758, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 23: test loss 16.6988, test obj 12.8494, ineq max 2.2669, ineq mean 0.0062, ineq q_g num viol 1.2500, ineq v_m num viol 5.4583, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.4546, q_g satisfication rate 88.6364, v_m satisfication rate 93.7266, test_line_limit_satisfication_rate 99.8810, test_line_limit_satisfication_rate_Sf 99.8810, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 24: test loss 17.2419, test obj 12.8502, ineq max 2.5335, ineq mean 0.0071, ineq q_g num viol 1.2000, ineq v_m num viol 5.4800, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.2727, q_g satisfication rate 89.0909, v_m satisfication rate 93.7079, test_line_limit_satisfication_rate 99.8667, test_line_limit_satisfication_rate_Sf 99.8667, test_line_limit_satisfication_rate_St 99.8667, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 25: test loss 17.1233, test obj 12.8520, ineq max 2.4529, ineq mean 0.0069, ineq q_g num viol 1.2308, ineq v_m num viol 5.4615, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.1049, q_g satisfication rate 88.8112, v_m satisfication rate 93.7338, test_line_limit_satisfication_rate 99.8535, test_line_limit_satisfication_rate_Sf 99.8535, test_line_limit_satisfication_rate_St 99.8535, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 26: test loss 16.9715, test obj 12.8497, ineq max 2.3677, ineq mean 0.0066, ineq q_g num viol 1.2222, ineq v_m num viol 5.4444, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.2862, q_g satisfication rate 88.8889, v_m satisfication rate 93.7578, test_line_limit_satisfication_rate 99.8589, test_line_limit_satisfication_rate_Sf 99.8589, test_line_limit_satisfication_rate_St 99.8589, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 27: test loss 16.8340, test obj 12.8507, ineq max 2.2878, ineq mean 0.0064, ineq q_g num viol 1.2143, ineq v_m num viol 5.4286, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.1299, q_g satisfication rate 88.9610, v_m satisfication rate 93.7400, test_line_limit_satisfication_rate 99.8640, test_line_limit_satisfication_rate_Sf 99.8640, test_line_limit_satisfication_rate_St 99.8640, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 28: test loss 17.6474, test obj 12.8466, ineq max 2.6939, ineq mean 0.0077, ineq q_g num viol 1.2414, ineq v_m num viol 5.4483, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.2978, q_g satisfication rate 88.7147, v_m satisfication rate 93.7234, test_line_limit_satisfication_rate 99.8522, test_line_limit_satisfication_rate_Sf 99.8522, test_line_limit_satisfication_rate_St 99.8522, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 29: test loss 17.5438, test obj 12.8505, ineq max 2.6512, ineq mean 0.0075, ineq q_g num viol 1.2333, ineq v_m num viol 5.4333, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.1515, q_g satisfication rate 88.7879, v_m satisfication rate 93.7453, test_line_limit_satisfication_rate 99.8572, test_line_limit_satisfication_rate_Sf 99.8572, test_line_limit_satisfication_rate_St 99.8572, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 30: test loss 18.0475, test obj 12.8509, ineq max 2.8980, ineq mean 0.0084, ineq q_g num viol 1.2581, ineq v_m num viol 5.4194, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3079, q_g satisfication rate 88.5630, v_m satisfication rate 93.7659, test_line_limit_satisfication_rate 99.8310, test_line_limit_satisfication_rate_Sf 99.8310, test_line_limit_satisfication_rate_St 99.8310, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 31: test loss 18.8477, test obj 12.8482, ineq max 3.3004, ineq mean 0.0096, ineq q_g num viol 1.2500, ineq v_m num viol 5.4062, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 88.6364, v_m satisfication rate 93.7851, test_line_limit_satisfication_rate 99.8214, test_line_limit_satisfication_rate_Sf 99.8214, test_line_limit_satisfication_rate_St 99.8214, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 32: test loss 18.7012, test obj 12.8507, ineq max 3.2289, ineq mean 0.0094, ineq q_g num viol 1.2727, ineq v_m num viol 5.4242, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3168, q_g satisfication rate 88.4298, v_m satisfication rate 93.7692, test_line_limit_satisfication_rate 99.8268, test_line_limit_satisfication_rate_Sf 99.8268, test_line_limit_satisfication_rate_St 99.8268, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 33: test loss 19.2570, test obj 12.8510, ineq max 3.5041, ineq mean 0.0103, ineq q_g num viol 1.2941, ineq v_m num viol 5.4412, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 88.2353, v_m satisfication rate 93.7541, test_line_limit_satisfication_rate 99.8179, test_line_limit_satisfication_rate_Sf 99.8179, test_line_limit_satisfication_rate_St 99.8179, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 34: test loss 19.0833, test obj 12.8517, ineq max 3.4074, ineq mean 0.0100, ineq q_g num viol 1.2857, ineq v_m num viol 5.4286, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3247, q_g satisfication rate 88.3117, v_m satisfication rate 93.7721, test_line_limit_satisfication_rate 99.8231, test_line_limit_satisfication_rate_Sf 99.8231, test_line_limit_satisfication_rate_St 99.8231, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 35: test loss 18.9176, test obj 12.8493, ineq max 3.3182, ineq mean 0.0098, ineq q_g num viol 1.3056, ineq v_m num viol 5.4167, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4546, q_g satisfication rate 88.1313, v_m satisfication rate 93.7890, test_line_limit_satisfication_rate 99.8280, test_line_limit_satisfication_rate_Sf 99.8280, test_line_limit_satisfication_rate_St 99.8280, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 36: test loss 18.8817, test obj 12.8572, ineq max 3.3402, ineq mean 0.0097, ineq q_g num viol 1.2703, ineq v_m num viol 5.4324, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3317, q_g satisfication rate 88.4521, v_m satisfication rate 93.7747, test_line_limit_satisfication_rate 99.8198, test_line_limit_satisfication_rate_Sf 99.8198, test_line_limit_satisfication_rate_St 99.8198, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 37: test loss 18.7265, test obj 12.8544, ineq max 3.2564, ineq mean 0.0094, ineq q_g num viol 1.2632, ineq v_m num viol 5.4211, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4546, q_g satisfication rate 88.5167, v_m satisfication rate 93.7611, test_line_limit_satisfication_rate 99.8246, test_line_limit_satisfication_rate_Sf 99.8246, test_line_limit_satisfication_rate_St 99.8246, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 38: test loss 18.6087, test obj 12.8565, ineq max 3.1993, ineq mean 0.0092, ineq q_g num viol 1.2821, ineq v_m num viol 5.4103, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3380, q_g satisfication rate 88.3450, v_m satisfication rate 93.7770, test_line_limit_satisfication_rate 99.8291, test_line_limit_satisfication_rate_Sf 99.8291, test_line_limit_satisfication_rate_St 99.8291, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 39: test loss 18.7048, test obj 12.8570, ineq max 3.2416, ineq mean 0.0094, ineq q_g num viol 1.3000, ineq v_m num viol 5.4000, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.2273, q_g satisfication rate 88.1818, v_m satisfication rate 93.7921, test_line_limit_satisfication_rate 99.8214, test_line_limit_satisfication_rate_Sf 99.8214, test_line_limit_satisfication_rate_St 99.8214, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 40: test loss 18.5636, test obj 12.8532, ineq max 3.1643, ineq mean 0.0092, ineq q_g num viol 1.3171, ineq v_m num viol 5.4146, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.3437, q_g satisfication rate 88.0266, v_m satisfication rate 93.7791, test_line_limit_satisfication_rate 99.8258, test_line_limit_satisfication_rate_Sf 99.8258, test_line_limit_satisfication_rate_St 99.8258, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 41: test loss 19.0286, test obj 12.8506, ineq max 3.3864, ineq mean 0.0099, ineq q_g num viol 1.3333, ineq v_m num viol 5.4048, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 87.8788, v_m satisfication rate 93.7935, test_line_limit_satisfication_rate 99.8073, test_line_limit_satisfication_rate_Sf 99.8073, test_line_limit_satisfication_rate_St 99.8073, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 42: test loss 18.8870, test obj 12.8508, ineq max 3.3082, ineq mean 0.0097, ineq q_g num viol 1.3256, ineq v_m num viol 5.3953, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5602, q_g satisfication rate 87.9493, v_m satisfication rate 93.8072, test_line_limit_satisfication_rate 99.8117, test_line_limit_satisfication_rate_Sf 99.8117, test_line_limit_satisfication_rate_St 99.8117, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 43: test loss 18.7550, test obj 12.8472, ineq max 3.2372, ineq mean 0.0095, ineq q_g num viol 1.3409, ineq v_m num viol 5.4091, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6612, q_g satisfication rate 87.8099, v_m satisfication rate 93.7947, test_line_limit_satisfication_rate 99.8160, test_line_limit_satisfication_rate_Sf 99.8160, test_line_limit_satisfication_rate_St 99.8160, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 44: test loss 18.6468, test obj 12.8488, ineq max 3.1819, ineq mean 0.0093, ineq q_g num viol 1.3556, ineq v_m num viol 5.4222, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5556, q_g satisfication rate 87.6768, v_m satisfication rate 93.7828, test_line_limit_satisfication_rate 99.8201, test_line_limit_satisfication_rate_Sf 99.8201, test_line_limit_satisfication_rate_St 99.8201, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 45: test loss 18.5311, test obj 12.8496, ineq max 3.1191, ineq mean 0.0091, ineq q_g num viol 1.3478, ineq v_m num viol 5.4348, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4545, q_g satisfication rate 87.7470, v_m satisfication rate 93.7714, test_line_limit_satisfication_rate 99.8240, test_line_limit_satisfication_rate_Sf 99.8240, test_line_limit_satisfication_rate_St 99.8240, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 46: test loss 18.4126, test obj 12.8473, ineq max 3.0550, ineq mean 0.0089, ineq q_g num viol 1.3617, ineq v_m num viol 5.4468, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5513, q_g satisfication rate 87.6209, v_m satisfication rate 93.7605, test_line_limit_satisfication_rate 99.8278, test_line_limit_satisfication_rate_Sf 99.8278, test_line_limit_satisfication_rate_St 99.8278, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 47: test loss 18.3021, test obj 12.8461, ineq max 2.9952, ineq mean 0.0088, ineq q_g num viol 1.3750, ineq v_m num viol 5.4583, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6439, q_g satisfication rate 87.5000, v_m satisfication rate 93.7500, test_line_limit_satisfication_rate 99.8314, test_line_limit_satisfication_rate_Sf 99.8314, test_line_limit_satisfication_rate_St 99.8314, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 48: test loss 18.1949, test obj 12.8466, ineq max 2.9362, ineq mean 0.0086, ineq q_g num viol 1.3673, ineq v_m num viol 5.4694, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7328, q_g satisfication rate 87.5696, v_m satisfication rate 93.7400, test_line_limit_satisfication_rate 99.8348, test_line_limit_satisfication_rate_Sf 99.8348, test_line_limit_satisfication_rate_St 99.8348, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 49: test loss 18.1105, test obj 12.8483, ineq max 2.8970, ineq mean 0.0085, ineq q_g num viol 1.3400, ineq v_m num viol 5.4600, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6364, q_g satisfication rate 87.8182, v_m satisfication rate 93.7528, test_line_limit_satisfication_rate 99.8381, test_line_limit_satisfication_rate_Sf 99.8381, test_line_limit_satisfication_rate_St 99.8381, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 50: test loss 18.0105, test obj 12.8462, ineq max 2.8434, ineq mean 0.0083, ineq q_g num viol 1.3529, ineq v_m num viol 5.4706, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7219, q_g satisfication rate 87.7005, v_m satisfication rate 93.7431, test_line_limit_satisfication_rate 99.8413, test_line_limit_satisfication_rate_Sf 99.8413, test_line_limit_satisfication_rate_St 99.8413, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 51: test loss 17.9160, test obj 12.8464, ineq max 2.7915, ineq mean 0.0082, ineq q_g num viol 1.3654, ineq v_m num viol 5.4808, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.8042, q_g satisfication rate 87.5874, v_m satisfication rate 93.7338, test_line_limit_satisfication_rate 99.8443, test_line_limit_satisfication_rate_Sf 99.8443, test_line_limit_satisfication_rate_St 99.8443, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 52: test loss 17.8468, test obj 12.8474, ineq max 2.7463, ineq mean 0.0080, ineq q_g num viol 1.3585, ineq v_m num viol 5.4717, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7118, q_g satisfication rate 87.6501, v_m satisfication rate 93.7460, test_line_limit_satisfication_rate 99.8383, test_line_limit_satisfication_rate_Sf 99.8383, test_line_limit_satisfication_rate_St 99.8383, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 53: test loss 17.7936, test obj 12.8501, ineq max 2.7303, ineq mean 0.0079, ineq q_g num viol 1.3519, ineq v_m num viol 5.4815, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6229, q_g satisfication rate 87.7104, v_m satisfication rate 93.7370, test_line_limit_satisfication_rate 99.8413, test_line_limit_satisfication_rate_Sf 99.8413, test_line_limit_satisfication_rate_St 99.8413, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 54: test loss 17.7059, test obj 12.8488, ineq max 2.6822, ineq mean 0.0078, ineq q_g num viol 1.3636, ineq v_m num viol 5.4909, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7025, q_g satisfication rate 87.6033, v_m satisfication rate 93.7283, test_line_limit_satisfication_rate 99.8442, test_line_limit_satisfication_rate_Sf 99.8442, test_line_limit_satisfication_rate_St 99.8442, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 55: test loss 17.6254, test obj 12.8479, ineq max 2.6378, ineq mean 0.0077, ineq q_g num viol 1.3750, ineq v_m num viol 5.5000, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7792, q_g satisfication rate 87.5000, v_m satisfication rate 93.7199, test_line_limit_satisfication_rate 99.8469, test_line_limit_satisfication_rate_Sf 99.8469, test_line_limit_satisfication_rate_St 99.8469, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 56: test loss 17.5435, test obj 12.8470, ineq max 2.5930, ineq mean 0.0076, ineq q_g num viol 1.3684, ineq v_m num viol 5.5088, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.8533, q_g satisfication rate 87.5598, v_m satisfication rate 93.7118, test_line_limit_satisfication_rate 99.8496, test_line_limit_satisfication_rate_Sf 99.8496, test_line_limit_satisfication_rate_St 99.8496, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 57: test loss 17.4786, test obj 12.8482, ineq max 2.5613, ineq mean 0.0074, ineq q_g num viol 1.3621, ineq v_m num viol 5.5000, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7680, q_g satisfication rate 87.6176, v_m satisfication rate 93.7234, test_line_limit_satisfication_rate 99.8522, test_line_limit_satisfication_rate_Sf 99.8522, test_line_limit_satisfication_rate_St 99.8522, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 58: test loss 17.4194, test obj 12.8496, ineq max 2.5340, ineq mean 0.0073, ineq q_g num viol 1.3559, ineq v_m num viol 5.4746, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6857, q_g satisfication rate 87.6733, v_m satisfication rate 93.7536, test_line_limit_satisfication_rate 99.8507, test_line_limit_satisfication_rate_Sf 99.8467, test_line_limit_satisfication_rate_St 99.8547, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 59: test loss 17.3642, test obj 12.8511, ineq max 2.5081, ineq mean 0.0073, ineq q_g num viol 1.3667, ineq v_m num viol 5.4833, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6061, q_g satisfication rate 87.5758, v_m satisfication rate 93.7453, test_line_limit_satisfication_rate 99.8532, test_line_limit_satisfication_rate_Sf 99.8492, test_line_limit_satisfication_rate_St 99.8571, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 60: test loss 17.3304, test obj 12.8537, ineq max 2.5024, ineq mean 0.0072, ineq q_g num viol 1.3607, ineq v_m num viol 5.4754, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5291, q_g satisfication rate 87.6304, v_m satisfication rate 93.7558, test_line_limit_satisfication_rate 99.8556, test_line_limit_satisfication_rate_Sf 99.8517, test_line_limit_satisfication_rate_St 99.8595, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 61: test loss 17.2774, test obj 12.8549, ineq max 2.4774, ineq mean 0.0071, ineq q_g num viol 1.3548, ineq v_m num viol 5.4677, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.4546, q_g satisfication rate 87.6833, v_m satisfication rate 93.7659, test_line_limit_satisfication_rate 99.8579, test_line_limit_satisfication_rate_Sf 99.8541, test_line_limit_satisfication_rate_St 99.8618, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 62: test loss 17.5511, test obj 12.8531, ineq max 2.6143, ineq mean 0.0076, ineq q_g num viol 1.3492, ineq v_m num viol 5.4762, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5267, q_g satisfication rate 87.7345, v_m satisfication rate 93.7578, test_line_limit_satisfication_rate 99.8526, test_line_limit_satisfication_rate_Sf 99.8488, test_line_limit_satisfication_rate_St 99.8564, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 63: test loss 17.4800, test obj 12.8526, ineq max 2.5744, ineq mean 0.0074, ineq q_g num viol 1.3594, ineq v_m num viol 5.4844, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5966, q_g satisfication rate 87.6420, v_m satisfication rate 93.7500, test_line_limit_satisfication_rate 99.8549, test_line_limit_satisfication_rate_Sf 99.8512, test_line_limit_satisfication_rate_St 99.8586, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 64: test loss 17.4119, test obj 12.8524, ineq max 2.5370, ineq mean 0.0073, ineq q_g num viol 1.3538, ineq v_m num viol 5.4923, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6643, q_g satisfication rate 87.6923, v_m satisfication rate 93.7424, test_line_limit_satisfication_rate 99.8571, test_line_limit_satisfication_rate_Sf 99.8535, test_line_limit_satisfication_rate_St 99.8608, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 65: test loss 17.3432, test obj 12.8491, ineq max 2.5001, ineq mean 0.0072, ineq q_g num viol 1.3636, ineq v_m num viol 5.5000, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7300, q_g satisfication rate 87.6033, v_m satisfication rate 93.7351, test_line_limit_satisfication_rate 99.8593, test_line_limit_satisfication_rate_Sf 99.8557, test_line_limit_satisfication_rate_St 99.8629, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 66: test loss 17.3180, test obj 12.8518, ineq max 2.4997, ineq mean 0.0072, ineq q_g num viol 1.3731, ineq v_m num viol 5.5075, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6581, q_g satisfication rate 87.5170, v_m satisfication rate 93.7280, test_line_limit_satisfication_rate 99.8614, test_line_limit_satisfication_rate_Sf 99.8578, test_line_limit_satisfication_rate_St 99.8650, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 67: test loss 17.2568, test obj 12.8516, ineq max 2.4647, ineq mean 0.0071, ineq q_g num viol 1.3824, ineq v_m num viol 5.5147, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7219, q_g satisfication rate 87.4332, v_m satisfication rate 93.7211, test_line_limit_satisfication_rate 99.8634, test_line_limit_satisfication_rate_Sf 99.8599, test_line_limit_satisfication_rate_St 99.8669, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 68: test loss 17.2232, test obj 12.8536, ineq max 2.4551, ineq mean 0.0070, ineq q_g num viol 1.3913, ineq v_m num viol 5.5072, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6522, q_g satisfication rate 87.3518, v_m satisfication rate 93.7307, test_line_limit_satisfication_rate 99.8654, test_line_limit_satisfication_rate_Sf 99.8620, test_line_limit_satisfication_rate_St 99.8689, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 17.1630, test obj 12.8523, ineq max 2.4217, ineq mean 0.0069, ineq q_g num viol 1.4000, ineq v_m num viol 5.5143, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7143, q_g satisfication rate 87.2727, v_m satisfication rate 93.7239, test_line_limit_satisfication_rate 99.8673, test_line_limit_satisfication_rate_Sf 99.8639, test_line_limit_satisfication_rate_St 99.8707, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 17.1158, test obj 12.8533, ineq max 2.3980, ineq mean 0.0069, ineq q_g num viol 1.3944, ineq v_m num viol 5.5211, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6466, q_g satisfication rate 87.3240, v_m satisfication rate 93.7173, test_line_limit_satisfication_rate 99.8692, test_line_limit_satisfication_rate_Sf 99.8659, test_line_limit_satisfication_rate_St 99.8726, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 17.0560, test obj 12.8498, ineq max 2.3663, ineq mean 0.0068, ineq q_g num viol 1.3889, ineq v_m num viol 5.5139, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7071, q_g satisfication rate 87.3737, v_m satisfication rate 93.7266, test_line_limit_satisfication_rate 99.8710, test_line_limit_satisfication_rate_Sf 99.8677, test_line_limit_satisfication_rate_St 99.8743, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 17.0249, test obj 12.8516, ineq max 2.3561, ineq mean 0.0067, ineq q_g num viol 1.3836, ineq v_m num viol 5.5205, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6414, q_g satisfication rate 87.4222, v_m satisfication rate 93.7202, test_line_limit_satisfication_rate 99.8728, test_line_limit_satisfication_rate_Sf 99.8695, test_line_limit_satisfication_rate_St 99.8761, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 16.9792, test obj 12.8522, ineq max 2.3306, ineq mean 0.0066, ineq q_g num viol 1.3919, ineq v_m num viol 5.5270, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5774, q_g satisfication rate 87.3464, v_m satisfication rate 93.7139, test_line_limit_satisfication_rate 99.8745, test_line_limit_satisfication_rate_Sf 99.8713, test_line_limit_satisfication_rate_St 99.8777, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 16.9545, test obj 12.8543, ineq max 2.3269, ineq mean 0.0066, ineq q_g num viol 1.3733, ineq v_m num viol 5.5333, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5152, q_g satisfication rate 87.5152, v_m satisfication rate 93.7079, test_line_limit_satisfication_rate 99.8762, test_line_limit_satisfication_rate_Sf 99.8730, test_line_limit_satisfication_rate_St 99.8794, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 16.9036, test obj 12.8539, ineq max 2.2983, ineq mean 0.0065, ineq q_g num viol 1.3816, ineq v_m num viol 5.5395, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5742, q_g satisfication rate 87.4402, v_m satisfication rate 93.7019, test_line_limit_satisfication_rate 99.8778, test_line_limit_satisfication_rate_Sf 99.8747, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 16.8951, test obj 12.8520, ineq max 2.2930, ineq mean 0.0065, ineq q_g num viol 1.3636, ineq v_m num viol 5.5325, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6317, q_g satisfication rate 87.6033, v_m satisfication rate 93.7108, test_line_limit_satisfication_rate 99.8732, test_line_limit_satisfication_rate_Sf 99.8701, test_line_limit_satisfication_rate_St 99.8763, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 16.8579, test obj 12.8530, ineq max 2.2756, ineq mean 0.0064, ineq q_g num viol 1.3590, ineq v_m num viol 5.5385, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5711, q_g satisfication rate 87.6457, v_m satisfication rate 93.7050, test_line_limit_satisfication_rate 99.8748, test_line_limit_satisfication_rate_Sf 99.8718, test_line_limit_satisfication_rate_St 99.8779, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 16.8277, test obj 12.8544, ineq max 2.2649, ineq mean 0.0064, ineq q_g num viol 1.3418, ineq v_m num viol 5.5443, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.5121, q_g satisfication rate 87.8021, v_m satisfication rate 93.6993, test_line_limit_satisfication_rate 99.8764, test_line_limit_satisfication_rate_Sf 99.8734, test_line_limit_satisfication_rate_St 99.8794, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 16.7817, test obj 12.8536, ineq max 2.2388, ineq mean 0.0063, ineq q_g num viol 1.3500, ineq v_m num viol 5.5500, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5682, q_g satisfication rate 87.7273, v_m satisfication rate 93.6938, test_line_limit_satisfication_rate 99.8780, test_line_limit_satisfication_rate_Sf 99.8750, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 16.7350, test obj 12.8518, ineq max 2.2135, ineq mean 0.0062, ineq q_g num viol 1.3457, ineq v_m num viol 5.5432, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6229, q_g satisfication rate 87.7666, v_m satisfication rate 93.7023, test_line_limit_satisfication_rate 99.8795, test_line_limit_satisfication_rate_Sf 99.8765, test_line_limit_satisfication_rate_St 99.8824, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 16.7041, test obj 12.8530, ineq max 2.2008, ineq mean 0.0062, ineq q_g num viol 1.3293, ineq v_m num viol 5.5488, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.5654, q_g satisfication rate 87.9157, v_m satisfication rate 93.6969, test_line_limit_satisfication_rate 99.8810, test_line_limit_satisfication_rate_Sf 99.8781, test_line_limit_satisfication_rate_St 99.8839, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 16.6666, test obj 12.8536, ineq max 2.1802, ineq mean 0.0061, ineq q_g num viol 1.3373, ineq v_m num viol 5.5542, eq max 0.0033, eq mean 0.0001, p_g satisfication rate 95.5093, q_g satisfication rate 87.8423, v_m satisfication rate 93.6916, test_line_limit_satisfication_rate 99.8824, test_line_limit_satisfication_rate_Sf 99.8795, test_line_limit_satisfication_rate_St 99.8853, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 16.8081, test obj 12.8525, ineq max 2.2500, ineq mean 0.0064, ineq q_g num viol 1.3333, ineq v_m num viol 5.5595, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.5628, q_g satisfication rate 87.8788, v_m satisfication rate 93.6865, test_line_limit_satisfication_rate 99.8781, test_line_limit_satisfication_rate_Sf 99.8753, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 16.8349, test obj 12.8499, ineq max 2.2632, ineq mean 0.0064, ineq q_g num viol 1.3176, ineq v_m num viol 5.5529, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6150, q_g satisfication rate 88.0214, v_m satisfication rate 93.6946, test_line_limit_satisfication_rate 99.8739, test_line_limit_satisfication_rate_Sf 99.8711, test_line_limit_satisfication_rate_St 99.8767, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 16.7911, test obj 12.8494, ineq max 2.2391, ineq mean 0.0063, ineq q_g num viol 1.3140, ineq v_m num viol 5.5581, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6660, q_g satisfication rate 88.0550, v_m satisfication rate 93.6896, test_line_limit_satisfication_rate 99.8754, test_line_limit_satisfication_rate_Sf 99.8726, test_line_limit_satisfication_rate_St 99.8782, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 16.7484, test obj 12.8495, ineq max 2.2150, ineq mean 0.0063, ineq q_g num viol 1.3103, ineq v_m num viol 5.5632, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7158, q_g satisfication rate 88.0878, v_m satisfication rate 93.6846, test_line_limit_satisfication_rate 99.8768, test_line_limit_satisfication_rate_Sf 99.8741, test_line_limit_satisfication_rate_St 99.8796, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 16.7077, test obj 12.8499, ineq max 2.1922, ineq mean 0.0062, ineq q_g num viol 1.2955, ineq v_m num viol 5.5682, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6612, q_g satisfication rate 88.2231, v_m satisfication rate 93.6798, test_line_limit_satisfication_rate 99.8782, test_line_limit_satisfication_rate_Sf 99.8755, test_line_limit_satisfication_rate_St 99.8810, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 16.6704, test obj 12.8503, ineq max 2.1716, ineq mean 0.0061, ineq q_g num viol 1.2921, ineq v_m num viol 5.5730, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6078, q_g satisfication rate 88.2533, v_m satisfication rate 93.6750, test_line_limit_satisfication_rate 99.8796, test_line_limit_satisfication_rate_Sf 99.8769, test_line_limit_satisfication_rate_St 99.8823, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 16.7704, test obj 12.8488, ineq max 2.2201, ineq mean 0.0063, ineq q_g num viol 1.3000, ineq v_m num viol 5.5778, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6566, q_g satisfication rate 88.1818, v_m satisfication rate 93.6704, test_line_limit_satisfication_rate 99.8756, test_line_limit_satisfication_rate_Sf 99.8730, test_line_limit_satisfication_rate_St 99.8783, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 16.7300, test obj 12.8467, ineq max 2.1984, ineq mean 0.0062, ineq q_g num viol 1.3077, ineq v_m num viol 5.5714, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7043, q_g satisfication rate 88.1119, v_m satisfication rate 93.6782, test_line_limit_satisfication_rate 99.8770, test_line_limit_satisfication_rate_Sf 99.8744, test_line_limit_satisfication_rate_St 99.8796, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 16.6899, test obj 12.8470, ineq max 2.1752, ineq mean 0.0062, ineq q_g num viol 1.3043, ineq v_m num viol 5.5761, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6522, q_g satisfication rate 88.1423, v_m satisfication rate 93.6737, test_line_limit_satisfication_rate 99.8784, test_line_limit_satisfication_rate_Sf 99.8758, test_line_limit_satisfication_rate_St 99.8809, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 16.6515, test obj 12.8466, ineq max 2.1541, ineq mean 0.0061, ineq q_g num viol 1.3118, ineq v_m num viol 5.5806, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.6989, q_g satisfication rate 88.0743, v_m satisfication rate 93.6692, test_line_limit_satisfication_rate 99.8797, test_line_limit_satisfication_rate_Sf 99.8771, test_line_limit_satisfication_rate_St 99.8822, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 16.8034, test obj 12.8466, ineq max 2.2299, ineq mean 0.0064, ineq q_g num viol 1.3085, ineq v_m num viol 5.5745, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7447, q_g satisfication rate 88.1045, v_m satisfication rate 93.6768, test_line_limit_satisfication_rate 99.8759, test_line_limit_satisfication_rate_Sf 99.8733, test_line_limit_satisfication_rate_St 99.8784, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 16.9728, test obj 12.8455, ineq max 2.3139, ineq mean 0.0066, ineq q_g num viol 1.3263, ineq v_m num viol 5.5684, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.7895, q_g satisfication rate 87.9426, v_m satisfication rate 93.6724, test_line_limit_satisfication_rate 99.8722, test_line_limit_satisfication_rate_Sf 99.8697, test_line_limit_satisfication_rate_St 99.8747, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 16.9316, test obj 12.8454, ineq max 2.2908, ineq mean 0.0066, ineq q_g num viol 1.3333, ineq v_m num viol 5.5625, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.8333, q_g satisfication rate 87.8788, v_m satisfication rate 93.6681, test_line_limit_satisfication_rate 99.8735, test_line_limit_satisfication_rate_Sf 99.8710, test_line_limit_satisfication_rate_St 99.8760, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 17.1971, test obj 12.8446, ineq max 2.4246, ineq mean 0.0070, ineq q_g num viol 1.3299, ineq v_m num viol 5.5567, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.8763, q_g satisfication rate 87.9100, v_m satisfication rate 93.6754, test_line_limit_satisfication_rate 99.8699, test_line_limit_satisfication_rate_Sf 99.8674, test_line_limit_satisfication_rate_St 99.8724, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 17.3583, test obj 12.8438, ineq max 2.5057, ineq mean 0.0073, ineq q_g num viol 1.3163, ineq v_m num viol 5.5510, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.9184, q_g satisfication rate 88.0334, v_m satisfication rate 93.6826, test_line_limit_satisfication_rate 99.8664, test_line_limit_satisfication_rate_Sf 99.8639, test_line_limit_satisfication_rate_St 99.8688, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 98: test loss 17.3154, test obj 12.8441, ineq max 2.4811, ineq mean 0.0072, ineq q_g num viol 1.3232, ineq v_m num viol 5.5455, eq max 0.0034, eq mean 0.0001, p_g satisfication rate 95.8678, q_g satisfication rate 87.9706, v_m satisfication rate 93.6897, test_line_limit_satisfication_rate 99.8677, test_line_limit_satisfication_rate_Sf 99.8653, test_line_limit_satisfication_rate_St 99.8701, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# ...
# Test batch 67: test loss 14.2858, test obj 9.9051, ineq max 2.5052, ineq mean 0.0070, ineq q_g num viol 1.0000, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.5241, q_g satisfication rate 90.9091, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8809, test_line_limit_satisfication_rate_Sf 99.8740, test_line_limit_satisfication_rate_St 99.8880, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 68: test loss 14.2496, test obj 9.9071, ineq max 2.4923, ineq mean 0.0070, ineq q_g num viol 1.0000, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4427, q_g satisfication rate 90.9091, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8827, test_line_limit_satisfication_rate_Sf 99.8758, test_line_limit_satisfication_rate_St 99.8896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 14.1874, test obj 9.9058, ineq max 2.4572, ineq mean 0.0069, ineq q_g num viol 1.0143, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4935, q_g satisfication rate 90.7792, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8843, test_line_limit_satisfication_rate_Sf 99.8776, test_line_limit_satisfication_rate_St 99.8912, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 14.1365, test obj 9.9067, ineq max 2.4305, ineq mean 0.0068, ineq q_g num viol 1.0000, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4149, q_g satisfication rate 90.9091, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8860, test_line_limit_satisfication_rate_Sf 99.8793, test_line_limit_satisfication_rate_St 99.8927, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 14.0769, test obj 9.9033, ineq max 2.3985, ineq mean 0.0067, ineq q_g num viol 1.0139, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4647, q_g satisfication rate 90.7828, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8876, test_line_limit_satisfication_rate_Sf 99.8810, test_line_limit_satisfication_rate_St 99.8942, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 14.0417, test obj 9.9050, ineq max 2.3854, ineq mean 0.0067, ineq q_g num viol 1.0137, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3885, q_g satisfication rate 90.7846, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8891, test_line_limit_satisfication_rate_Sf 99.8826, test_line_limit_satisfication_rate_St 99.8956, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 13.9915, test obj 9.9057, ineq max 2.3570, ineq mean 0.0066, ineq q_g num viol 1.0135, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3145, q_g satisfication rate 90.7863, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8906, test_line_limit_satisfication_rate_Sf 99.8842, test_line_limit_satisfication_rate_St 99.8970, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 13.9646, test obj 9.9077, ineq max 2.3505, ineq mean 0.0065, ineq q_g num viol 1.0133, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2424, q_g satisfication rate 90.7879, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8921, test_line_limit_satisfication_rate_Sf 99.8857, test_line_limit_satisfication_rate_St 99.8984, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 13.9121, test obj 9.9074, ineq max 2.3202, ineq mean 0.0064, ineq q_g num viol 1.0132, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2919, q_g satisfication rate 90.7895, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8935, test_line_limit_satisfication_rate_Sf 99.8872, test_line_limit_satisfication_rate_St 99.8997, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 13.9159, test obj 9.9055, ineq max 2.3230, ineq mean 0.0064, ineq q_g num viol 1.0260, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3400, q_g satisfication rate 90.6730, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8887, test_line_limit_satisfication_rate_Sf 99.8825, test_line_limit_satisfication_rate_St 99.8949, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 13.8755, test obj 9.9065, ineq max 2.3028, ineq mean 0.0064, ineq q_g num viol 1.0128, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2704, q_g satisfication rate 90.7926, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8901, test_line_limit_satisfication_rate_Sf 99.8840, test_line_limit_satisfication_rate_St 99.8962, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 13.8436, test obj 9.9079, ineq max 2.2895, ineq mean 0.0063, ineq q_g num viol 1.0127, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2025, q_g satisfication rate 90.7940, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8915, test_line_limit_satisfication_rate_Sf 99.8855, test_line_limit_satisfication_rate_St 99.8975, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 13.7943, test obj 9.9071, ineq max 2.2612, ineq mean 0.0062, ineq q_g num viol 1.0250, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2500, q_g satisfication rate 90.6818, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8929, test_line_limit_satisfication_rate_Sf 99.8869, test_line_limit_satisfication_rate_St 99.8988, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 13.7458, test obj 9.9053, ineq max 2.2338, ineq mean 0.0062, ineq q_g num viol 1.0370, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2963, q_g satisfication rate 90.5724, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8942, test_line_limit_satisfication_rate_Sf 99.8883, test_line_limit_satisfication_rate_St 99.9001, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 13.7130, test obj 9.9064, ineq max 2.2186, ineq mean 0.0061, ineq q_g num viol 1.0366, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2306, q_g satisfication rate 90.5765, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8955, test_line_limit_satisfication_rate_Sf 99.8897, test_line_limit_satisfication_rate_St 99.9013, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 13.6718, test obj 9.9070, ineq max 2.1955, ineq mean 0.0061, ineq q_g num viol 1.0241, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.1665, q_g satisfication rate 90.6900, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8967, test_line_limit_satisfication_rate_Sf 99.8910, test_line_limit_satisfication_rate_St 99.9025, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 13.8228, test obj 9.9059, ineq max 2.2737, ineq mean 0.0063, ineq q_g num viol 1.0119, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2121, q_g satisfication rate 90.8009, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8923, test_line_limit_satisfication_rate_Sf 99.8866, test_line_limit_satisfication_rate_St 99.8979, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 13.8598, test obj 9.9034, ineq max 2.2943, ineq mean 0.0064, ineq q_g num viol 1.0118, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2567, q_g satisfication rate 90.8021, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8879, test_line_limit_satisfication_rate_Sf 99.8823, test_line_limit_satisfication_rate_St 99.8935, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 13.8144, test obj 9.9029, ineq max 2.2682, ineq mean 0.0063, ineq q_g num viol 1.0233, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3002, q_g satisfication rate 90.6977, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8893, test_line_limit_satisfication_rate_Sf 99.8837, test_line_limit_satisfication_rate_St 99.8948, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 13.7703, test obj 9.9029, ineq max 2.2425, ineq mean 0.0062, ineq q_g num viol 1.0230, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3427, q_g satisfication rate 90.7001, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8905, test_line_limit_satisfication_rate_Sf 99.8850, test_line_limit_satisfication_rate_St 99.8960, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 13.7284, test obj 9.9033, ineq max 2.2180, ineq mean 0.0061, ineq q_g num viol 1.0227, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2810, q_g satisfication rate 90.7025, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8918, test_line_limit_satisfication_rate_Sf 99.8864, test_line_limit_satisfication_rate_St 99.8972, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 13.6882, test obj 9.9038, ineq max 2.1951, ineq mean 0.0061, ineq q_g num viol 1.0112, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2206, q_g satisfication rate 90.8069, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8930, test_line_limit_satisfication_rate_Sf 99.8876, test_line_limit_satisfication_rate_St 99.8983, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 13.7966, test obj 9.9023, ineq max 2.2511, ineq mean 0.0063, ineq q_g num viol 1.0111, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.2626, q_g satisfication rate 90.8081, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8889, test_line_limit_satisfication_rate_Sf 99.8836, test_line_limit_satisfication_rate_St 99.8942, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 13.7542, test obj 9.9002, ineq max 2.2274, ineq mean 0.0062, ineq q_g num viol 1.0330, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3037, q_g satisfication rate 90.6094, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8901, test_line_limit_satisfication_rate_Sf 99.8849, test_line_limit_satisfication_rate_St 99.8953, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 13.7138, test obj 9.9005, ineq max 2.2041, ineq mean 0.0061, ineq q_g num viol 1.0326, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3439, q_g satisfication rate 90.6127, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8913, test_line_limit_satisfication_rate_Sf 99.8861, test_line_limit_satisfication_rate_St 99.8965, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 13.6741, test obj 9.9001, ineq max 2.1816, ineq mean 0.0061, ineq q_g num viol 1.0323, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.3832, q_g satisfication rate 90.6158, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8925, test_line_limit_satisfication_rate_Sf 99.8874, test_line_limit_satisfication_rate_St 99.8976, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 13.8375, test obj 9.9001, ineq max 2.2648, ineq mean 0.0063, ineq q_g num viol 1.0532, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4217, q_g satisfication rate 90.4255, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8885, test_line_limit_satisfication_rate_Sf 99.8835, test_line_limit_satisfication_rate_St 99.8936, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 14.0145, test obj 9.8990, ineq max 2.3562, ineq mean 0.0066, ineq q_g num viol 1.0526, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4593, q_g satisfication rate 90.4306, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8847, test_line_limit_satisfication_rate_Sf 99.8797, test_line_limit_satisfication_rate_St 99.8897, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 13.9720, test obj 9.8989, ineq max 2.3318, ineq mean 0.0065, ineq q_g num viol 1.0417, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.4962, q_g satisfication rate 90.5303, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8859, test_line_limit_satisfication_rate_Sf 99.8810, test_line_limit_satisfication_rate_St 99.8909, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 14.2477, test obj 9.8981, ineq max 2.4734, ineq mean 0.0070, ineq q_g num viol 1.0412, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.5323, q_g satisfication rate 90.5342, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8822, test_line_limit_satisfication_rate_Sf 99.8773, test_line_limit_satisfication_rate_St 99.8871, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 14.4188, test obj 9.8973, ineq max 2.5616, ineq mean 0.0073, ineq q_g num viol 1.0408, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.5677, q_g satisfication rate 90.5380, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8785, test_line_limit_satisfication_rate_Sf 99.8737, test_line_limit_satisfication_rate_St 99.8834, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 98: test loss 14.3737, test obj 9.8976, ineq max 2.5358, ineq mean 0.0072, ineq q_g num viol 1.0303, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.6024, q_g satisfication rate 90.6336, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8797, test_line_limit_satisfication_rate_Sf 99.8749, test_line_limit_satisfication_rate_St 99.8846, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 99: test loss 14.3532, test obj 9.8994, ineq max 2.5326, ineq mean 0.0072, ineq q_g num viol 1.0200, ineq v_m num viol 4.0000, eq max 0.0028, eq mean 0.0001, p_g satisfication rate 96.5455, q_g satisfication rate 90.7273, v_m satisfication rate 95.5056, test_line_limit_satisfication_rate 99.8809, test_line_limit_satisfication_rate_Sf 99.8762, test_line_limit_satisfication_rate_St 99.8857, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000

# %% [markdown]
# * Arithmetic mean

# %%
## Calculate the results of GraphLDE
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats_contingency[case]['test_obj_cost'])*10000, 4))
    print("GraphLDE eq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_mean']))
    print("GraphLDE eq. max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_max']))
    print("GraphLDE eq. active mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_mean']))
    print("GraphLDE eq. active max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_max']))
    print("GraphLDE eq. reactive mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_mean']))
    print("GraphLDE eq. reactive max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_max']))
    
    print("\n")
    print("GraphLDE ineq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_mean']))
    print("GraphLDE ineq. max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_max']))
    print("GraphLDE ineq. p_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_mean']))
    print("GraphLDE ineq. p_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_max']))
    print("GraphLDE ineq. q_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_mean']))
    print("GraphLDE ineq. q_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_max']))
    print("GraphLDE ineq. v_m mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_mean']))
    print("GraphLDE ineq. v_m max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_max']))
    print("GraphLDE ineq. line_l mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_mean']))
    print("GraphLDE ineq. line_l max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_max']))
    
    print("\n")
    print("GraphLDE p_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_p_g_satisfication rate (%)']))
    print("GraphLDE q_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_q_g_satisfication rate (%)']))
    print("GraphLDE v_m satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_v_m_satisfication rate (%)']))
    print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_Sf(%)']))
    print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_St(%)']))
    print("GraphLDE active eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_active_eq_satisfication rate (%)']))
    print("GraphLDE reactive eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_reactive_eq_satisfication rate (%)']))
    
    print("\n")
    # print("DeepLDE time (ms) <== average value for test dataset:", (test_stats['time']/1000)*1e3)
    print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
    print("\n")
# Out:
# Contingency  0
# GraphLDE obj. value for test samples:  128459.414
# GraphLDE eq. mean for test samples:  0.0001485742
# GraphLDE eq. max for test samples:  0.0033750883
# GraphLDE eq. active mean for test samples:  8.989416e-05
# GraphLDE eq. active max for test samples:  0.0033750883
# GraphLDE eq. reactive mean for test samples:  0.00020725424
# GraphLDE eq. reactive max for test samples:  0.0026893064
#
#
# GraphLDE ineq. mean for test samples:  0.00715829
# GraphLDE ineq. max for test samples:  2.4803436
# GraphLDE ineq. p_g mean for test samples:  0.02352525
# GraphLDE ineq. p_g max for test samples:  0.51755553
# GraphLDE ineq. q_g mean for test samples:  0.005374016
# GraphLDE ineq. q_g max for test samples:  0.094760515
# GraphLDE ineq. v_m mean for test samples:  0.00041605174
# GraphLDE ineq. v_m max for test samples:  0.022959776
# GraphLDE ineq. line_l mean for test samples:  0.00891099
# GraphLDE ineq. line_l max for test samples:  1.9245721
#
#
# GraphLDE p_g satisfication rate for test samples:  95.818184
# GraphLDE q_g satisfication rate for test samples:  88.00001
# GraphLDE v_m satisfication rate for test samples:  93.685394
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.86666
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.871414
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 14.793705940246582
#
#
# Contingency  1
# GraphLDE obj. value for test samples:  98994.18
# GraphLDE eq. mean for test samples:  0.00012530154
# GraphLDE eq. max for test samples:  0.0028080507
# GraphLDE eq. active mean for test samples:  7.62496e-05
# GraphLDE eq. active max for test samples:  0.0028080507
# GraphLDE eq. reactive mean for test samples:  0.0001743535
# GraphLDE eq. reactive max for test samples:  0.0015893931
#
#
# GraphLDE ineq. mean for test samples:  0.007160349
# GraphLDE ineq. max for test samples:  2.5326138
# GraphLDE ineq. p_g mean for test samples:  0.02000097
# GraphLDE ineq. p_g max for test samples:  0.44002137
# GraphLDE ineq. q_g mean for test samples:  0.0025095763
# GraphLDE ineq. q_g max for test samples:  0.048491612
# GraphLDE ineq. v_m mean for test samples:  0.00017304704
# GraphLDE ineq. v_m max for test samples:  0.011500304
# GraphLDE ineq. line_l mean for test samples:  0.009351674
# GraphLDE ineq. line_l max for test samples:  2.074569
#
#
# GraphLDE p_g satisfication rate for test samples:  96.545456
# GraphLDE q_g satisfication rate for test samples:  90.72729
# GraphLDE v_m satisfication rate for test samples:  95.50562
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.87618
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.885704
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 14.793705940246582

# %% [markdown]
# * Harmonic mean

# %%
import statistics as st

## Calculate optimality gap
print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats['test_obj_cost'])*10000, 4))
print("GraphLDE eq. mean for test samples: ", st.harmonic_mean(test_stats['test_eq_mean'])) # print("LDF eq. mean for test samples: ", np.mean(test_stats['test_eq_mean']))
print("GraphLDE eq. max for test samples: ", st.harmonic_mean(test_stats['test_eq_max'])) # print("LDF eq. max for test samples: ", np.mean(test_stats['test_eq_max']))
print("GraphLDE eq. active mean for test samples: ", st.harmonic_mean(test_stats['test_eq_real_mean'])) # print("LDF eq. active mean for test samples: ", np.mean(test_stats['test_eq_real_mean']))
print("GraphLDE eq. active max for test samples: ", st.harmonic_mean(test_stats['test_eq_real_max'])) # print("LDF eq. active max for test samples: ", np.mean(test_stats['test_eq_real_max']))
print("GraphLDE eq. reactive mean for test samples: ", st.harmonic_mean(test_stats['test_eq_react_mean'])) # print("LDF eq. reactive mean for test samples: ", np.mean(test_stats['test_eq_react_mean']))
print("GraphLDE eq. reactive max for test samples: ", st.harmonic_mean(test_stats['test_eq_react_max'])) # print("LDF eq. reactive max for test samples: ", np.mean(test_stats['test_eq_react_max']))
print("\n")
print("GraphLDE ineq. mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_mean'])) # print("LDF ineq. mean for test samples: ", np.mean(test_stats['test_ineq_mean']))
print("GraphLDE ineq. max for test samples: ", st.harmonic_mean(test_stats['test_ineq_max'])) # print("LDF ineq. max for test samples: ", np.mean(test_stats['test_ineq_max']))
print("GraphLDE ineq. p_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_mean'])) # print("LDF ineq. p_g mean for test samples: ", np.mean(test_stats['test_ineq_p_g_mean']))
print("GraphLDE ineq. p_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_max'])) # print("LDF ineq. p_g max for test samples: ", np.mean(test_stats['test_ineq_p_g_max']))
print("GraphLDE ineq. q_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_mean'])) # print("LDF ineq. q_g mean for test samples: ", np.mean(test_stats['test_ineq_q_g_mean']))
print("GraphLDE ineq. q_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_max'])) # print("LDF ineq. q_g max for test samples: ", np.mean(test_stats['test_ineq_q_g_max']))
print("GraphLDE ineq. v_m mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_mean'])) # print("LDF ineq. v_m mean for test samples: ", np.mean(test_stats['test_ineq_v_m_mean']))
print("GraphLDE ineq. v_m max for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_max'])) # print("LDF ineq. v_m max for test samples: ", np.mean(test_stats['test_ineq_v_m_max']))
print("GraphLDE ineq. line_l mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_mean'])) # print("LDF ineq. line_l mean for test samples: ", np.mean(test_stats['test_ineq_line_l_mean']))
print("GraphLDE ineq. line_l max for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_max'])) # print("LDF ineq. line_l max for test samples: ", np.mean(test_stats['test_ineq_line_l_max']))
print("\n")

print("GraphLDE p_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_p_g_satisfication rate (%)'].reshape(-1))) # print("LDF p_g satisfication rate for test samples: ", np.mean(test_stats['test_p_g_satisfication rate (%)']))
print("GraphLDE q_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_q_g_satisfication rate (%)'].reshape(-1))) # print("LDF q_g satisfication rate for test samples: ", np.mean(test_stats['test_q_g_satisfication rate (%)']))
print("GraphLDE v_m satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_v_m_satisfication rate (%)'].reshape(-1))) # print("LDF v_m satisfication rate for test samples: ", np.mean(test_stats['test_v_m_satisfication rate (%)']))
print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_Sf(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']))
print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_St(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']))
print("GraphLDE active eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_active_eq_satisfication rate (%)'].reshape(-1))) # print("LDF active eq satisfication rate for test samples: ", np.mean(test_stats['test_active_eq_satisfication rate (%)']))
print("GraphLDE reactive eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_reactive_eq_satisfication rate (%)'].reshape(-1))) # print("LDF reactive eq satisfication rate for test samples: ", np.mean(test_stats['test_reactive_eq_satisfication rate (%)']))

print("\n")
print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
# Out:
# GraphLDE obj. value for test samples:  114521.91
# GraphLDE eq. mean for test samples:  9.938747e-05
# GraphLDE eq. max for test samples:  0.0027875048
# GraphLDE eq. active mean for test samples:  7.965768e-05
# GraphLDE eq. active max for test samples:  0.0027861511
# GraphLDE eq. reactive mean for test samples:  0.000117550284
# GraphLDE eq. reactive max for test samples:  0.0010674979
#
#
# GraphLDE ineq. mean for test samples:  0.0
# GraphLDE ineq. max for test samples:  0.0
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  0.0
# GraphLDE ineq. q_g max for test samples:  0.0
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  95.96929
# GraphLDE q_g satisfication rate for test samples:  86.06264
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.71365
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.73749
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 13.998639583587646
# /pscratch/sd/k/kjsong/conda/pytorch/2.8.0/lib/python3.12/statistics.py:593: RuntimeWarning: divide by zero encountered in scalar divide
#   T, total, count = _sum(w / x if w else 0 for w, x in zip(weights, data))
