# %% [markdown]
# # N-1 Fine tuning task for FedOPF
#
# * Create N-1 contingencies: number & indicies of cut off lines and generators
#     * For the dataset, we only need to generate load because this is unsupervised way
# * Test on the zero-shot (i.e., just inference by using pretrained client/server/global model)
#     * For branch contingency, zero-shot is effective! (Done)
#     * **However, for generator contingency, fine-tuning must be needed**

# %%
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cu121.html

# !pip install pypower
# !pip install pyrlu
# # !pip install conflictfree

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
# os.environ["PYTORCH_LINALG_WARNINGS"] = "0"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0"
# os.environ["CUDA_VISIBLE_DEVICES"] = '0, 1, 2, 3'

import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Device:', device)  # 출력결과: cuda
print('Count of using GPUs:', torch.cuda.device_count())   #출력결과: 1 (GPU #2 한개 사용하므로)
print('Current cuda device:', torch.cuda.current_device())  # 출력결과: 2 (GPU #2 의미)
# Out:
# Device: cuda
# Count of using GPUs: 1
# Current cuda device: 0

# %%
from utils.utils1354_graphlde import ACOPFProblem
grid_data_path = './data/pglib_opf_case1354.mat'
grid = ACOPFProblem(grid_filename=grid_data_path)
# Out:
# /global/u1/k/kjsong/FedOPF-APPFL/fine-tuning-task/n-1/case1354/utils/utils1354_graphlde.py:88: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   self.slackva = torch.tensor([np.deg2rad(self.ppc['bus'][self.slack, idx_bus.VA])],

# %%
component="branch" # "gen" or "branch"
num_cases = 2
contingencies = grid.check_contingencies(component=component, num_cases=num_cases)

contingencies['contingencies'] = [x for x in contingencies['contingencies'] if x]
acopf_contingencies = []
for c in range(contingencies['num_cases']):
    acopf_contingencies += [ACOPFProblem(grid_filename=grid_data_path, contingencies=contingencies['contingencies'][c], component=component)] # update the grid components' values from modified ppc data based on the contingencies 

    # Put all variables in "data" to the cuda.
    acopf_contingencies[-1]._device = device
    for attr in dir(acopf_contingencies[-1]):
        var = getattr(acopf_contingencies[-1], attr)
        if not callable(var) and not attr.startswith("__") and torch.is_tensor(var):
            try:
                setattr(acopf_contingencies[-1], attr, var.to(device))
            except AttributeError:
                pass
# Out:
# 260
# 1990
# /pscratch/sd/k/kjsong/conda/pytorch/2.8.0/lib/python3.12/site-packages/pypower/pplinsolve.py:27: MatrixRankWarning: Matrix is exactly singular
#   x = spsolve(A, b)
# Did not converge (0.55 seconds)
#
# Objective Function Value = 1857660.08 $/hr
# ================================================================================
# |     System Summary                                                           |
# ================================================================================
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses           1354     Total Gen Capacity   128738.6       -220875.4 to 256915.1
# Generators       260     On-line Capacity     128738.6       -220875.4 to 256915.1
# Committed Gens   260     Generation (actual)  75888.1           18019.8
# Loads            673     Load                 73059.7           13401.4
#   Fixed          673       Fixed              73059.7           13401.4
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts          1082     Shunt (inj)             -0.0           14817.5
# Branches        1990     Losses (I^2 * Z)        27.92           2138.40
# Transformers     240     Branch Charging (inj)     -                0.0
# Inter-ties         0     Total Inter-tie Flow     0.0               0.0
# Areas              1
#
#                           Minimum                      Maximum
#                  -------------------------  --------------------------------
# Voltage Magnitude   1.000 p.u. @ bus 0          1.000 p.u. @ bus 0
# Voltage Angle       0.00 deg   @ bus 0          0.00 deg   @ bus 0
# P Losses (I^2*R)             -                  0.46 MW    @ line 778-1041
# Q Losses (I^2*X)             -                 43.28 MVAr  @ line 778-1041
# Lambda P            0.00 $/MWh @ bus 0          0.00 $/MWh @ bus 0
# Lambda Q            0.00 $/MWh @ bus 0          0.00 $/MWh @ bus 0
#
# ================================================================================
# |     Bus Data                                                                 |
# ================================================================================
#  Bus      Voltage          Generation             Load          Lambda($/MVA-hr)
#   #   Mag(pu) Ang(deg)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)     P        Q
# ----- ------- --------  --------  --------  --------  --------  -------  -------
#     0  1.000    0.
# 237 1234     -       -1.69      3.61      3.61    0.080
# 240 1253     -      -14.96     34.92     34.92    0.050
# 241 1255     -      -20.39     54.32     54.32    0.258
# 244 1273     -      -14.07     35.84     35.84    0.004
# 247 1296   0.002    -28.41    -28.41     28.99      -
# 248 1302     -      -11.61     38.23     38.23    0.048
# 251 1309     -     -101.48    107.59    107.59    0.001
# 256 1335     -      -26.48     73.19     73.19    0.018
# 258 1341     -      -49.16    175.00    175.00    0.335
#
# ================================================================================
# |     Branch Flow Constraints                                                  |
# ================================================================================
# Brnch   From     "From" End        Limit       "To" End        To
#   #     Bus   |Sf| mu    |Sf|     |Smax|     |St|    |St| mu   Bus
# -----  -----  -------  --------  --------  --------  -------  -----
#  118    111     8.495   756.00    756.00    755.14      -      592
#  166   1202    22.609   986.00    986.00    982.83      -     1101
#  226   1169     0.258  1447.00   1447.00   1421.44      -      260
#  229   1169    73.755   821.00    821.00    820.79      -      283
#  296    996      -      819.89    821.00    821.00    31.822   684
#  298    996    74.989   854.00    854.00    845.86      -     1093
#  642    134      -      528.85    529.00    529.00    21.380    63
#  779    843    11.811  1183.00   1183.00   1182.64      -      936
#  828   1351      -     1676.76   1677.00   1677.00    15.862  1287
#  829   1351     9.525  1480.00   1480.00   1446.61      -     1252
# 1201   1252      -      652.44    657.00    657.00     5.263  1045
# 1506    950      -     1709.74   1710.00   1710.00     3.012   243
# 1704    486      -      852.82    853.00    853.00    17.210    16
# 1705   1282      -      852.71    853.00    853.00    19.408   712
# 1706    350      -      852.77    853.00    853.00    19.908   491

# %%
contingencies
# Out:
# {'contingencies': [{'branch': 1581}], 'num_cases': 1}

# %%
from pypower import idx_bus, idx_gen, idx_brch
import numpy as np
import torch_geometric
from torch_geometric.data import Data 
from models.Edge_GNN_solver import Edge_GNNSolver
import copy

# Load data generation (unsupervised)
pd_base = grid.ppc['bus'][:,idx_bus.PD] / grid.baseMVA.item()
qd_base = grid.ppc['bus'][:,idx_bus.QD] / grid.baseMVA.item()
num_data = 200
perturb = (1.0 + np.random.uniform(-0.1, 0.1, size=(num_data, grid.nbus)))

# data sample from uniform distribution
pd_samples = torch.from_numpy(pd_base * perturb).float()
qd_samples = torch.from_numpy(qd_base * perturb).float()
demand = pd_samples + 1j*qd_samples

# %%
# Graph data representation
graph_dataset_contingency = []
graph_dataset_contingency_statics = []

# Model config
train_config = {
    'probType': 'acopf',
    'useCompl': True, # boolean type: whether to use completion (DC3, DeepLDE 기술)

    # GNN model parameters
    'n_gnn_layers': 3,
    'nfeature_dim': 2, # input dim
    'efeature_dim': 4, # edge feature dim 
    'hidden_dim': 40,
    'dropout_rate': 0.1,
    'K': 10, # 6 # only for TAGConv or ChebConv and GATConv (as multi-head)

    # DeepLDE hyperparameters
    'epochs': 20, # 10 (GPU RTX 4090), 8 (GPU A100)
    'batchSize': 5, # 6, (8) (GPU RTX 4090; GPU 다운 에러 발생..), 16 (GPU A100)
    'lr': 1e-2, # 1e-3
    'lr_w': 1e-2, # 1e-3
    # 'weight_decay': 0.0, # 1e-5,
    'weight_decay': 1e-5, # 1e-5,

    # LDF parameters
    # 'rho_init': 0.01, # 0.01  
    'rho_init': 0.1, # 0.01  
    's_init': 0.1,
    'p_iter_max': 5,
    'warmup_iter': 20, # 20, # 0 for non-warmup start cases
    'corrEps': 1e-4, # float type: correction procedure tolerance
}

# Models
contingency_models = []

for case in range(len(acopf_contingencies)):
    node_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus, 2))
    node_mask_x = np.zeros((demand.shape[0], acopf_contingencies[case].nbus))
    for s in range(node_feat_x.shape[0]):
        node_feat_x[s,:,0] = np.real(demand[s,:])
        node_feat_x[s,:,1] = np.imag(demand[s,:])
        node_mask_x[s,acopf_contingencies[case].spv] = 1
        # node_mask_x[s,self.pv] = 1
    
    edge_feat_x = np.zeros((demand.shape[0], acopf_contingencies[case].nl, 6))
    for s in range(edge_feat_x.shape[0]):
        edge_feat_x[s,:,0] = acopf_contingencies[case].ppc['branch'][:, idx_brch.F_BUS]
        edge_feat_x[s,:,1] = acopf_contingencies[case].ppc['branch'][:, idx_brch.T_BUS]
        edge_feat_x[s,:,2] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_R]
        edge_feat_x[s,:,3] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_X]
        edge_feat_x[s,:,4] = acopf_contingencies[case].ppc['branch'][:, idx_brch.BR_B]
        
        br_ratea_feat = (acopf_contingencies[case].ppc['branch'][:, idx_brch.RATE_A] / acopf_contingencies[case].baseMVA)
        # br_ratea_feat[br_ratea_feat == 0] = np.Inf
        edge_feat_x[s,:,5] = br_ratea_feat

    node_feat_x = torch.tensor(node_feat_x[:,:,:], dtype=torch.get_default_dtype())
    node_mask_x = torch.tensor(node_mask_x[:,:], dtype=torch.get_default_dtype())
    edge_feat_x = torch.tensor(edge_feat_x[:,:,:], dtype=torch.get_default_dtype())
    pyg_data_list = []
    for i in range(demand.shape[0]):
        pyg_data_list += [Data(
            x=node_feat_x[i,:,:],
            node_mask=node_mask_x[i,:].to(torch.bool),
            edge_index=edge_feat_x[i, :, 0:2].T.to(torch.long),
            edge_attr=edge_feat_x[i, :, 2:],) # R,X,B,RateA
            ]
    
    graph_dataset_contingency += [pyg_data_list]
    
    node_dataset = torch.zeros((acopf_contingencies[case].nbus*len(pyg_data_list),2))
    edge_dataset = torch.zeros((acopf_contingencies[case].nl*len(pyg_data_list),4))
    for (i,data) in enumerate(pyg_data_list):
        node_dataset[acopf_contingencies[case].nbus*i:acopf_contingencies[case].nbus*(i+1),:] = data.x
        edge_dataset[acopf_contingencies[case].nl*i:acopf_contingencies[case].nl*(i+1),:] = data.edge_attr
    
    node_means = node_dataset.mean(axis=0, keepdims = True)
    node_stds = node_dataset.std(axis=0, keepdims = True)
    edge_means = edge_dataset.mean(axis=0, keepdims = True)
    edge_stds = edge_dataset.std(axis=0, keepdims = True)

    graph_dataset_contingency_statics += [[node_means.to(dtype=torch.get_default_dtype()),
                                          node_stds.to(dtype=torch.get_default_dtype()),
                                          edge_means.to(dtype=torch.get_default_dtype()),
                                          edge_stds.to(dtype=torch.get_default_dtype())]]

    data_loader = torch_geometric.loader.DataLoader(pyg_data_list, batch_size=1, shuffle=False, drop_last=True)
    solver_net = Edge_GNNSolver(acopf_contingencies[case], train_config)
    contingency_models += [solver_net]

    print(solver_net)
# Out:
# Edge_GNNSolver(
#   (layers): ModuleList(
#     (0): EdgeAggregation()
#     (1): TransformerConv(120, 40, heads=10)
#     (2): EdgeAggregation()
#     (3): TransformerConv(120, 40, heads=10)
#     (4): EdgeAggregation()
#     (5): TransformerConv(120, 40, heads=10)
#   )
#   (flatten): Linear(in_features=31200, out_features=519, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# /tmp/ipykernel_45101/83984568.py:59: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,0] = np.real(demand[s,:])
# /tmp/ipykernel_45101/83984568.py:60: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   node_feat_x[s,:,1] = np.imag(demand[s,:])

# %% [markdown]
# * Load pretrained GraphOPF model

# %%
pretrained_client = torch.load("./models/pretrained_models/client/checkpoint_Client11.pth", weights_only=False, map_location=device)
# pretrained_server = torch.load("./models/pretrained_models/server/checkpoint_Server_1.pth", weights_only=False, map_location=device)
# pretrained_global = torch.load("./models/pretrained_models/global/checkpoint_Global.pth", weights_only=False, map_location=device)

# %%
for contingency_model in contingency_models:
    if component == 'gen':
        print("Generator contingency")
        # Dimension reduction for N-1 contingency
        new_row = contingency_model.flatten.weight.shape[0] 
        new_col = contingency_model.flatten.weight.shape[1]
        old_row = pretrained_client['flatten.weight'].shape[0]
        old_col = pretrained_client['flatten.weight'].shape[1]
    
        pretrained_flatten_weight = copy.deepcopy(pretrained_client['flatten.weight'])
        pretrained_flatten_bias = copy.deepcopy(pretrained_client['flatten.bias'])
        
        # Way 1
        row_norm = torch.norm(pretrained_flatten_weight, dim=1)
        rows_removed = torch.argsort(row_norm)[:old_row - new_row]
        col_norm = torch.norm(pretrained_flatten_weight, dim=0)
        cols_removed = torch.argsort(col_norm)[:old_col - new_col]
        
        row_mask = torch.ones(pretrained_flatten_weight.size(0), dtype=torch.bool, device=device)
        row_mask[rows_removed] = False
        col_mask = torch.ones(pretrained_flatten_weight.size(1), dtype=torch.bool, device=device)
        col_mask[cols_removed] = False

        shrinked_weight = pretrained_flatten_weight[row_mask][:, col_mask]
        shrinked_bias = pretrained_flatten_bias[row_mask] # corresponding to the flatten.weight

        # # Way 2
        # shrinked_weight = pretrained_flatten_weight[(old_row - new_row):, (old_col - new_col):]
        # shrinked_bias = pretrained_flatten_bias[(old_row - new_row):] # corresponding to the flatten.weight

        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()
        
        layer_names = list(target_state_dict.keys())
        for name in layer_names[:-2]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()
            
        for name in layer_names[-2:]:
            if 'weight' in name:
                # print('weight load')
                target_state_dict[name] = shrinked_weight
            elif 'bias' in name:
                # print('bias load')
                target_state_dict[name] = shrinked_bias
    
    elif component == 'branch':
        print("Branch contingency")
        ### Transfer the weights from the pretrained GraphOPF
        global_pretrained_state_dict = pretrained_client
        target_state_dict = contingency_model.state_dict()

        layer_names = list(target_state_dict.keys())
        for name in layer_names[:]:
            if name in target_state_dict.keys() and name in global_pretrained_state_dict.keys():
                # print(name)
                target_state_dict[name] = global_pretrained_state_dict[name].clone()

    contingency_model.load_state_dict(target_state_dict)

    # Freezing the half-GNN layers
    for i, (name, param) in enumerate(contingency_model.named_parameters()):
        if i <= 32: # 5, 10, 21
            # print(name)
            param.requires_grad = False
        else:
            print(name)
            param.requires_grad = True
# Out:
# Branch contingency
# flatten.weight
# flatten.bias

# %% [markdown]
# * Fine-tuning (for generator contingency)

# %%
import torch.optim as optim
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

# Set the linear algebra solver(?)
torch._C._set_linalg_preferred_backend(torch._C._LinalgBackend.Cusolver) # torch._C._LinalgBackend.Magma, torch._C._LinalgBackend.Cusolver
# torch._C._get_linalg_preferred_backend() 

# stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    stats = {}
    
    # NOTE: LDF parameters.
    LagM_sp_gen = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_gen = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_bus = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    warmup_iter = train_config["warmup_iter"] # the warmup period: the NN is trained with an additional inner iteration before the first outer iteration.
    rho_init = train_config["rho_init"]
    
    rho = rho_init
    
    rho_iter = 0
    s_iter = 0
    
    p_iter_max = train_config["p_iter_max"]
    p_iter_max_sum = p_iter_max
    
    d = 0 # 0 for static case otherwise use 5"
    beta = 0 # 0.001 # 0 for static case otherwise use 1
    
    lr_w = train_config["lr_w"] # 이거 증가해도 되지 않을지?
    lr = train_config["lr"]
    print_interval = 1
    eps_converge = 1e-4
    
    contingency_models[case] = contingency_models[case].to(device)
    train_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][:20], batch_size=train_config['batchSize'], shuffle=True, drop_last=True)
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    train_loss_list = []
    train_start_time = time.time()
    for i in range(train_config["epochs"]):
        epoch_stats = {}
        ################### TRAINING PHASE ###################
        solver_net.train()
        if i<warmup_iter:
            ######### WARM-UP PERIOD #########
            if i == 0:
                solver_opt = optim.Adam(contingency_models[case].parameters(), lr=lr_w) # this will be reinitalized after warmup stage
                print("Warmup start!")
    
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                # start_time = time.time()
                solver_opt.zero_grad()
    
                # DNN + NR (equality constraint)
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, train_obj, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        else:
            if i == warmup_iter:
                print("Warmup ended!")
                # data.ref_freedom = False
    
                # ineq_lag_flag = True # for the first warmup end epoch, consider lag. multipliers update of ineq.
            # elif (i - warmup_iter)%ineq_lag_flag_trigger == 0:
            #     # print("Doing test... continue this case..")
            #     print("consider lagrangian multipliers update for ineq. constraints!")
            #     ineq_lag_flag = True
            # else:
            #     ineq_lag_flag = False
    
            # for every (updated) p_iter_max_sum time.
            if (i - warmup_iter)%p_iter_max_sum == 0:
                ######### Outer Interation: calculate step size of lagrangian multipliers update #########
                if i> warmup_iter:
                    print("current epoch %d || p_iter_max updated : %d -> %d" %(i, p_iter_max, p_iter_max + d))
                    # s = s_init * (1/(1+beta*(s_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    # s_iter += 1
                    # print("mu iter updated : %d -> %d" %(s_iter-1, s_iter))
    
                    rho = rho_init * (1/(1+beta*(rho_iter + 1))) # 근데 이 부분 중복아닌가?? 있어야 하나????
                    rho_iter += 1
                    print("rho iter updated : %d -> %d" %(rho_iter-1, rho_iter))
                    p_iter_max = p_iter_max + d
                    p_iter_max_sum += p_iter_max
    
                with torch.no_grad():
                    print("Lambda updated at %d epoch" %i)
                    contingency_models[case].eval()
                    for Xtrain in train_loader:
                        Xtrain = Xtrain.to(device)
                        #solver_opt.zero_grad()
                        Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                        # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                        # LagM += rho*ineq_violation(data, Xtrain.x, Yhat_train) # Update the lagrangian multiplier.
                        LagM_sp_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[:2] # Update the lagrangian multiplier.
                        LagM_gen += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2:2+2*acopf_contingencies[case].ng] # Update the lagrangian multiplier.
                        LagM_bus += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus] # Update the lagrangian multiplier.
                        LagM_line += rho*ineq_violation(acopf_contingencies[case], Xtrain.x, Yhat_train)[2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:] # Update the lagrangian multiplier.
                
                ## Does this stablize the learning process much better?
                LagM_sp_gen = (LagM_sp_gen/len(train_loader))
                LagM_gen = (LagM_gen/len(train_loader))
                LagM_bus = (LagM_bus/len(train_loader))
                LagM_line = (LagM_line/len(train_loader))
    
                # solver_opt = optim.Adam(contingency_models[0].parameters(), lr = lr)
    
            contingency_models[case].train()
            for Xtrain in train_loader:
                Xtrain = Xtrain.to(device)
                solver_opt.zero_grad()
                Yhat_train = contingency_models[case](Xtrain, n_means, n_stds, e_means, e_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
                # Yhat_train = solver_net(Xtrain, n_means, n_stds) # solve power flow equation using Newton-Rahpson method (NOTE: if "useCompl" is True.)
    
                # train_loss, obj_train, ineq_dist, eq_resid = total_loss(data, Xtrain.x, Yhat_train, LagM) # LagM is lagrangian multiplier (1, num_inequalities)
                train_loss, train_obj, ineq_dist, eq_resid = total_loss(acopf_contingencies[case], Xtrain.x, Yhat_train, LagM_sp_gen, LagM_gen, LagM_bus, LagM_line)
    
                train_loss.sum().backward()
                solver_opt.step()
    
                dict_agg(epoch_stats, 'train_loss', train_loss.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_obj', train_obj.detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_max', torch.max(ineq_dist, dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_mean', torch.mean(ineq_dist, dim=1).detach().cpu().numpy())
    
                ineq_p_g = ineq_dist[:,:2]
                ineq_q_g = ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
                ineq_v_m = ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
                ineq_line_l = ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
                dict_agg(epoch_stats, 'train_ineq_p_g_num_viol_0', torch.sum(ineq_p_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_q_g_num_viol_0', torch.sum(ineq_q_g > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_v_m_num_viol_0', torch.sum(ineq_v_m > eps_converge, dim=1).detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_ineq_line_thermal_num_viol_0', torch.sum(ineq_line_l > eps_converge, dim=1).detach().cpu().numpy())
    
                dict_agg(epoch_stats, 'train_eq_max', torch.max(torch.abs(eq_resid), dim=1)[0].detach().cpu().numpy())
                dict_agg(epoch_stats, 'train_eq_mean', torch.mean(torch.abs(eq_resid), dim=1).detach().cpu().numpy())
    
        if (i == 0) or (i%print_interval == 0):
            print(
                'Epoch {}: train loss {:.4f}, train obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq p_g num viol {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, ineq line_theraml num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}'.format(
                    i, np.mean(epoch_stats['train_loss']), np.mean(epoch_stats['train_obj']), np.mean(epoch_stats['train_ineq_max']), np.mean(epoch_stats['train_ineq_mean']),
                    np.mean(epoch_stats['train_ineq_p_g_num_viol_0']), np.mean(epoch_stats['train_ineq_q_g_num_viol_0']), np.mean(epoch_stats['train_ineq_v_m_num_viol_0']), np.mean(epoch_stats['train_ineq_line_thermal_num_viol_0']),
                    np.mean(epoch_stats['train_eq_max']), np.mean(epoch_stats['train_eq_mean'])))
        
        train_loss_list.append(np.mean(epoch_stats['train_loss']))
        # valid_eval_list.append(np.mean(epoch_stats['valid_eval']))
    # stats_contingency += []
    print("\n")
train_end_time = time.time()
total_train_time = train_end_time - train_start_time
# Out:
# Contingency  0
# Warmup start!
# Epoch 0: train loss 279679.1562, train obj 187.4359, ineq max 64786.7578, ineq mean 38.7645, ineq p_g num viol 0.8500, ineq q_g num viol 183.7000, ineq v_m num viol 4.2500, ineq line_theraml num viol 144.3500, eq max 0.0017, eq mean 0.0000
# Epoch 1: train loss 12545.2041, train obj 184.1738, ineq max 2227.2234, ineq mean 1.7144, ineq p_g num viol 0.4000, ineq q_g num viol 177.1500, ineq v_m num viol 0.9000, ineq line_theraml num viol 39.4500, eq max 0.0017, eq mean 0.0000
# Epoch 2: train loss 4859.2363, train obj 178.3847, ineq max 684.1532, ineq mean 0.6492, ineq p_g num viol 0.6500, ineq q_g num viol 163.5000, ineq v_m num viol 0.2500, ineq line_theraml num viol 29.8000, eq max 0.0019, eq mean 0.0000
# Epoch 3: train loss 2695.0518, train obj 188.3869, ineq max 375.5156, ineq mean 0.3477, ineq p_g num viol 1.0000, ineq q_g num viol 160.2000, ineq v_m num viol 2.3000, ineq line_theraml num viol 20.8500, eq max 0.0015, eq mean 0.0000
# Epoch 4: train loss 2113.7441, train obj 184.9671, ineq max 348.2220, ineq mean 0.2675, ineq p_g num viol 1.0000, ineq q_g num viol 141.7000, ineq v_m num viol 4.7000, ineq line_theraml num viol 13.9500, eq max 0.0019, eq mean 0.0000
# Epoch 5: train loss 2157.1768, train obj 176.1368, ineq max 356.4382, ineq mean 0.2748, ineq p_g num viol 0.6000, ineq q_g num viol 141.1500, ineq v_m num viol 6.9500, ineq line_theraml num viol 12.9000, eq max 0.0017, eq mean 0.0000
# Epoch 6: train loss 1282.0092, train obj 169.2858, ineq max 194.1228, ineq mean 0.1543, ineq p_g num viol 0.3000, ineq q_g num viol 129.0500, ineq v_m num viol 6.9000, ineq line_theraml num viol 9.4500, eq max 0.0018, eq mean 0.0000
# Epoch 7: train loss 964.6318, train obj 168.3509, ineq max 167.2397, ineq mean 0.1104, ineq p_g num viol 0.3500, ineq q_g num viol 125.2000, ineq v_m num viol 5.8500, ineq line_theraml num viol 6.4000, eq max 0.0017, eq mean 0.0000
# Epoch 8: train loss 697.4929, train obj 170.4415, ineq max 85.5240, ineq mean 0.0731, ineq p_g num viol 0.1500, ineq q_g num viol 117.9500, ineq v_m num viol 5.3000, ineq line_theraml num viol 5.4500, eq max 0.0018, eq mean 0.0000
# Epoch 9: train loss 635.7285, train obj 170.5649, ineq max 73.2634, ineq mean 0.0645, ineq p_g num viol 0.1500, ineq q_g num viol 122.2500, ineq v_m num viol 5.3500, ineq line_theraml num viol 4.6000, eq max 0.0017, eq mean 0.0000
# Epoch 10: train loss 448.0255, train obj 169.6190, ineq max 43.3805, ineq mean 0.0386, ineq p_g num viol 0.1000, ineq q_g num viol 102.4000, ineq v_m num viol 4.3000, ineq line_theraml num viol 2.2000, eq max 0.0017, eq mean 0.0000
# Epoch 11: train loss 375.9039, train obj 168.4182, ineq max 41.1785, ineq mean 0.0288, ineq p_g num viol 0.0500, ineq q_g num viol 91.9000, ineq v_m num viol 4.3500, ineq line_theraml num viol 1.6000, eq max 0.0017, eq mean 0.0000
# Epoch 12: train loss 349.7869, train obj 167.4597, ineq max 32.5243, ineq mean 0.0253, ineq p_g num viol 0.1000, ineq q_g num viol 87.5000, ineq v_m num viol 4.2500, ineq line_theraml num viol 1.6000, eq max 0.0017, eq mean 0.0000
# Epoch 13: train loss 299.6996, train obj 166.5461, ineq max 22.9055, ineq mean 0.0185, ineq p_g num viol 0.2000, ineq q_g num viol 79.5500, ineq v_m num viol 4.6500, ineq line_theraml num viol 1.2000, eq max 0.0018, eq mean 0.0000
# Epoch 14: train loss 310.6302, train obj 166.1754, ineq max 25.6783, ineq mean 0.0200, ineq p_g num viol 0.2500, ineq q_g num viol 79.0500, ineq v_m num viol 4.3500, ineq line_theraml num viol 1.5000, eq max 0.0016, eq mean 0.0000
# Epoch 15: train loss 293.4662, train obj 166.5010, ineq max 18.0236, ineq mean 0.0176, ineq p_g num viol 0.0500, ineq q_g num viol 80.7500, ineq v_m num viol 2.2500, ineq line_theraml num viol 1.2500, eq max 0.0017, eq mean 0.0000
# Epoch 16: train loss 278.6917, train obj 166.3682, ineq max 16.0577, ineq mean 0.0156, ineq p_g num viol 0.1500, ineq q_g num viol 72.3500, ineq v_m num viol 0.5500, ineq line_theraml num viol 1.1000, eq max 0.0017, eq mean 0.0000
# Epoch 17: train loss 277.2238, train obj 165.3885, ineq max 21.6478, ineq mean 0.0155, ineq p_g num viol 0.2500, ineq q_g num viol 67.6500, ineq v_m num viol 0.8000, ineq line_theraml num viol 1.4500, eq max 0.0016, eq mean 0.0000
# Epoch 18: train loss 282.8348, train obj 165.9677, ineq max 19.8629, ineq mean 0.0162, ineq p_g num viol 0.0500, ineq q_g num viol 72.3000, ineq v_m num viol 0.7500, ineq line_theraml num viol 1.5000, eq max 0.0017, eq mean 0.0000
# Epoch 19: train loss 297.5095, train obj 164.8952, ineq max 20.9304, ineq mean 0.0184, ineq p_g num viol 0.3500, ineq q_g num viol 77.6000, ineq v_m num viol 2.2500, ineq line_theraml num viol 1.7000, eq max 0.0015, eq mean 0.0000
#
#
# Contingency  1
# Warmup start!
# Epoch 0: train loss 140846.6875, train obj 189.9647, ineq max 32935.9453, ineq mean 19.5086, ineq p_g num viol 0.7500, ineq q_g num viol 173.1500, ineq v_m num viol 1.7000, ineq line_theraml num viol 76.1500, eq max 0.0016, eq mean 0.0000
# Epoch 1: train loss 14899.1484, train obj 183.0983, ineq max 2920.2800, ineq mean 2.0411, ineq p_g num viol 0.8500, ineq q_g num viol 171.5000, ineq v_m num viol 2.8500, ineq line_theraml num viol 38.7000, eq max 0.0017, eq mean 0.0000
# Epoch 2: train loss 3195.0554, train obj 189.2395, ineq max 593.5876, ineq mean 0.4169, ineq p_g num viol 1.0000, ineq q_g num viol 131.0500, ineq v_m num viol 0.6500, ineq line_theraml num viol 20.2500, eq max 0.0018, eq mean 0.0000
# Epoch 3: train loss 1651.7024, train obj 185.5018, ineq max 277.8742, ineq mean 0.2034, ineq p_g num viol 1.0000, ineq q_g num viol 127.4000, ineq v_m num viol 1.6000, ineq line_theraml num viol 15.8000, eq max 0.0016, eq mean 0.0000
# Epoch 4: train loss 733.3970, train obj 182.1526, ineq max 108.6692, ineq mean 0.0765, ineq p_g num viol 0.4000, ineq q_g num viol 110.8500, ineq v_m num viol 4.2500, ineq line_theraml num viol 9.0500, eq max 0.0017, eq mean 0.0000
# Epoch 5: train loss 497.4602, train obj 182.9115, ineq max 49.0512, ineq mean 0.0436, ineq p_g num viol 0.6000, ineq q_g num viol 105.6500, ineq v_m num viol 4.3500, ineq line_theraml num viol 5.6000, eq max 0.0016, eq mean 0.0000
# Epoch 6: train loss 316.0435, train obj 179.6952, ineq max 14.0420, ineq mean 0.0189, ineq p_g num viol 0.2000, ineq q_g num viol 87.1000, ineq v_m num viol 4.5000, ineq line_theraml num viol 1.0000, eq max 0.0017, eq mean 0.0000
# Epoch 7: train loss 308.7151, train obj 176.5407, ineq max 22.1472, ineq mean 0.0183, ineq p_g num viol 0.1000, ineq q_g num viol 91.2500, ineq v_m num viol 5.2500, ineq line_theraml num viol 1.8000, eq max 0.0016, eq mean 0.0000
# Epoch 8: train loss 292.7805, train obj 175.9659, ineq max 19.3175, ineq mean 0.0162, ineq p_g num viol 0.1500, ineq q_g num viol 89.6500, ineq v_m num viol 4.9000, ineq line_theraml num viol 1.5000, eq max 0.0015, eq mean 0.0000
# Epoch 9: train loss 245.2558, train obj 173.7903, ineq max 8.2804, ineq mean 0.0099, ineq p_g num viol 0.5000, ineq q_g num viol 74.3000, ineq v_m num viol 5.1000, ineq line_theraml num viol 0.6500, eq max 0.0017, eq mean 0.0000
# Epoch 10: train loss 247.1031, train obj 174.2855, ineq max 8.2137, ineq mean 0.0101, ineq p_g num viol 0.1500, ineq q_g num viol 73.3500, ineq v_m num viol 4.9000, ineq line_theraml num viol 0.9000, eq max 0.0016, eq mean 0.0000
# Epoch 11: train loss 220.0368, train obj 173.3530, ineq max 5.9905, ineq mean 0.0065, ineq p_g num viol 0.1000, ineq q_g num viol 62.8500, ineq v_m num viol 4.9000, ineq line_theraml num viol 0.2500, eq max 0.0016, eq mean 0.0000
# Epoch 12: train loss 216.3562, train obj 172.3687, ineq max 6.3042, ineq mean 0.0061, ineq p_g num viol 0.2000, ineq q_g num viol 56.5000, ineq v_m num viol 4.8500, ineq line_theraml num viol 0.2500, eq max 0.0016, eq mean 0.0000
# Epoch 13: train loss 216.9216, train obj 171.8683, ineq max 5.7200, ineq mean 0.0062, ineq p_g num viol 0.1000, ineq q_g num viol 59.2000, ineq v_m num viol 4.3500, ineq line_theraml num viol 0.5000, eq max 0.0017, eq mean 0.0000
# Epoch 14: train loss 206.6458, train obj 170.9994, ineq max 4.7963, ineq mean 0.0049, ineq p_g num viol 0.2500, ineq q_g num viol 52.2000, ineq v_m num viol 4.2500, ineq line_theraml num viol 0.4000, eq max 0.0015, eq mean 0.0000
# Epoch 15: train loss 205.0275, train obj 169.9382, ineq max 5.4237, ineq mean 0.0049, ineq p_g num viol 0.3000, ineq q_g num viol 53.0000, ineq v_m num viol 4.2500, ineq line_theraml num viol 0.3000, eq max 0.0016, eq mean 0.0000
# Epoch 16: train loss 201.5175, train obj 169.9415, ineq max 4.1718, ineq mean 0.0044, ineq p_g num viol 0.1000, ineq q_g num viol 50.2000, ineq v_m num viol 4.3000, ineq line_theraml num viol 0.2000, eq max 0.0014, eq mean 0.0000
# Epoch 17: train loss 208.5407, train obj 168.9353, ineq max 6.3002, ineq mean 0.0055, ineq p_g num viol 0.1500, ineq q_g num viol 51.7000, ineq v_m num viol 4.3000, ineq line_theraml num viol 0.4500, eq max 0.0017, eq mean 0.0000
# Epoch 18: train loss 204.5621, train obj 168.6709, ineq max 6.5943, ineq mean 0.0050, ineq p_g num viol 0.0500, ineq q_g num viol 47.0500, ineq v_m num viol 4.4000, ineq line_theraml num viol 0.3000, eq max 0.0015, eq mean 0.0000
# Epoch 19: train loss 202.0893, train obj 167.6566, ineq max 5.4974, ineq mean 0.0048, ineq p_g num viol 0.1000, ineq q_g num viol 47.2000, ineq v_m num viol 4.3500, ineq line_theraml num viol 0.5000, eq max 0.0018, eq mean 0.0000

# %%
total_train_time
# Out:
# 24.77087140083313

# %% [markdown]
# * Evaluation (zero-shot)

# %%
from pypower.api import makeYbus
import time
from utils.loss_fn_graphlde import total_loss, ineq_violation
from utils.log import dict_agg

test_stats_contingency = []
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    Ybus, Yf, Yt = makeYbus(acopf_contingencies[case].baseMVA, acopf_contingencies[case].ppc['bus'], acopf_contingencies[case].ppc['branch'])
    # branch thermal limit information
    flow_max = (acopf_contingencies[case].ppc['branch'][:, 5] / acopf_contingencies[case].baseMVA)**2
    flow_max[flow_max == 0] = np.inf
    flow_max = torch.tensor(flow_max, dtype=torch.float32).to(device)
    
    node_means, node_stds, edge_means, edge_stds = graph_dataset_contingency_statics[case][0], graph_dataset_contingency_statics[case][1], graph_dataset_contingency_statics[case][2], graph_dataset_contingency_statics[case][3]
    n_means = node_means.to(device)
    n_stds = node_stds.to(device)
    e_means = edge_means.to(device)
    e_stds = edge_stds.to(device)
    
    test_loader = torch_geometric.loader.DataLoader(graph_dataset_contingency[case][100:], batch_size=1, shuffle=False, drop_last=True)
    contingency_models[case] = contingency_models[case].to(device)
    contingency_models[case].eval()
    test_stats = {}
    # test_stats["Contingency"] = case
    test_eps_converge = 1e-4
    
    LagM_sp_g = torch.ones(1, 2).to(device) # shape: (1, num_inequalities)
    LagM_q_g = torch.ones(1, 2*acopf_contingencies[case].ng).to(device) # shape: (1, num_inequalities)
    LagM_v_m = torch.ones(1, 2*acopf_contingencies[case].nbus).to(device) # shape: (1, num_inequalities)
    LagM_line_l = torch.ones(1, 2*acopf_contingencies[case].nl).to(device) # shape: (1, num_inequalities)
    
    solve_time = []
    for (i, Xtest) in enumerate(test_loader):
        Xtest = Xtest.to(device)
    
        start_time = time.time()
        Y = contingency_models[case](Xtest, n_means, n_stds, e_means, e_stds)
        end_time = time.time()
    
        solve_time += [end_time - start_time]
    
        ## line thermal limit
        pg, qg, vm, va = acopf_contingencies[case].get_yvars(Y)
        vr = vm*torch.cos(va)
        vi = vm*torch.sin(va)
        vz = torch.complex(vr, vi) # complex voltage
    
        # calculate the branch current of from bus and to bus based on the Yf*V and Yt*V
        If = torch.tensor(Yf.todense(), dtype=torch.complex64).to(device) @ vz.T
        It = torch.tensor(Yt.todense(), dtype=torch.complex64).to(device) @ vz.T
    
        # Calculate the apparent power S
        Sf = vz[:,acopf_contingencies[case].ppc['branch'][:,0].astype(int)] * torch.conj(If.T)
        St = vz[:,acopf_contingencies[case].ppc['branch'][:,1].astype(int)] * torch.conj(It.T)
        Sff = Sf * torch.conj(Sf)
        Stt = St * torch.conj(St)
    
        # calculate the line thermal limit constraints violation
        diff_Sf = Sff.real - flow_max
        diff_St = Stt.real - flow_max
        # diff_Sf[torch.clamp(diff_Sf, 0) != 0]
    
        line_limit_vio_Sf = torch.clamp(diff_Sf, 0)
        line_limit_vio_St = torch.clamp(diff_St, 0)
        ###########################################
    
        # test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(data, Xtest.x, Y, LagM)
        test_loss, test_obj_cost, test_ineq_dist, test_eq_resid = total_loss(acopf_contingencies[case], Xtest.x, Y, LagM_sp_g, LagM_q_g, LagM_v_m, LagM_line_l) # LagM is lagrangian multiplier, and the shape is (1, num_inequalities)
    
        dict_agg(test_stats, 'time', end_time - start_time, op='sum')
    
        test_ineq_p_g = torch.cat([pg - acopf_contingencies[case].pmax, acopf_contingencies[case].pmin - pg], dim=1)
        test_ineq_p_g = torch.clamp(test_ineq_p_g, 0).to(device)
        test_ineq_q_g = test_ineq_dist[:,2:2+2*acopf_contingencies[case].ng]
        test_ineq_v_m = test_ineq_dist[:,2+2*acopf_contingencies[case].ng:2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus]
        test_ineq_line_l = test_ineq_dist[:,2+2*acopf_contingencies[case].ng+2*acopf_contingencies[case].nbus:]
    
        dict_agg(test_stats, 'test_loss', test_loss.detach().cpu().numpy())
        # dict_agg(test_stats, 'test_loss', (test_loss[0]+test_loss[1]+test_loss[2]+test_loss[3]).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_obj_cost', test_obj_cost.detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_max', torch.max(test_ineq_dist, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_mean', torch.mean(test_ineq_dist, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_max', torch.max(test_ineq_p_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_p_g_mean', torch.mean(test_ineq_p_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_max', torch.max(test_ineq_q_g, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_q_g_mean', torch.mean(test_ineq_q_g, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_max', torch.max(test_ineq_v_m, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_mean', torch.mean(test_ineq_v_m, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_max', torch.max(test_ineq_line_l, dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_line_l_mean', torch.mean(test_ineq_line_l, dim=1).detach().cpu().numpy())
    
        pg_rate_torch = (((pg <= acopf_contingencies[case].pmax) & (pg >= acopf_contingencies[case].pmin)).sum()/acopf_contingencies[case].ng)*100
        qg_rate_torch = (((qg <= acopf_contingencies[case].qmax) & (qg >= acopf_contingencies[case].qmin)).sum()/acopf_contingencies[case].ng)*100
        dict_agg(test_stats, 'test_p_g_satisfication rate (%)', pg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_q_g_satisfication rate (%)', qg_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_p_g_satisfication rate (%)', ((torch.sum(test_ineq_p_g == 0, dim=1)/test_ineq_p_g.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_q_g_satisfication rate (%)', ((torch.sum(test_ineq_q_g == 0, dim=1)/test_ineq_q_g.shape[1])*100).detach().cpu().numpy())
    
        v_rate_torch = (((vm <= acopf_contingencies[case].vmax) & (vm >= acopf_contingencies[case].vmin)).sum()/acopf_contingencies[case].nbus)*100
        dict_agg(test_stats, 'test_v_m_satisfication rate (%)', v_rate_torch.detach().cpu().numpy().reshape(-1,1))
        # dict_agg(test_stats, 'test_v_m_satisfication rate (%)', ((torch.sum(test_ineq_v_m == 0, dim=1)/test_ineq_v_m.shape[1])*100).detach().cpu().numpy())
    
        sff_rate_torch = ((Sff.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        stt_rate_torch = ((Stt.real <= flow_max).sum()/acopf_contingencies[case].nl)*100        
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', sff_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', stt_rate_torch.detach().cpu().numpy().reshape(-1,1))
        dict_agg(test_stats, 'test_line_limit_satisfication_rate (%)', ((torch.sum(test_ineq_line_l == 0, dim=1)/test_ineq_line_l.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_Sf(%)', ((torch.sum(line_limit_vio_Sf == 0, dim=1)/line_limit_vio_Sf.shape[1])*100).detach().cpu().numpy())
        # dict_agg(test_stats, 'test_line_limit_satisfication_rate_St(%)', ((torch.sum(line_limit_vio_St == 0, dim=1)/line_limit_vio_St.shape[1])*100).detach().cpu().numpy())
    
        dict_agg(test_stats, 'test_ineq_q_g_num_viol_0', torch.sum(test_ineq_q_g > test_eps_converge, dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_ineq_v_m_num_viol_0', torch.sum(test_ineq_v_m > test_eps_converge, dim=1).detach().cpu().numpy())
    
        test_eq_real = test_eq_resid[:,:acopf_contingencies[case].nbus]
        test_eq_react = test_eq_resid[:,acopf_contingencies[case].nbus:]
        dict_agg(test_stats, 'test_eq_max', torch.max(torch.abs(test_eq_resid), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_mean', torch.mean(torch.abs(test_eq_resid), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_max', torch.max(torch.abs(test_eq_real), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_real_mean', torch.mean(torch.abs(test_eq_real), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_max', torch.max(torch.abs(test_eq_react), dim=1)[0].detach().cpu().numpy())
        dict_agg(test_stats, 'test_eq_react_mean', torch.mean(torch.abs(test_eq_react), dim=1).detach().cpu().numpy())
        dict_agg(test_stats, 'test_active_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,:acopf_contingencies[case].nbus] <= 1e-2) & (test_eq_resid[:,:acopf_contingencies[case].nbus] >= -1e-2)  , dim=1)/test_eq_resid[:,:acopf_contingencies[case].nbus].shape[1]*100).detach().cpu().numpy())
        dict_agg(test_stats, 'test_reactive_eq_satisfication rate (%)', (torch.sum((test_eq_resid[:,acopf_contingencies[case].nbus:] <= 1e-2) & (test_eq_resid[:,acopf_contingencies[case].nbus:] >= -1e-2)  , dim=1)/test_eq_resid[:,acopf_contingencies[case].nbus:].shape[1]*100).detach().cpu().numpy())

        print('Test batch {}: test loss {:.4f}, test obj {:.4f}, ineq max {:.4f}, ineq mean {:.4f}, ineq q_g num viol {:.4f}, ineq v_m num viol {:.4f}, eq max {:.4f}, eq mean {:.4f}, p_g satisfication rate {:.4f}, q_g satisfication rate {:.4f}, v_m satisfication rate {:.4f}, test_line_limit_satisfication_rate {:.4f}, test_line_limit_satisfication_rate_Sf {:.4f}, test_line_limit_satisfication_rate_St {:.4f}, active eq satisfication rate {:.4f}, reactive eq satisfication rate {:.4f}'.format(
                    i, np.mean(test_stats['test_loss']), np.mean(test_stats['test_obj_cost']), np.mean(test_stats['test_ineq_max']), np.mean(test_stats['test_ineq_mean']),
                    np.mean(test_stats['test_ineq_q_g_num_viol_0']), np.mean(test_stats['test_ineq_v_m_num_viol_0']),
                    np.mean(test_stats['test_eq_max']), np.mean(test_stats['test_eq_mean']), np.mean(test_stats['test_p_g_satisfication rate (%)']), np.mean(test_stats['test_q_g_satisfication rate (%)']), np.mean(test_stats['test_v_m_satisfication rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate (%)']), np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']), np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']), np.mean(test_stats['test_active_eq_satisfication rate (%)']), np.mean(test_stats['test_reactive_eq_satisfication rate (%)'])))

    test_stats_contingency += [test_stats]
    print("\n")
# Out:
# Contingency  0
# Test batch 0: test loss 133.0507, test obj 131.0887, ineq max 0.4713, ineq mean 0.0003, ineq q_g num viol 22.0000, ineq v_m num viol 0.0000, eq max 0.0015, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 91.5385, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 1: test loss 133.3489, test obj 130.8628, ineq max 0.4798, ineq mean 0.0003, ineq q_g num viol 23.5000, ineq v_m num viol 0.0000, eq max 0.0014, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 90.9615, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 100.0000, test_line_limit_satisfication_rate_Sf 100.0000, test_line_limit_satisfication_rate_St 100.0000, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 2: test loss 133.6799, test obj 130.8422, ineq max 0.6023, ineq mean 0.0004, ineq q_g num viol 22.0000, ineq v_m num viol 0.0000, eq max 0.0015, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 91.5385, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9749, test_line_limit_satisfication_rate_Sf 99.9832, test_line_limit_satisfication_rate_St 99.9665, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 3: test loss 133.4529, test obj 130.8089, ineq max 0.5938, ineq mean 0.0004, ineq q_g num viol 20.7500, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.0192, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9812, test_line_limit_satisfication_rate_Sf 99.9874, test_line_limit_satisfication_rate_St 99.9749, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 4: test loss 133.4535, test obj 130.8718, ineq max 0.5575, ineq mean 0.0004, ineq q_g num viol 19.8000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.3846, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9849, test_line_limit_satisfication_rate_Sf 99.9899, test_line_limit_satisfication_rate_St 99.9799, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 5: test loss 133.2312, test obj 130.8115, ineq max 0.5388, ineq mean 0.0003, ineq q_g num viol 20.3333, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.1795, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9916, test_line_limit_satisfication_rate_St 99.9833, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 6: test loss 133.1622, test obj 130.8285, ineq max 0.5349, ineq mean 0.0003, ineq q_g num viol 20.1429, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.2527, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9892, test_line_limit_satisfication_rate_Sf 99.9928, test_line_limit_satisfication_rate_St 99.9856, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 7: test loss 133.1225, test obj 130.8458, ineq max 0.5402, ineq mean 0.0003, ineq q_g num viol 20.0000, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.3077, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9906, test_line_limit_satisfication_rate_Sf 99.9937, test_line_limit_satisfication_rate_St 99.9874, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 8: test loss 133.1921, test obj 130.8840, ineq max 0.5406, ineq mean 0.0003, ineq q_g num viol 20.0000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.3077, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9860, test_line_limit_satisfication_rate_Sf 99.9888, test_line_limit_satisfication_rate_St 99.9833, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 9: test loss 133.1842, test obj 130.8604, ineq max 0.5581, ineq mean 0.0003, ineq q_g num viol 19.9000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 100.0000, q_g satisfication rate 92.3462, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9824, test_line_limit_satisfication_rate_Sf 99.9799, test_line_limit_satisfication_rate_St 99.9849, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 10: test loss 133.3539, test obj 130.9138, ineq max 0.6565, ineq mean 0.0003, ineq q_g num viol 19.9091, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9650, q_g satisfication rate 92.3427, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9840, test_line_limit_satisfication_rate_Sf 99.9817, test_line_limit_satisfication_rate_St 99.9863, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 11: test loss 133.4178, test obj 130.9102, ineq max 0.7101, ineq mean 0.0003, ineq q_g num viol 19.9167, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9679, q_g satisfication rate 92.3397, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9812, test_line_limit_satisfication_rate_Sf 99.9791, test_line_limit_satisfication_rate_St 99.9833, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 12: test loss 133.3966, test obj 130.9061, ineq max 0.6938, ineq mean 0.0003, ineq q_g num viol 19.9231, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9704, q_g satisfication rate 92.3373, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9826, test_line_limit_satisfication_rate_Sf 99.9807, test_line_limit_satisfication_rate_St 99.9845, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 13: test loss 133.3620, test obj 130.8992, ineq max 0.6792, ineq mean 0.0003, ineq q_g num viol 19.8571, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9725, q_g satisfication rate 92.3626, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9838, test_line_limit_satisfication_rate_Sf 99.9820, test_line_limit_satisfication_rate_St 99.9856, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 14: test loss 133.4786, test obj 130.9062, ineq max 0.7157, ineq mean 0.0004, ineq q_g num viol 19.7333, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9744, q_g satisfication rate 92.4103, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9816, test_line_limit_satisfication_rate_Sf 99.9799, test_line_limit_satisfication_rate_St 99.9833, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 15: test loss 133.5348, test obj 130.9064, ineq max 0.7154, ineq mean 0.0004, ineq q_g num viol 19.6875, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9760, q_g satisfication rate 92.4279, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9827, test_line_limit_satisfication_rate_Sf 99.9812, test_line_limit_satisfication_rate_St 99.9843, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 16: test loss 133.5879, test obj 130.9166, ineq max 0.7304, ineq mean 0.0004, ineq q_g num viol 19.7059, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9774, q_g satisfication rate 92.4208, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9837, test_line_limit_satisfication_rate_Sf 99.9823, test_line_limit_satisfication_rate_St 99.9852, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 17: test loss 133.5515, test obj 130.9015, ineq max 0.7166, ineq mean 0.0004, ineq q_g num viol 19.5000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9786, q_g satisfication rate 92.5000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9846, test_line_limit_satisfication_rate_Sf 99.9832, test_line_limit_satisfication_rate_St 99.9860, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 18: test loss 133.4848, test obj 130.8971, ineq max 0.6954, ineq mean 0.0004, ineq q_g num viol 19.6316, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9798, q_g satisfication rate 92.4494, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9855, test_line_limit_satisfication_rate_Sf 99.9841, test_line_limit_satisfication_rate_St 99.9868, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 19: test loss 133.4523, test obj 130.8967, ineq max 0.6798, ineq mean 0.0004, ineq q_g num viol 19.7500, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9808, q_g satisfication rate 92.4039, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9862, test_line_limit_satisfication_rate_Sf 99.9849, test_line_limit_satisfication_rate_St 99.9874, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 20: test loss 133.5018, test obj 130.9131, ineq max 0.6931, ineq mean 0.0004, ineq q_g num viol 19.4762, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9817, q_g satisfication rate 92.5092, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9844, test_line_limit_satisfication_rate_Sf 99.9832, test_line_limit_satisfication_rate_St 99.9856, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 21: test loss 133.4986, test obj 130.9144, ineq max 0.6861, ineq mean 0.0004, ineq q_g num viol 19.4545, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9825, q_g satisfication rate 92.5175, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9852, test_line_limit_satisfication_rate_Sf 99.9840, test_line_limit_satisfication_rate_St 99.9863, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 22: test loss 133.6544, test obj 130.9444, ineq max 0.8249, ineq mean 0.0004, ineq q_g num viol 19.3913, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9666, q_g satisfication rate 92.5418, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9847, test_line_limit_satisfication_rate_Sf 99.9825, test_line_limit_satisfication_rate_St 99.9869, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 23: test loss 133.7243, test obj 130.9657, ineq max 0.8633, ineq mean 0.0004, ineq q_g num viol 19.3750, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9519, q_g satisfication rate 92.5481, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9853, test_line_limit_satisfication_rate_Sf 99.9832, test_line_limit_satisfication_rate_St 99.9874, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 24: test loss 133.7211, test obj 130.9435, ineq max 0.8498, ineq mean 0.0004, ineq q_g num viol 19.4400, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9538, q_g satisfication rate 92.5231, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9859, test_line_limit_satisfication_rate_Sf 99.9839, test_line_limit_satisfication_rate_St 99.9879, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 25: test loss 133.7325, test obj 130.9619, ineq max 0.8673, ineq mean 0.0004, ineq q_g num viol 19.3077, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9408, q_g satisfication rate 92.5740, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9865, test_line_limit_satisfication_rate_Sf 99.9845, test_line_limit_satisfication_rate_St 99.9884, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 26: test loss 133.7377, test obj 130.9769, ineq max 0.8545, ineq mean 0.0004, ineq q_g num viol 19.2593, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9288, q_g satisfication rate 92.5926, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9851, test_line_limit_satisfication_rate_St 99.9888, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 27: test loss 133.9070, test obj 131.0029, ineq max 1.0123, ineq mean 0.0004, ineq q_g num viol 19.1429, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9176, q_g satisfication rate 92.6374, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9856, test_line_limit_satisfication_rate_St 99.9892, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 28: test loss 134.2630, test obj 131.0316, ineq max 1.2239, ineq mean 0.0004, ineq q_g num viol 19.1034, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9072, q_g satisfication rate 92.6525, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9844, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 29: test loss 134.3907, test obj 131.0370, ineq max 1.2752, ineq mean 0.0005, ineq q_g num viol 19.3667, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9103, q_g satisfication rate 92.5513, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9866, test_line_limit_satisfication_rate_Sf 99.9832, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 30: test loss 134.3635, test obj 131.0385, ineq max 1.2563, ineq mean 0.0005, ineq q_g num viol 19.3548, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9132, q_g satisfication rate 92.5558, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9838, test_line_limit_satisfication_rate_St 99.9903, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 31: test loss 134.4074, test obj 131.0318, ineq max 1.2779, ineq mean 0.0005, ineq q_g num viol 19.2812, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9159, q_g satisfication rate 92.5841, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9859, test_line_limit_satisfication_rate_Sf 99.9827, test_line_limit_satisfication_rate_St 99.9890, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 32: test loss 134.3838, test obj 131.0178, ineq max 1.2514, ineq mean 0.0005, ineq q_g num viol 19.4242, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9184, q_g satisfication rate 92.5291, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9863, test_line_limit_satisfication_rate_Sf 99.9833, test_line_limit_satisfication_rate_St 99.9893, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 33: test loss 134.3794, test obj 131.0206, ineq max 1.2313, ineq mean 0.0005, ineq q_g num viol 19.5000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9208, q_g satisfication rate 92.5000, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9867, test_line_limit_satisfication_rate_Sf 99.9837, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 34: test loss 134.4840, test obj 131.0382, ineq max 1.3183, ineq mean 0.0005, ineq q_g num viol 19.6286, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9121, q_g satisfication rate 92.4506, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9871, test_line_limit_satisfication_rate_Sf 99.9842, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 35: test loss 134.4651, test obj 131.0381, ineq max 1.2998, ineq mean 0.0005, ineq q_g num viol 19.6667, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9145, q_g satisfication rate 92.4359, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9846, test_line_limit_satisfication_rate_St 99.9902, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 36: test loss 134.4882, test obj 131.0178, ineq max 1.2991, ineq mean 0.0005, ineq q_g num viol 19.6757, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9168, q_g satisfication rate 92.4324, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9864, test_line_limit_satisfication_rate_Sf 99.9837, test_line_limit_satisfication_rate_St 99.9891, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 37: test loss 134.4845, test obj 130.9965, ineq max 1.2813, ineq mean 0.0005, ineq q_g num viol 19.7632, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9190, q_g satisfication rate 92.3988, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9868, test_line_limit_satisfication_rate_Sf 99.9841, test_line_limit_satisfication_rate_St 99.9894, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 38: test loss 134.4869, test obj 131.0021, ineq max 1.2665, ineq mean 0.0005, ineq q_g num viol 19.8462, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9211, q_g satisfication rate 92.3669, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9871, test_line_limit_satisfication_rate_Sf 99.9845, test_line_limit_satisfication_rate_St 99.9897, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 39: test loss 134.4346, test obj 130.9998, ineq max 1.2445, ineq mean 0.0005, ineq q_g num viol 19.7000, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9231, q_g satisfication rate 92.4231, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9849, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 40: test loss 134.6035, test obj 131.0215, ineq max 1.4061, ineq mean 0.0005, ineq q_g num viol 19.6829, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9156, q_g satisfication rate 92.4296, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9877, test_line_limit_satisfication_rate_Sf 99.9853, test_line_limit_satisfication_rate_St 99.9902, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 41: test loss 134.5995, test obj 131.0303, ineq max 1.3929, ineq mean 0.0005, ineq q_g num viol 19.6905, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9084, q_g satisfication rate 92.4267, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9880, test_line_limit_satisfication_rate_Sf 99.9856, test_line_limit_satisfication_rate_St 99.9904, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 42: test loss 134.5947, test obj 131.0339, ineq max 1.3810, ineq mean 0.0005, ineq q_g num viol 19.7907, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9106, q_g satisfication rate 92.3882, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9883, test_line_limit_satisfication_rate_Sf 99.9860, test_line_limit_satisfication_rate_St 99.9906, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 43: test loss 134.5578, test obj 131.0325, ineq max 1.3597, ineq mean 0.0005, ineq q_g num viol 19.7727, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9126, q_g satisfication rate 92.3951, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9886, test_line_limit_satisfication_rate_Sf 99.9863, test_line_limit_satisfication_rate_St 99.9909, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 44: test loss 134.5919, test obj 131.0446, ineq max 1.4061, ineq mean 0.0005, ineq q_g num viol 19.6667, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9060, q_g satisfication rate 92.4359, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9888, test_line_limit_satisfication_rate_Sf 99.9866, test_line_limit_satisfication_rate_St 99.9911, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 45: test loss 134.5558, test obj 131.0496, ineq max 1.3873, ineq mean 0.0005, ineq q_g num viol 19.6739, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9080, q_g satisfication rate 92.4331, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9891, test_line_limit_satisfication_rate_Sf 99.9869, test_line_limit_satisfication_rate_St 99.9913, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 46: test loss 134.6232, test obj 131.0624, ineq max 1.4548, ineq mean 0.0005, ineq q_g num viol 19.7234, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9018, q_g satisfication rate 92.4141, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9893, test_line_limit_satisfication_rate_Sf 99.9872, test_line_limit_satisfication_rate_St 99.9914, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 47: test loss 134.8582, test obj 131.0504, ineq max 1.5409, ineq mean 0.0005, ineq q_g num viol 19.8125, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9038, q_g satisfication rate 92.3798, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9880, test_line_limit_satisfication_rate_Sf 99.9864, test_line_limit_satisfication_rate_St 99.9895, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 48: test loss 134.8181, test obj 131.0418, ineq max 1.5190, ineq mean 0.0005, ineq q_g num viol 19.8163, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9058, q_g satisfication rate 92.3783, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9882, test_line_limit_satisfication_rate_Sf 99.9867, test_line_limit_satisfication_rate_St 99.9897, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 49: test loss 134.7736, test obj 131.0336, ineq max 1.5006, ineq mean 0.0005, ineq q_g num viol 19.8000, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9077, q_g satisfication rate 92.3846, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9884, test_line_limit_satisfication_rate_Sf 99.9869, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 50: test loss 134.7426, test obj 131.0210, ineq max 1.4789, ineq mean 0.0005, ineq q_g num viol 19.7647, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9095, q_g satisfication rate 92.3982, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9887, test_line_limit_satisfication_rate_Sf 99.9872, test_line_limit_satisfication_rate_St 99.9901, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 51: test loss 134.7291, test obj 131.0242, ineq max 1.4644, ineq mean 0.0005, ineq q_g num viol 19.6923, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9112, q_g satisfication rate 92.4260, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9889, test_line_limit_satisfication_rate_Sf 99.9874, test_line_limit_satisfication_rate_St 99.9903, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 52: test loss 134.7441, test obj 131.0128, ineq max 1.4598, ineq mean 0.0005, ineq q_g num viol 19.6792, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9129, q_g satisfication rate 92.4311, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9886, test_line_limit_satisfication_rate_Sf 99.9867, test_line_limit_satisfication_rate_St 99.9905, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 53: test loss 134.7560, test obj 131.0218, ineq max 1.4773, ineq mean 0.0005, ineq q_g num viol 19.6852, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9074, q_g satisfication rate 92.4288, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9888, test_line_limit_satisfication_rate_Sf 99.9870, test_line_limit_satisfication_rate_St 99.9907, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 54: test loss 134.7355, test obj 131.0200, ineq max 1.4610, ineq mean 0.0005, ineq q_g num viol 19.6727, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9091, q_g satisfication rate 92.4336, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9886, test_line_limit_satisfication_rate_Sf 99.9872, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 55: test loss 134.8024, test obj 131.0192, ineq max 1.4777, ineq mean 0.0005, ineq q_g num viol 19.6429, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9107, q_g satisfication rate 92.4451, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9856, test_line_limit_satisfication_rate_St 99.9892, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 56: test loss 134.7702, test obj 131.0220, ineq max 1.4621, ineq mean 0.0005, ineq q_g num viol 19.5965, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9123, q_g satisfication rate 92.4629, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9876, test_line_limit_satisfication_rate_Sf 99.9859, test_line_limit_satisfication_rate_St 99.9894, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 57: test loss 134.7399, test obj 131.0180, ineq max 1.4465, ineq mean 0.0005, ineq q_g num viol 19.6207, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9138, q_g satisfication rate 92.4536, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9879, test_line_limit_satisfication_rate_Sf 99.9861, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 58: test loss 134.8258, test obj 131.0266, ineq max 1.4694, ineq mean 0.0005, ineq q_g num viol 19.6610, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9087, q_g satisfication rate 92.4381, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9876, test_line_limit_satisfication_rate_Sf 99.9855, test_line_limit_satisfication_rate_St 99.9898, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 59: test loss 134.8432, test obj 131.0313, ineq max 1.4590, ineq mean 0.0005, ineq q_g num viol 19.7333, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9103, q_g satisfication rate 92.4102, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9849, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 60: test loss 134.8307, test obj 131.0288, ineq max 1.4433, ineq mean 0.0005, ineq q_g num viol 19.7869, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9117, q_g satisfication rate 92.3896, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9876, test_line_limit_satisfication_rate_Sf 99.9852, test_line_limit_satisfication_rate_St 99.9901, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 61: test loss 134.9231, test obj 131.0382, ineq max 1.4832, ineq mean 0.0005, ineq q_g num viol 19.8548, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9069, q_g satisfication rate 92.3635, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9846, test_line_limit_satisfication_rate_St 99.9903, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 62: test loss 134.9494, test obj 131.0349, ineq max 1.4876, ineq mean 0.0005, ineq q_g num viol 19.8571, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9084, q_g satisfication rate 92.3626, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9868, test_line_limit_satisfication_rate_Sf 99.9840, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 63: test loss 134.9422, test obj 131.0339, ineq max 1.4741, ineq mean 0.0005, ineq q_g num viol 19.8906, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9099, q_g satisfication rate 92.3498, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9843, test_line_limit_satisfication_rate_St 99.9898, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 64: test loss 134.9161, test obj 131.0343, ineq max 1.4596, ineq mean 0.0005, ineq q_g num viol 19.8308, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9112, q_g satisfication rate 92.3728, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9872, test_line_limit_satisfication_rate_Sf 99.9845, test_line_limit_satisfication_rate_St 99.9900, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 65: test loss 134.8908, test obj 131.0388, ineq max 1.4444, ineq mean 0.0005, ineq q_g num viol 19.7727, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9068, q_g satisfication rate 92.3951, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9871, test_line_limit_satisfication_rate_Sf 99.9848, test_line_limit_satisfication_rate_St 99.9893, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 66: test loss 134.8946, test obj 131.0455, ineq max 1.4571, ineq mean 0.0005, ineq q_g num viol 19.6866, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9024, q_g satisfication rate 92.4282, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9869, test_line_limit_satisfication_rate_Sf 99.9850, test_line_limit_satisfication_rate_St 99.9887, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 67: test loss 134.8844, test obj 131.0413, ineq max 1.4491, ineq mean 0.0005, ineq q_g num viol 19.7206, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9038, q_g satisfication rate 92.4152, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9863, test_line_limit_satisfication_rate_Sf 99.9845, test_line_limit_satisfication_rate_St 99.9882, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 68: test loss 134.9111, test obj 131.0465, ineq max 1.4416, ineq mean 0.0005, ineq q_g num viol 19.7101, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.8997, q_g satisfication rate 92.4192, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9865, test_line_limit_satisfication_rate_Sf 99.9847, test_line_limit_satisfication_rate_St 99.9883, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 69: test loss 134.8921, test obj 131.0505, ineq max 1.4300, ineq mean 0.0005, ineq q_g num viol 19.6429, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9011, q_g satisfication rate 92.4451, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9864, test_line_limit_satisfication_rate_Sf 99.9842, test_line_limit_satisfication_rate_St 99.9885, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 70: test loss 134.8801, test obj 131.0464, ineq max 1.4200, ineq mean 0.0005, ineq q_g num viol 19.6901, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9025, q_g satisfication rate 92.4269, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9859, test_line_limit_satisfication_rate_Sf 99.9837, test_line_limit_satisfication_rate_St 99.9880, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 71: test loss 134.8997, test obj 131.0533, ineq max 1.4415, ineq mean 0.0005, ineq q_g num viol 19.6944, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.8985, q_g satisfication rate 92.4252, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9860, test_line_limit_satisfication_rate_Sf 99.9839, test_line_limit_satisfication_rate_St 99.9881, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 72: test loss 134.8641, test obj 131.0517, ineq max 1.4263, ineq mean 0.0005, ineq q_g num viol 19.6027, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.8999, q_g satisfication rate 92.4605, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9859, test_line_limit_satisfication_rate_Sf 99.9842, test_line_limit_satisfication_rate_St 99.9876, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 73: test loss 134.8423, test obj 131.0535, ineq max 1.4136, ineq mean 0.0005, ineq q_g num viol 19.5811, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9012, q_g satisfication rate 92.4688, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9861, test_line_limit_satisfication_rate_Sf 99.9844, test_line_limit_satisfication_rate_St 99.9878, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 74: test loss 134.8214, test obj 131.0470, ineq max 1.4011, ineq mean 0.0005, ineq q_g num viol 19.6267, ineq v_m num viol 0.0000, eq max 0.0017, eq mean 0.0000, p_g satisfication rate 99.9026, q_g satisfication rate 92.4513, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9863, test_line_limit_satisfication_rate_Sf 99.9846, test_line_limit_satisfication_rate_St 99.9879, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 75: test loss 134.7922, test obj 131.0454, ineq max 1.3877, ineq mean 0.0005, ineq q_g num viol 19.5789, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9038, q_g satisfication rate 92.4696, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9865, test_line_limit_satisfication_rate_Sf 99.9848, test_line_limit_satisfication_rate_St 99.9881, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 76: test loss 134.7763, test obj 131.0417, ineq max 1.3762, ineq mean 0.0005, ineq q_g num viol 19.6234, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9051, q_g satisfication rate 92.4525, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9866, test_line_limit_satisfication_rate_Sf 99.9850, test_line_limit_satisfication_rate_St 99.9883, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 77: test loss 134.7634, test obj 131.0361, ineq max 1.3664, ineq mean 0.0005, ineq q_g num viol 19.6795, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9063, q_g satisfication rate 92.4310, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9868, test_line_limit_satisfication_rate_Sf 99.9852, test_line_limit_satisfication_rate_St 99.9884, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 78: test loss 134.7520, test obj 131.0328, ineq max 1.3608, ineq mean 0.0005, ineq q_g num viol 19.7342, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9075, q_g satisfication rate 92.4099, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9854, test_line_limit_satisfication_rate_St 99.9885, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 79: test loss 134.7264, test obj 131.0270, ineq max 1.3480, ineq mean 0.0005, ineq q_g num viol 19.7875, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9087, q_g satisfication rate 92.3894, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9871, test_line_limit_satisfication_rate_Sf 99.9855, test_line_limit_satisfication_rate_St 99.9887, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 80: test loss 134.8486, test obj 131.0374, ineq max 1.4259, ineq mean 0.0005, ineq q_g num viol 19.8025, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9050, q_g satisfication rate 92.3837, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9851, test_line_limit_satisfication_rate_St 99.9888, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 81: test loss 134.8348, test obj 131.0368, ineq max 1.4234, ineq mean 0.0005, ineq q_g num viol 19.7927, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9062, q_g satisfication rate 92.3874, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9868, test_line_limit_satisfication_rate_Sf 99.9847, test_line_limit_satisfication_rate_St 99.9890, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 82: test loss 134.8250, test obj 131.0351, ineq max 1.4137, ineq mean 0.0005, ineq q_g num viol 19.8072, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9073, q_g satisfication rate 92.3818, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9849, test_line_limit_satisfication_rate_St 99.9891, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 83: test loss 134.8013, test obj 131.0325, ineq max 1.4040, ineq mean 0.0005, ineq q_g num viol 19.7619, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9084, q_g satisfication rate 92.3993, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9871, test_line_limit_satisfication_rate_Sf 99.9850, test_line_limit_satisfication_rate_St 99.9892, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 84: test loss 134.8072, test obj 131.0348, ineq max 1.4008, ineq mean 0.0005, ineq q_g num viol 19.7882, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9095, q_g satisfication rate 92.3891, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9873, test_line_limit_satisfication_rate_Sf 99.9852, test_line_limit_satisfication_rate_St 99.9894, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 85: test loss 134.8214, test obj 131.0406, ineq max 1.4192, ineq mean 0.0005, ineq q_g num viol 19.7558, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9061, q_g satisfication rate 92.4016, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9854, test_line_limit_satisfication_rate_St 99.9895, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 86: test loss 134.8076, test obj 131.0318, ineq max 1.4103, ineq mean 0.0005, ineq q_g num viol 19.7931, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9072, q_g satisfication rate 92.3873, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9876, test_line_limit_satisfication_rate_Sf 99.9856, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 87: test loss 134.8261, test obj 131.0379, ineq max 1.4319, ineq mean 0.0005, ineq q_g num viol 19.7841, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9039, q_g satisfication rate 92.3907, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9877, test_line_limit_satisfication_rate_Sf 99.9857, test_line_limit_satisfication_rate_St 99.9897, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 88: test loss 134.8596, test obj 131.0318, ineq max 1.4402, ineq mean 0.0005, ineq q_g num viol 19.7528, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9049, q_g satisfication rate 92.3984, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9870, test_line_limit_satisfication_rate_Sf 99.9853, test_line_limit_satisfication_rate_St 99.9887, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 89: test loss 134.8446, test obj 131.0357, ineq max 1.4324, ineq mean 0.0005, ineq q_g num viol 19.7444, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9017, q_g satisfication rate 92.4017, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9872, test_line_limit_satisfication_rate_Sf 99.9855, test_line_limit_satisfication_rate_St 99.9888, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 90: test loss 134.8628, test obj 131.0412, ineq max 1.4489, ineq mean 0.0005, ineq q_g num viol 19.7582, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.8986, q_g satisfication rate 92.3965, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9873, test_line_limit_satisfication_rate_Sf 99.9856, test_line_limit_satisfication_rate_St 99.9890, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 91: test loss 134.8428, test obj 131.0404, ineq max 1.4369, ineq mean 0.0005, ineq q_g num viol 19.7609, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.8997, q_g satisfication rate 92.3955, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9874, test_line_limit_satisfication_rate_Sf 99.9858, test_line_limit_satisfication_rate_St 99.9891, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 92: test loss 134.8269, test obj 131.0382, ineq max 1.4281, ineq mean 0.0005, ineq q_g num viol 19.7527, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9007, q_g satisfication rate 92.3987, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9876, test_line_limit_satisfication_rate_Sf 99.9860, test_line_limit_satisfication_rate_St 99.9892, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 93: test loss 134.8120, test obj 131.0397, ineq max 1.4173, ineq mean 0.0005, ineq q_g num viol 19.7553, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9018, q_g satisfication rate 92.3977, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9877, test_line_limit_satisfication_rate_Sf 99.9861, test_line_limit_satisfication_rate_St 99.9893, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 94: test loss 134.7953, test obj 131.0391, ineq max 1.4081, ineq mean 0.0005, ineq q_g num viol 19.7895, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9028, q_g satisfication rate 92.3846, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9878, test_line_limit_satisfication_rate_Sf 99.9863, test_line_limit_satisfication_rate_St 99.9894, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 95: test loss 134.7811, test obj 131.0342, ineq max 1.3999, ineq mean 0.0005, ineq q_g num viol 19.7917, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9038, q_g satisfication rate 92.3838, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9880, test_line_limit_satisfication_rate_Sf 99.9864, test_line_limit_satisfication_rate_St 99.9895, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 96: test loss 134.7715, test obj 131.0315, ineq max 1.3915, ineq mean 0.0005, ineq q_g num viol 19.8351, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9048, q_g satisfication rate 92.3672, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9881, test_line_limit_satisfication_rate_Sf 99.9865, test_line_limit_satisfication_rate_St 99.9896, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 97: test loss 134.7869, test obj 131.0361, ineq max 1.3999, ineq mean 0.0005, ineq q_g num viol 19.7959, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9019, q_g satisfication rate 92.3823, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9882, test_line_limit_satisfication_rate_Sf 99.9867, test_line_limit_satisfication_rate_St 99.9897, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 98: test loss 134.8475, test obj 131.0423, ineq max 1.4304, ineq mean 0.0005, ineq q_g num viol 19.8384, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.8990, q_g satisfication rate 92.3660, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9881, test_line_limit_satisfication_rate_Sf 99.9863, test_line_limit_satisfication_rate_St 99.9898, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000
# Test batch 99: test loss 134.8353, test obj 131.0408, ineq max 1.4220, ineq mean 0.0005, ineq q_g num viol 19.9100, ineq v_m num viol 0.0000, eq max 0.0018, eq mean 0.0000, p_g satisfication rate 99.9000, q_g satisfication rate 92.3385, v_m satisfication rate 100.0000, test_line_limit_satisfication_rate 99.9882, test_line_limit_satisfication_rate_Sf 99.9864, test_line_limit_satisfication_rate_St 99.9899, active eq satisfication rate 100.0000, reactive eq satisfication rate 100.0000

# %% [markdown]
# * Arithmetic mean

# %%
## Calculate the results of GraphLDE
for case in range(len(acopf_contingencies)):
    print("Contingency ", case)
    print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats_contingency[case]['test_obj_cost'])*10000, 4))
    print("GraphLDE eq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_mean']))
    print("GraphLDE eq. max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_max']))
    print("GraphLDE eq. active mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_mean']))
    print("GraphLDE eq. active max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_real_max']))
    print("GraphLDE eq. reactive mean for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_mean']))
    print("GraphLDE eq. reactive max for test samples: ", np.mean(test_stats_contingency[case]['test_eq_react_max']))
    
    print("\n")
    print("GraphLDE ineq. mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_mean']))
    print("GraphLDE ineq. max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_max']))
    print("GraphLDE ineq. p_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_mean']))
    print("GraphLDE ineq. p_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_p_g_max']))
    print("GraphLDE ineq. q_g mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_mean']))
    print("GraphLDE ineq. q_g max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_q_g_max']))
    print("GraphLDE ineq. v_m mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_mean']))
    print("GraphLDE ineq. v_m max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_v_m_max']))
    print("GraphLDE ineq. line_l mean for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_mean']))
    print("GraphLDE ineq. line_l max for test samples: ", np.mean(test_stats_contingency[case]['test_ineq_line_l_max']))
    
    print("\n")
    print("GraphLDE p_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_p_g_satisfication rate (%)']))
    print("GraphLDE q_g satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_q_g_satisfication rate (%)']))
    print("GraphLDE v_m satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_v_m_satisfication rate (%)']))
    print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_Sf(%)']))
    print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats_contingency[case]['test_line_limit_satisfication_rate_St(%)']))
    print("GraphLDE active eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_active_eq_satisfication rate (%)']))
    print("GraphLDE reactive eq satisfication rate for test samples: ", np.mean(test_stats_contingency[case]['test_reactive_eq_satisfication rate (%)']))
    
    print("\n")
    # print("DeepLDE time (ms) <== average value for test dataset:", (test_stats['time']/1000)*1e3)
    print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
    print("\n")
# Out:
# Contingency  0
# GraphLDE obj. value for test samples:  1310408.1
# GraphLDE eq. mean for test samples:  3.608863e-05
# GraphLDE eq. max for test samples:  0.0017942488
# GraphLDE eq. active mean for test samples:  2.872278e-05
# GraphLDE eq. active max for test samples:  0.0011278655
# GraphLDE eq. reactive mean for test samples:  4.3454478e-05
# GraphLDE eq. reactive max for test samples:  0.0017001911
#
#
# GraphLDE ineq. mean for test samples:  0.0005262871
# GraphLDE ineq. max for test samples:  1.4220247
# GraphLDE ineq. p_g mean for test samples:  0.0015782282
# GraphLDE ineq. p_g max for test samples:  0.8206787
# GraphLDE ineq. q_g mean for test samples:  0.004648377
# GraphLDE ineq. q_g max for test samples:  0.5586155
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.00013987318
# GraphLDE ineq. line_l max for test samples:  0.39878488
#
#
# GraphLDE p_g satisfication rate for test samples:  99.9
# GraphLDE q_g satisfication rate for test samples:  92.338455
# GraphLDE v_m satisfication rate for test samples:  100.0
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.986435
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.989944
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 54.08669710159302

# %% [markdown]
# * Harmonic mean

# %%
import statistics as st

## Calculate optimality gap
print("GraphLDE obj. value for test samples: ", round(np.mean(test_stats['test_obj_cost'])*10000, 4))
print("GraphLDE eq. mean for test samples: ", st.harmonic_mean(test_stats['test_eq_mean'])) # print("LDF eq. mean for test samples: ", np.mean(test_stats['test_eq_mean']))
print("GraphLDE eq. max for test samples: ", st.harmonic_mean(test_stats['test_eq_max'])) # print("LDF eq. max for test samples: ", np.mean(test_stats['test_eq_max']))
print("GraphLDE eq. active mean for test samples: ", st.harmonic_mean(test_stats['test_eq_real_mean'])) # print("LDF eq. active mean for test samples: ", np.mean(test_stats['test_eq_real_mean']))
print("GraphLDE eq. active max for test samples: ", st.harmonic_mean(test_stats['test_eq_real_max'])) # print("LDF eq. active max for test samples: ", np.mean(test_stats['test_eq_real_max']))
print("GraphLDE eq. reactive mean for test samples: ", st.harmonic_mean(test_stats['test_eq_react_mean'])) # print("LDF eq. reactive mean for test samples: ", np.mean(test_stats['test_eq_react_mean']))
print("GraphLDE eq. reactive max for test samples: ", st.harmonic_mean(test_stats['test_eq_react_max'])) # print("LDF eq. reactive max for test samples: ", np.mean(test_stats['test_eq_react_max']))
print("\n")
print("GraphLDE ineq. mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_mean'])) # print("LDF ineq. mean for test samples: ", np.mean(test_stats['test_ineq_mean']))
print("GraphLDE ineq. max for test samples: ", st.harmonic_mean(test_stats['test_ineq_max'])) # print("LDF ineq. max for test samples: ", np.mean(test_stats['test_ineq_max']))
print("GraphLDE ineq. p_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_mean'])) # print("LDF ineq. p_g mean for test samples: ", np.mean(test_stats['test_ineq_p_g_mean']))
print("GraphLDE ineq. p_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_p_g_max'])) # print("LDF ineq. p_g max for test samples: ", np.mean(test_stats['test_ineq_p_g_max']))
print("GraphLDE ineq. q_g mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_mean'])) # print("LDF ineq. q_g mean for test samples: ", np.mean(test_stats['test_ineq_q_g_mean']))
print("GraphLDE ineq. q_g max for test samples: ", st.harmonic_mean(test_stats['test_ineq_q_g_max'])) # print("LDF ineq. q_g max for test samples: ", np.mean(test_stats['test_ineq_q_g_max']))
print("GraphLDE ineq. v_m mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_mean'])) # print("LDF ineq. v_m mean for test samples: ", np.mean(test_stats['test_ineq_v_m_mean']))
print("GraphLDE ineq. v_m max for test samples: ", st.harmonic_mean(test_stats['test_ineq_v_m_max'])) # print("LDF ineq. v_m max for test samples: ", np.mean(test_stats['test_ineq_v_m_max']))
print("GraphLDE ineq. line_l mean for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_mean'])) # print("LDF ineq. line_l mean for test samples: ", np.mean(test_stats['test_ineq_line_l_mean']))
print("GraphLDE ineq. line_l max for test samples: ", st.harmonic_mean(test_stats['test_ineq_line_l_max'])) # print("LDF ineq. line_l max for test samples: ", np.mean(test_stats['test_ineq_line_l_max']))
print("\n")

print("GraphLDE p_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_p_g_satisfication rate (%)'].reshape(-1))) # print("LDF p_g satisfication rate for test samples: ", np.mean(test_stats['test_p_g_satisfication rate (%)']))
print("GraphLDE q_g satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_q_g_satisfication rate (%)'].reshape(-1))) # print("LDF q_g satisfication rate for test samples: ", np.mean(test_stats['test_q_g_satisfication rate (%)']))
print("GraphLDE v_m satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_v_m_satisfication rate (%)'].reshape(-1))) # print("LDF v_m satisfication rate for test samples: ", np.mean(test_stats['test_v_m_satisfication rate (%)']))
print("GraphLDE test_line_limit_satisfication_rate_Sf for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_Sf(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_Sf for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_Sf(%)']))
print("GraphLDE test_line_limit_satisfication_rate_St for test samples: ", st.harmonic_mean(test_stats['test_line_limit_satisfication_rate_St(%)'].reshape(-1))) # print("LDF test_line_limit_satisfication_rate_St for test samples: ", np.mean(test_stats['test_line_limit_satisfication_rate_St(%)']))
print("GraphLDE active eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_active_eq_satisfication rate (%)'].reshape(-1))) # print("LDF active eq satisfication rate for test samples: ", np.mean(test_stats['test_active_eq_satisfication rate (%)']))
print("GraphLDE reactive eq satisfication rate for test samples: ", st.harmonic_mean(test_stats['test_reactive_eq_satisfication rate (%)'].reshape(-1))) # print("LDF reactive eq satisfication rate for test samples: ", np.mean(test_stats['test_reactive_eq_satisfication rate (%)']))

print("\n")
print("GraphLDE time (ms) <== average value for test dataset:", (np.mean(solve_time)/1)*1e3)
# Out:
# GraphLDE obj. value for test samples:  1310930.4
# GraphLDE eq. mean for test samples:  3.5897927e-05
# GraphLDE eq. max for test samples:  0.0016717056
# GraphLDE eq. active mean for test samples:  2.8573166e-05
# GraphLDE eq. active max for test samples:  0.0009564006
# GraphLDE eq. reactive mean for test samples:  4.3002572e-05
# GraphLDE eq. reactive max for test samples:  0.0015979278
#
#
# GraphLDE ineq. mean for test samples:  0.00036288172
# GraphLDE ineq. max for test samples:  0.64950836
# GraphLDE ineq. p_g mean for test samples:  0.0
# GraphLDE ineq. p_g max for test samples:  0.0
# GraphLDE ineq. q_g mean for test samples:  0.0039722873
# GraphLDE ineq. q_g max for test samples:  0.48839676
# GraphLDE ineq. v_m mean for test samples:  0.0
# GraphLDE ineq. v_m max for test samples:  0.0
# GraphLDE ineq. line_l mean for test samples:  0.0
# GraphLDE ineq. line_l max for test samples:  0.0
#
#
# GraphLDE p_g satisfication rate for test samples:  99.89972
# GraphLDE q_g satisfication rate for test samples:  92.89624
# GraphLDE v_m satisfication rate for test samples:  99.99926
# GraphLDE test_line_limit_satisfication_rate_Sf for test samples:  99.987434
# GraphLDE test_line_limit_satisfication_rate_St for test samples:  99.992966
# GraphLDE active eq satisfication rate for test samples:  100.0
# GraphLDE reactive eq satisfication rate for test samples:  100.0
#
#
# GraphLDE time (ms) <== average value for test dataset: 53.45505237579346
# /pscratch/sd/k/kjsong/conda/pytorch/2.8.0/lib/python3.12/statistics.py:593: RuntimeWarning: divide by zero encountered in scalar divide
#   T, total, count = _sum(w / x if w else 0 for w, x in zip(weights, data))
